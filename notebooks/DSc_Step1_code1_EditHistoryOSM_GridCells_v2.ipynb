# %% [markdown]
# <img src="https://cienciasgeodesicas.ufpr.br/wp-content/uploads/2021/03/cropped-folder-site3.png" alt="Drawing"/>
#
# **Universidade Federal do Paraná**
#
# Programa de Pós-Graduação em Ciências Geodésicas (PPGCG)
#
# ---
#
# *PhD Thesis: TOPONYMS IN TOPOGRAPHIC MAPPING: AN INTEGRATED APPROACH USING OPEN AND COLLABORATIVE GEOSPATIAL DATA*
#
# Authors:
#  - Darlan Miranda Nunes | [ORCID- 0000-0003-3557-5341](https://orcid.org/0000-0001-5566-7919)
#  - Silvana Philippi Camboim | [ORCID- 0000-0003-3557-5341](https://orcid.org/0000-0003-3557-5341)
#
# ---

# %% [markdown]
# ***Article Title: Quantitative Analysis of Collaborative Toponyms in OpenStreetMap: Investigating the Connections with Intrinsic Quality Parameters***
#
#  - DIAGNÓSTICO QUANTITATIVO DOS TOPÔNIMOS COLABORATIVOS NO
# OSM E A RELAÇÃO COM OS PARÂMETROS INTRÍNSECOS DE QUALIDADE

# %% [markdown]
# **Aims**
#
# - To conduct a quantitative assessment of elements within OpenStreetMap (OSM) that have the 'name' attribute filled for potential categories of the Brazilian Authoritative Topographic Map; and
#
# - To investigate the most significant intrinsic quality parameters that contribute to the reliability of toponyms in OSM.

# %% [markdown]
# **Brief Overview of the Proposed Methodology**
#
# - Preliminary survey of potential OpenStreetMap (OSM) tags to provide toponym information relevant to the categories of interest in Brazilian Topographic Mapping;
#
# - Execution of a quantitative analysis on collaboratively entered toponyms, utilizing homogeneous grid-based approaches; and
#
# - Assessment of intrinsic quality parameters as indicators of the reliability of toponyms in a scientific context.

# %% [markdown]
# <img src="../images/flowchart_article01_v2.png" width="600">

# %% [markdown]
# ### Install the necessary libraries to the project

# %%
# In case of using colab, install these necessary libraries
# %pip install requests -q
# %pip install geopandas -q
# %pip install folium -q
# %pip install shapely -q

# %% [markdown]
# ### Import the libraries

# %%
# Import library and some pre-installed modules
import os
import requests
import json
import pandas as pd
import geopandas as gpd
import time
from ipywidgets import widgets

# %% [markdown]
# ### Connect to Google Drive

# %%
# In case of using colab, conect to Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Homogeneous Grid Cells
#  - Statistical Grid (cell size of 200 x 200m) produced by Instituto Brasileiro de Geografia e Estatística (Brazilian Institute of Geography and Statistics)
#
#   - https://geoftp.ibge.gov.br/recortes_para_fins_estatisticos/

# %% [markdown]
# #### Import Homogeneous Grid Cells from Google Drive

# %%
# Import the statistics grid in GeoJSON format

# @title Import the grid with the aggregated data extracted from OSM via the OHSOME API
grid = None

# Function for selecting and loading the GeoJSON file
def select_file(change):
    global grid
    selected_file = change['new']
    
    if selected_file != "Select the GeoJSON file with grid cells:":
        file_path = os.path.join('../data/input_geojson/', selected_file)
        try:
            with open(file_path, 'r') as file:
                grid = json.load(file)
            print("File selected with success:", selected_file)
            print("File path:", file_path)
        except FileNotFoundError:
            print("File not found:", selected_file)

# Listing available GeoJSON files
file_list = [f for f in os.listdir('../data/input_geojson/') if f.endswith('.geojson')]
options = ["Select the GeoJSON file with grid cells:"] + file_list

# Dropdown to select the GeoJSON file
dropdown = widgets.Dropdown(options=options)
dropdown.observe(select_file, names='value')

# Display the dropdown
display(dropdown)
# Out:
# Dropdown(options=('Select the GeoJSON file with grid cells:', 'grade_id25_aguaverde.geojson', 'grade_id77_pass…
# File selected with success: grade_id25_aguaverde.geojson
# File path: ../data/input_geojson/grade_id25_aguaverde.geojson

# %%
# Preview grid cells
grid
# Out:
# {'type': 'FeatureCollection',
#  'name': 'grade_id25_aguaverde_',
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}},
#  'features': [{'type': 'Feature',
#    'properties': {'id': '200ME54798N84962', 'POP10': 834},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.291122118790724, -25.468608595809997],
#        [-49.29115515448677, -25.466779538444882],
#        [-49.28919268899136, -25.46674874296008],
#        [-49.28915963980552, -25.468577799425873],
#        [-49.291122118790724, -25.468608595809997]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54796N84964', 'POP10': 475},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.293117620881446, -25.46681032133921],
#        [-49.29315064218832, -25.46498127836327],
#        [-49.291188189283446, -25.46495049546894],
#        [-49.29115515448677, -25.466779538444882],
#        [-49.293117620881446, -25.46681032133921]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84964', 'POP10': 368},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29115515448677, -25.466779538444882],
#        [-49.291188189283446, -25.46495049546894],
#        [-49.28922573817721, -25.464919700883456],
#        [-49.28919268899136, -25.46674874296008],
#        [-49.29115515448677, -25.466779538444882]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54796N84966', 'POP10': 218},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29315064218832, -25.46498127836327],
#        [-49.293183662595936, -25.463152249776442],
#        [-49.291221224080175, -25.46312146778149],
#        [-49.291188189283446, -25.46495049546894],
#        [-49.29315064218832, -25.46498127836327]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84966', 'POP10': 1086},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.291188189283446, -25.46495049546894],
#        [-49.291221224080175, -25.46312146778149],
#        [-49.28925878646379, -25.46309067319595],
#        [-49.28922573817721, -25.464919700883456],
#        [-49.291188189283446, -25.46495049546894]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84968', 'POP10': 581},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.291221224080175, -25.46312146778149],
#        [-49.291254257977585, -25.461292453583837],
#        [-49.289291833850996, -25.461261658998296],
#        [-49.28925878646379, -25.46309067319595],
#        [-49.291221224080175, -25.46312146778149]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84970', 'POP10': 1243},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.291254257977585, -25.461292453583837],
#        [-49.291287291874994, -25.4594634537753],
#        [-49.28932488123826, -25.459432660089135],
#        [-49.289291833850996, -25.461261658998296],
#        [-49.291254257977585, -25.461292453583837]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54796N84976', 'POP10': 449},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.293315740628884, -25.455836278421486],
#        [-49.2933487592378, -25.45400732178041],
#        [-49.29138638996989, -25.453976541584098],
#        [-49.29135335787112, -25.455805498225118],
#        [-49.293315740628884, -25.455836278421486]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84976', 'POP10': 383},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29135335787112, -25.455805498225118],
#        [-49.29138638996989, -25.453976541584098],
#        [-49.28942402070197, -25.453945748797253],
#        [-49.28939097421403, -25.455774705438273],
#        [-49.29135335787112, -25.455805498225118]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54794N84978', 'POP10': 238},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.295311129405036, -25.454038088486925],
#        [-49.29534413362484, -25.452209145335758],
#        [-49.29338177784672, -25.45217837862924],
#        [-49.2933487592378, -25.45400732178041],
#        [-49.295311129405036, -25.454038088486925]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54796N84978', 'POP10': 308},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2933487592378, -25.45400732178041],
#        [-49.29338177784672, -25.45217837862924],
#        [-49.29141942116934, -25.452147599332193],
#        [-49.29138638996989, -25.453976541584098],
#        [-49.2933487592378, -25.45400732178041]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84978', 'POP10': 632},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29138638996989, -25.453976541584098],
#        [-49.29141942116934, -25.452147599332193],
#        [-49.28945706629054, -25.452116807444668],
#        [-49.28942402070197, -25.453945748797253],
#        [-49.29138638996989, -25.453976541584098]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54794N84980', 'POP10': 242},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29534413362484, -25.452209145335758],
#        [-49.29537713784458, -25.450380216573706],
#        [-49.293414794657, -25.45034945076651],
#        [-49.29338177784672, -25.45217837862924],
#        [-49.29534413362484, -25.452209145335758]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54796N84980', 'POP10': 318},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29338177784672, -25.45217837862924],
#        [-49.293414794657, -25.45034945076651],
#        [-49.29145245236873, -25.45031867146946],
#        [-49.29141942116934, -25.452147599332193],
#        [-49.29338177784672, -25.45217837862924]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84980', 'POP10': 602},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29141942116934, -25.452147599332193],
#        [-49.29145245236873, -25.45031867146946],
#        [-49.289490110979784, -25.450287880481255],
#        [-49.28945706629054, -25.452116807444668],
#        [-49.29141942116934, -25.452147599332193]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54792N84982', 'POP10': 362},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29733948103217, -25.45041096979037],
#        [-49.29737246996348, -25.44858205541749],
#        [-49.295410141165064, -25.44855130220077],
#        [-49.29537713784458, -25.450380216573706],
#        [-49.29733948103217, -25.45041096979037]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54794N84982', 'POP10': 193},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29537713784458, -25.450380216573706],
#        [-49.295410141165064, -25.44855130220077],
#        [-49.293447812366594, -25.448520537292893],
#        [-49.293414794657, -25.45034945076651],
#        [-49.29537713784458, -25.450380216573706]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54796N84982', 'POP10': 148},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.293414794657, -25.45034945076651],
#        [-49.293447812366594, -25.448520537292893],
#        [-49.29148548356818, -25.44848975889522],
#        [-49.29145245236873, -25.45031867146946],
#        [-49.293414794657, -25.45034945076651]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84982', 'POP10': 1180},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29145245236873, -25.45031867146946],
#        [-49.29148548356818, -25.44848975889522],
#        [-49.28952315566903, -25.448458967007696],
#        [-49.289490110979784, -25.450287880481255],
#        [-49.29145245236873, -25.45031867146946]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54794N84984', 'POP10': 279},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.295410141165064, -25.44855130220077],
#        [-49.29544314358617, -25.446722402217063],
#        [-49.29348082827755, -25.446691637309186],
#        [-49.293447812366594, -25.448520537292893],
#        [-49.295410141165064, -25.44855130220077]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54796N84984', 'POP10': 493},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.293447812366594, -25.448520537292893],
#        [-49.29348082827755, -25.446691637309186],
#        [-49.291518513868255, -25.446660859810777],
#        [-49.29148548356818, -25.44848975889522],
#        [-49.293447812366594, -25.448520537292893]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84984', 'POP10': 794},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.29148548356818, -25.44848975889522],
#        [-49.291518513868255, -25.446660859810777],
#        [-49.289556199459014, -25.44663006882257],
#        [-49.28952315566903, -25.448458967007696],
#        [-49.29148548356818, -25.44848975889522]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54798N84986', 'POP10': 862},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.291518513868255, -25.446660859810777],
#        [-49.291551544168385, -25.444831975115505],
#        [-49.28958924324894, -25.4448011841273],
#        [-49.289556199459014, -25.44663006882257],
#        [-49.291518513868255, -25.446660859810777]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84956', 'POP10': 589},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.287097969195884, -25.474034244384825],
#        [-49.28713103367022, -25.47220514565089],
#        [-49.285168527705366, -25.472174322287117],
#        [-49.285135449741176, -25.474003421020996],
#        [-49.287097969195884, -25.474034244384825]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84958', 'POP10': 477},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28713103367022, -25.47220514565089],
#        [-49.28716409724524, -25.470376060406807],
#        [-49.2852016056695, -25.470345237942354],
#        [-49.285168527705366, -25.472174322287117],
#        [-49.28713103367022, -25.47220514565089]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84958', 'POP10': 188},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.285168527705366, -25.472174322287117],
#        [-49.2852016056695, -25.470345237942354],
#        [-49.2832391131945, -25.47031440288731],
#        [-49.283206021740455, -25.47214348723213],
#        [-49.285168527705366, -25.472174322287117]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84960', 'POP10': 374},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2891265897203, -25.470406870280783],
#        [-49.28915963980552, -25.468577799425873],
#        [-49.287197160820256, -25.468546990451216],
#        [-49.28716409724524, -25.470376060406807],
#        [-49.2891265897203, -25.470406870280783]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84960', 'POP10': 229},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28716409724524, -25.470376060406807],
#        [-49.287197160820256, -25.468546990451216],
#        [-49.28523468273437, -25.468516167986706],
#        [-49.2852016056695, -25.470345237942354],
#        [-49.28716409724524, -25.470376060406807]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84960', 'POP10': 57},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2852016056695, -25.470345237942354],
#        [-49.28523468273437, -25.468516167986706],
#        [-49.28327220464848, -25.46848533383104],
#        [-49.2832391131945, -25.47031440288731],
#        [-49.2852016056695, -25.470345237942354]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84960', 'POP10': 154},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2832391131945, -25.47031440288731],
#        [-49.28327220464848, -25.46848533383104],
#        [-49.28130972746192, -25.46845448618552],
#        [-49.28127662251808, -25.47028355524185],
#        [-49.2832391131945, -25.47031440288731]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84962', 'POP10': 417},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28915963980552, -25.468577799425873],
#        [-49.28919268899136, -25.46674874296008],
#        [-49.28723022349595, -25.46671793398542],
#        [-49.287197160820256, -25.468546990451216],
#        [-49.28915963980552, -25.468577799425873]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84962', 'POP10': 301},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.287197160820256, -25.468546990451216],
#        [-49.28723022349595, -25.46671793398542],
#        [-49.28526775889992, -25.46668711242023],
#        [-49.28523468273437, -25.468516167986706],
#        [-49.287197160820256, -25.468546990451216]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84962', 'POP10': 198},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28523468273437, -25.468516167986706],
#        [-49.28526775889992, -25.46668711242023],
#        [-49.28330529520315, -25.466656278264566],
#        [-49.28327220464848, -25.46848533383104],
#        [-49.28523468273437, -25.468516167986706]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84962', 'POP10': 111},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28327220464848, -25.46848533383104],
#        [-49.28330529520315, -25.466656278264566],
#        [-49.281342831506436, -25.466625431518423],
#        [-49.28130972746192, -25.46845448618552],
#        [-49.28327220464848, -25.46848533383104]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84962', 'POP10': 79},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28130972746192, -25.46845448618552],
#        [-49.281342831506436, -25.466625431518423],
#        [-49.279380367809665, -25.46659457128237],
#        [-49.27934725027535, -25.468423625949526],
#        [-49.28130972746192, -25.46845448618552]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84964', 'POP10': 465},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28919268899136, -25.46674874296008],
#        [-49.28922573817721, -25.464919700883456],
#        [-49.28726328617165, -25.46488889280812],
#        [-49.28723022349595, -25.46671793398542],
#        [-49.28919268899136, -25.46674874296008]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84964', 'POP10': 643},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28723022349595, -25.46671793398542],
#        [-49.28726328617165, -25.46488889280812],
#        [-49.28530083506547, -25.46485807124293],
#        [-49.28526775889992, -25.46668711242023],
#        [-49.28723022349595, -25.46671793398542]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84964', 'POP10': 618},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28526775889992, -25.46668711242023],
#        [-49.28530083506547, -25.46485807124293],
#        [-49.28333838485855, -25.464827237986583],
#        [-49.28330529520315, -25.466656278264566],
#        [-49.28526775889992, -25.46668711242023]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84964', 'POP10': 761},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28330529520315, -25.466656278264566],
#        [-49.28333838485855, -25.464827237986583],
#        [-49.281375934651635, -25.46479639124044],
#        [-49.281342831506436, -25.466625431518423],
#        [-49.28330529520315, -25.466656278264566]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84964', 'POP10': 111},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.281342831506436, -25.466625431518423],
#        [-49.281375934651635, -25.46479639124044],
#        [-49.27941348534404, -25.46476553190371],
#        [-49.279380367809665, -25.46659457128237],
#        [-49.281342831506436, -25.466625431518423]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84966', 'POP10': 361},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28922573817721, -25.464919700883456],
#        [-49.28925878646379, -25.46309067319595],
#        [-49.287296348847406, -25.463059865120613],
#        [-49.28726328617165, -25.46488889280812],
#        [-49.28922573817721, -25.464919700883456]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84966', 'POP10': 983},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28726328617165, -25.46488889280812],
#        [-49.287296348847406, -25.463059865120613],
#        [-49.285333911230964, -25.4630290444548],
#        [-49.28530083506547, -25.46485807124293],
#        [-49.28726328617165, -25.46488889280812]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84966', 'POP10': 408},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28530083506547, -25.46485807124293],
#        [-49.285333911230964, -25.4630290444548],
#        [-49.2833714745139, -25.462998211198453],
#        [-49.28333838485855, -25.464827237986583],
#        [-49.28530083506547, -25.46485807124293]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84966', 'POP10': 469},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28333838485855, -25.464827237986583],
#        [-49.2833714745139, -25.462998211198453],
#        [-49.281409038696154, -25.462967365351574],
#        [-49.281375934651635, -25.46479639124044],
#        [-49.28333838485855, -25.464827237986583]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84966', 'POP10': 325},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.281375934651635, -25.46479639124044],
#        [-49.281409038696154, -25.462967365351574],
#        [-49.27944660287835, -25.4629365060149],
#        [-49.27941348534404, -25.46476553190371],
#        [-49.281375934651635, -25.46479639124044]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84968', 'POP10': 815},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28925878646379, -25.46309067319595],
#        [-49.289291833850996, -25.461261658998296],
#        [-49.287329409724464, -25.461230851822336],
#        [-49.287296348847406, -25.463059865120613],
#        [-49.28925878646379, -25.46309067319595]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84968', 'POP10': 785},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.287296348847406, -25.463059865120613],
#        [-49.287329409724464, -25.461230851822336],
#        [-49.285366986497195, -25.461200032055785],
#        [-49.285333911230964, -25.4630290444548],
#        [-49.287296348847406, -25.463059865120613]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84968', 'POP10': 415},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.285333911230964, -25.4630290444548],
#        [-49.285366986497195, -25.461200032055785],
#        [-49.283404564169246, -25.46116919879944],
#        [-49.2833714745139, -25.462998211198453],
#        [-49.285333911230964, -25.4630290444548]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84968', 'POP10': 474},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2833714745139, -25.462998211198453],
#        [-49.283404564169246, -25.46116919879944],
#        [-49.28144214094203, -25.46113835385188],
#        [-49.281409038696154, -25.462967365351574],
#        [-49.2833714745139, -25.462998211198453]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84968', 'POP10': 326},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.281409038696154, -25.462967365351574],
#        [-49.28144214094203, -25.46113835385188],
#        [-49.279479719513404, -25.461107495414524],
#        [-49.27944660287835, -25.4629365060149],
#        [-49.281409038696154, -25.462967365351574]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84970', 'POP10': 924},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.289291833850996, -25.461261658998296],
#        [-49.28932488123826, -25.459432660089135],
#        [-49.28736247150084, -25.459401853812437],
#        [-49.287329409724464, -25.461230851822336],
#        [-49.289291833850996, -25.461261658998296]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84970', 'POP10': 511},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.287329409724464, -25.461230851822336],
#        [-49.28736247150084, -25.459401853812437],
#        [-49.285400061763426, -25.459371034045944],
#        [-49.285366986497195, -25.461200032055785],
#        [-49.287329409724464, -25.461230851822336]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84970', 'POP10': 567},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.285366986497195, -25.461200032055785],
#        [-49.285400061763426, -25.459371034045944],
#        [-49.28343765202595, -25.459340201688917],
#        [-49.283404564169246, -25.46116919879944],
#        [-49.285366986497195, -25.461200032055785]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84970', 'POP10': 502},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.283404564169246, -25.46116919879944],
#        [-49.28343765202595, -25.459340201688917],
#        [-49.281475244087176, -25.459309355842038],
#        [-49.28144214094203, -25.46113835385188],
#        [-49.283404564169246, -25.46116919879944]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84970', 'POP10': 320},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28144214094203, -25.46113835385188],
#        [-49.281475244087176, -25.459309355842038],
#        [-49.27951283524908, -25.459278498304002],
#        [-49.279479719513404, -25.461107495414524],
#        [-49.28144214094203, -25.46113835385188]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84972', 'POP10': 115},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28932488123826, -25.459432660089135],
#        [-49.289357927726144, -25.457603675569146],
#        [-49.28739553147858, -25.45757286929245],
#        [-49.28736247150084, -25.459401853812437],
#        [-49.28932488123826, -25.459432660089135]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84972', 'POP10': 889},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28736247150084, -25.459401853812437],
#        [-49.28739553147858, -25.45757286929245],
#        [-49.28543313613028, -25.457542050425218],
#        [-49.285400061763426, -25.459371034045944],
#        [-49.28736247150084, -25.459401853812437]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84972', 'POP10': 645},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.285400061763426, -25.459371034045944],
#        [-49.28543313613028, -25.457542050425218],
#        [-49.283470740782036, -25.45751121806819],
#        [-49.28343765202595, -25.459340201688917],
#        [-49.285400061763426, -25.459371034045944]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84972', 'POP10': 380},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28343765202595, -25.459340201688917],
#        [-49.283470740782036, -25.45751121806819],
#        [-49.281508345433735, -25.45748037312069],
#        [-49.281475244087176, -25.459309355842038],
#        [-49.28343765202595, -25.459340201688917]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84972', 'POP10': 239},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.281475244087176, -25.459309355842038],
#        [-49.281508345433735, -25.45748037312069],
#        [-49.27954595098481, -25.457449515582653],
#        [-49.27951283524908, -25.459278498304002],
#        [-49.281475244087176, -25.459309355842038]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84974', 'POP10': 545},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.289357927726144, -25.457603675569146],
#        [-49.28939097421403, -25.455774705438273],
#        [-49.28742859235564, -25.455743899161575],
#        [-49.28739553147858, -25.45757286929245],
#        [-49.289357927726144, -25.457603675569146]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84974', 'POP10': 652},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28739553147858, -25.45757286929245],
#        [-49.28742859235564, -25.455743899161575],
#        [-49.28546620959787, -25.4557130802944],
#        [-49.28543313613028, -25.457542050425218],
#        [-49.28739553147858, -25.45757286929245]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84974', 'POP10': 303},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28543313613028, -25.457542050425218],
#        [-49.28546620959787, -25.4557130802944],
#        [-49.28350382863874, -25.455682248836695],
#        [-49.283470740782036, -25.45751121806819],
#        [-49.28543313613028, -25.457542050425218]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84974', 'POP10': 134},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.283470740782036, -25.45751121806819],
#        [-49.28350382863874, -25.455682248836695],
#        [-49.281541446780295, -25.455651404788455],
#        [-49.281508345433735, -25.45748037312069],
#        [-49.283470740782036, -25.45751121806819]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84974', 'POP10': 260},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.281508345433735, -25.45748037312069],
#        [-49.281541446780295, -25.455651404788455],
#        [-49.27957906672049, -25.45562054814974],
#        [-49.27954595098481, -25.457449515582653],
#        [-49.281508345433735, -25.45748037312069]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84976', 'POP10': 625},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28939097421403, -25.455774705438273],
#        [-49.28942402070197, -25.453945748797253],
#        [-49.287461651434, -25.453914943419875],
#        [-49.28742859235564, -25.455743899161575],
#        [-49.28939097421403, -25.455774705438273]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84976', 'POP10': 1716},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28742859235564, -25.455743899161575],
#        [-49.287461651434, -25.453914943419875],
#        [-49.285499283065406, -25.453884125451964],
#        [-49.28546620959787, -25.4557130802944],
#        [-49.28742859235564, -25.455743899161575]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84976', 'POP10': 206},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28546620959787, -25.4557130802944],
#        [-49.285499283065406, -25.453884125451964],
#        [-49.28353691559613, -25.453853294893577],
#        [-49.28350382863874, -25.455682248836695],
#        [-49.28546620959787, -25.4557130802944]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84976', 'POP10': 1},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28350382863874, -25.455682248836695],
#        [-49.28353691559613, -25.453853294893577],
#        [-49.281574548126855, -25.453822450845394],
#        [-49.281541446780295, -25.455651404788455],
#        [-49.28350382863874, -25.455682248836695]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84976', 'POP10': 286},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.281541446780295, -25.455651404788455],
#        [-49.281574548126855, -25.453822450845394],
#        [-49.2796121815569, -25.453791594206677],
#        [-49.27957906672049, -25.45562054814974],
#        [-49.281541446780295, -25.455651404788455]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84978', 'POP10': 1020},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28942402070197, -25.453945748797253],
#        [-49.28945706629054, -25.452116807444668],
#        [-49.28749471051242, -25.45208600296661],
#        [-49.287461651434, -25.453914943419875],
#        [-49.28942402070197, -25.453945748797253]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84978', 'POP10': 1135},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.287461651434, -25.453914943419875],
#        [-49.28749471051242, -25.45208600296661],
#        [-49.285532356533, -25.452055184998756],
#        [-49.285499283065406, -25.453884125451964],
#        [-49.287461651434, -25.453914943419875]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84978', 'POP10': 723},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.285499283065406, -25.453884125451964],
#        [-49.285532356533, -25.452055184998756],
#        [-49.28357000255352, -25.45202435444037],
#        [-49.28353691559613, -25.453853294893577],
#        [-49.285499283065406, -25.453884125451964]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84978', 'POP10': 251},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28353691559613, -25.453853294893577],
#        [-49.28357000255352, -25.45202435444037],
#        [-49.281607648574095, -25.451993511291448],
#        [-49.281574548126855, -25.453822450845394],
#        [-49.28353691559613, -25.453853294893577]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84978', 'POP10': 48},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.281574548126855, -25.453822450845394],
#        [-49.281607648574095, -25.451993511291448],
#        [-49.279645295493935, -25.451962654652732],
#        [-49.2796121815569, -25.453791594206677],
#        [-49.281574548126855, -25.453822450845394]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84980', 'POP10': 619},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28945706629054, -25.452116807444668],
#        [-49.289490110979784, -25.450287880481255],
#        [-49.28752776959084, -25.450257076003197],
#        [-49.28749471051242, -25.45208600296661],
#        [-49.28945706629054, -25.452116807444668]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84980', 'POP10': 314},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28749471051242, -25.45208600296661],
#        [-49.28752776959084, -25.450257076003197],
#        [-49.28556542910121, -25.450226258934663],
#        [-49.285532356533, -25.452055184998756],
#        [-49.28749471051242, -25.45208600296661]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84980', 'POP10': 488},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.285532356533, -25.452055184998756],
#        [-49.28556542910121, -25.450226258934663],
#        [-49.283603088611585, -25.450195428376276],
#        [-49.28357000255352, -25.45202435444037],
#        [-49.285532356533, -25.452055184998756]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84980', 'POP10': 375},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28357000255352, -25.45202435444037],
#        [-49.283603088611585, -25.450195428376276],
#        [-49.281640749021335, -25.450164585227355],
#        [-49.281607648574095, -25.451993511291448],
#        [-49.28357000255352, -25.45202435444037]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84980', 'POP10': 239},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.281607648574095, -25.451993511291448],
#        [-49.281640749021335, -25.450164585227355],
#        [-49.27967840943103, -25.45013372948796],
#        [-49.279645295493935, -25.451962654652732],
#        [-49.281607648574095, -25.451993511291448]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84982', 'POP10': 968},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.289490110979784, -25.450287880481255],
#        [-49.28952315566903, -25.448458967007696],
#        [-49.28756082776994, -25.448428163428957],
#        [-49.28752776959084, -25.450257076003197],
#        [-49.289490110979784, -25.450287880481255]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84982', 'POP10': 890},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28752776959084, -25.450257076003197],
#        [-49.28756082776994, -25.448428163428957],
#        [-49.28559850077016, -25.448397346360423],
#        [-49.28556542910121, -25.450226258934663],
#        [-49.28752776959084, -25.450257076003197]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84982', 'POP10': 401},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28556542910121, -25.450226258934663],
#        [-49.28559850077016, -25.448397346360423],
#        [-49.28363617466971, -25.448366516701356],
#        [-49.283603088611585, -25.450195428376276],
#        [-49.28556542910121, -25.450226258934663]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84982', 'POP10': 433},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.283603088611585, -25.450195428376276],
#        [-49.28363617466971, -25.448366516701356],
#        [-49.2816738485692, -25.448335674451755],
#        [-49.281640749021335, -25.450164585227355],
#        [-49.283603088611585, -25.450195428376276]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84982', 'POP10': 392},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.281640749021335, -25.450164585227355],
#        [-49.2816738485692, -25.448335674451755],
#        [-49.279711522468745, -25.44830481871236],
#        [-49.27967840943103, -25.45013372948796],
#        [-49.281640749021335, -25.450164585227355]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84984', 'POP10': 1007},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28952315566903, -25.448458967007696],
#        [-49.289556199459014, -25.44663006882257],
#        [-49.287593885949036, -25.446599265243833],
#        [-49.28756082776994, -25.448428163428957],
#        [-49.28952315566903, -25.448458967007696]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84984', 'POP10': 560},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28756082776994, -25.448428163428957],
#        [-49.287593885949036, -25.446599265243833],
#        [-49.28563157243906, -25.44656844907462],
#        [-49.28559850077016, -25.448397346360423],
#        [-49.28756082776994, -25.448428163428957]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84984', 'POP10': 474},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28559850077016, -25.448397346360423],
#        [-49.28563157243906, -25.44656844907462],
#        [-49.28366925982846, -25.44653761941555],
#        [-49.28363617466971, -25.448366516701356],
#        [-49.28559850077016, -25.448397346360423]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84984', 'POP10': 474},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28363617466971, -25.448366516701356],
#        [-49.28366925982846, -25.44653761941555],
#        [-49.2817069472178, -25.446506777166007],
#        [-49.2816738485692, -25.448335674451755],
#        [-49.28363617466971, -25.448366516701356]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84984', 'POP10': 320},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2816738485692, -25.448335674451755],
#        [-49.2817069472178, -25.446506777166007],
#        [-49.27974463550646, -25.44647592232593],
#        [-49.279711522468745, -25.44830481871236],
#        [-49.2816738485692, -25.448335674451755]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54800N84986', 'POP10': 838},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.289556199459014, -25.44663006882257],
#        [-49.28958924324894, -25.4448011841273],
#        [-49.287626943228815, -25.44477038144788],
#        [-49.287593885949036, -25.446599265243833],
#        [-49.289556199459014, -25.44663006882257]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54802N84986', 'POP10': 792},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.287593885949036, -25.446599265243833],
#        [-49.287626943228815, -25.44477038144788],
#        [-49.28566464410801, -25.444739565278667],
#        [-49.28563157243906, -25.44656844907462],
#        [-49.287593885949036, -25.446599265243833]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84986', 'POP10': 986},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28563157243906, -25.44656844907462],
#        [-49.28566464410801, -25.444739565278667],
#        [-49.283702344987205, -25.44470873651892],
#        [-49.28366925982846, -25.44653761941555],
#        [-49.28563157243906, -25.44656844907462]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84986', 'POP10': 753},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28366925982846, -25.44653761941555],
#        [-49.283702344987205, -25.44470873651892],
#        [-49.2817400458664, -25.444677895168695],
#        [-49.2817069472178, -25.446506777166007],
#        [-49.28366925982846, -25.44653761941555]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84986', 'POP10': 346},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2817069472178, -25.446506777166007],
#        [-49.2817400458664, -25.444677895168695],
#        [-49.279777747644914, -25.44464704032862],
#        [-49.27974463550646, -25.44647592232593],
#        [-49.2817069472178, -25.446506777166007]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54804N84988', 'POP10': 628},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28566464410801, -25.444739565278667],
#        [-49.285697714877585, -25.442910696771207],
#        [-49.28373542924663, -25.44287986801146],
#        [-49.283702344987205, -25.44470873651892],
#        [-49.28566464410801, -25.444739565278667]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54806N84988', 'POP10': 893},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.283702344987205, -25.44470873651892],
#        [-49.28373542924663, -25.44287986801146],
#        [-49.28177314451494, -25.44284902666118],
#        [-49.2817400458664, -25.444677895168695],
#        [-49.283702344987205, -25.44470873651892]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84988', 'POP10': 910},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2817400458664, -25.444677895168695],
#        [-49.28177314451494, -25.44284902666118],
#        [-49.27981085978331, -25.442818172720422],
#        [-49.279777747644914, -25.44464704032862],
#        [-49.2817400458664, -25.444677895168695]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54808N84990', 'POP10': 967},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.28177314451494, -25.44284902666118],
#        [-49.281806242264224, -25.44102017344221],
#        [-49.27984397192171, -25.440989319501455],
#        [-49.27981085978331, -25.442818172720422],
#        [-49.28177314451494, -25.44284902666118]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84964', 'POP10': 61},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.279380367809665, -25.46659457128237],
#        [-49.27941348534404, -25.46476553190371],
#        [-49.27745103693576, -25.464734659077237],
#        [-49.27741790501227, -25.4665636984559],
#        [-49.279380367809665, -25.46659457128237]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84966', 'POP10': 149},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27941348534404, -25.46476553190371],
#        [-49.27944660287835, -25.4629365060149],
#        [-49.27748416706061, -25.46290563408769],
#        [-49.27745103693576, -25.464734659077237],
#        [-49.27941348534404, -25.46476553190371]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84966', 'POP10': 169},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27745103693576, -25.464734659077237],
#        [-49.27748416706061, -25.46290563408769],
#        [-49.27552173214218, -25.462874749570005],
#        [-49.27548858762816, -25.464703774559496],
#        [-49.27745103693576, -25.464734659077237]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84968', 'POP10': 210},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27944660287835, -25.4629365060149],
#        [-49.279479719513404, -25.461107495414524],
#        [-49.277517298084774, -25.461076623487315],
#        [-49.27748416706061, -25.46290563408769],
#        [-49.27944660287835, -25.4629365060149]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84968', 'POP10': 248},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27748416706061, -25.46290563408769],
#        [-49.277517298084774, -25.461076623487315],
#        [-49.2755548766562, -25.46104573986895],
#        [-49.27552173214218, -25.462874749570005],
#        [-49.27748416706061, -25.46290563408769]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84968', 'POP10': 304},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27552173214218, -25.462874749570005],
#        [-49.2755548766562, -25.46104573986895],
#        [-49.27359245612689, -25.461014842760733],
#        [-49.273559298123075, -25.462843852461788],
#        [-49.27552173214218, -25.462874749570005]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84970', 'POP10': 368},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.279479719513404, -25.461107495414524],
#        [-49.27951283524908, -25.459278498304002],
#        [-49.2775504273103, -25.459247627276113],
#        [-49.277517298084774, -25.461076623487315],
#        [-49.279479719513404, -25.461107495414524]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84970', 'POP10': 217},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.277517298084774, -25.461076623487315],
#        [-49.2775504273103, -25.459247627276113],
#        [-49.2755880202709, -25.45921674365775],
#        [-49.2755548766562, -25.46104573986895],
#        [-49.277517298084774, -25.461076623487315]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84970', 'POP10': 361},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2755548766562, -25.46104573986895],
#        [-49.2755880202709, -25.45921674365775],
#        [-49.273625613231445, -25.45918584744885],
#        [-49.27359245612689, -25.461014842760733],
#        [-49.2755548766562, -25.46104573986895]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54816N84970', 'POP10': 408},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27359245612689, -25.461014842760733],
#        [-49.273625613231445, -25.45918584744885],
#        [-49.27166320709131, -25.459154937750156],
#        [-49.27163003559764, -25.46098393306204],
#        [-49.27359245612689, -25.461014842760733]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54818N84970', 'POP10': 245},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27163003559764, -25.46098393306204],
#        [-49.27166320709131, -25.459154937750156],
#        [-49.26970080095117, -25.459124015460873],
#        [-49.26966761596765, -25.460953009873435],
#        [-49.27163003559764, -25.46098393306204]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84972', 'POP10': 144},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27951283524908, -25.459278498304002],
#        [-49.27954595098481, -25.457449515582653],
#        [-49.27758355743521, -25.457418645454084],
#        [-49.2775504273103, -25.459247627276113],
#        [-49.27951283524908, -25.459278498304002]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84972', 'POP10': 216},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2775504273103, -25.459247627276113],
#        [-49.27758355743521, -25.457418645454084],
#        [-49.275621163885546, -25.45738776183572],
#        [-49.2755880202709, -25.45921674365775],
#        [-49.2775504273103, -25.459247627276113]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84972', 'POP10': 257},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2755880202709, -25.45921674365775],
#        [-49.275621163885546, -25.45738776183572],
#        [-49.27365877033594, -25.45735686562682],
#        [-49.273625613231445, -25.45918584744885],
#        [-49.2755880202709, -25.45921674365775]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54816N84972', 'POP10': 134},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.273625613231445, -25.45918584744885],
#        [-49.27365877033594, -25.45735686562682],
#        [-49.27169637768566, -25.45732595682739],
#        [-49.27166320709131, -25.459154937750156],
#        [-49.273625613231445, -25.45918584744885]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54818N84972', 'POP10': 62},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27166320709131, -25.459154937750156],
#        [-49.27169637768566, -25.45732595682739],
#        [-49.269733985934636, -25.457295035437483],
#        [-49.26970080095117, -25.459124015460873],
#        [-49.27166320709131, -25.459154937750156]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84974', 'POP10': 196},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27954595098481, -25.457449515582653],
#        [-49.27957906672049, -25.45562054814974],
#        [-49.277616685761416, -25.45558967802117],
#        [-49.27758355743521, -25.457418645454084],
#        [-49.27954595098481, -25.457449515582653]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84974', 'POP10': 178},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27758355743521, -25.457418645454084],
#        [-49.277616685761416, -25.45558967802117],
#        [-49.27565430660093, -25.455558795302125],
#        [-49.275621163885546, -25.45738776183572],
#        [-49.27758355743521, -25.457418645454084]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84974', 'POP10': 174},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.275621163885546, -25.45738776183572],
#        [-49.27565430660093, -25.455558795302125],
#        [-49.27369192744044, -25.455527899093227],
#        [-49.27365877033594, -25.45735686562682],
#        [-49.275621163885546, -25.45738776183572]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54816N84974', 'POP10': 129},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27365877033594, -25.45735686562682],
#        [-49.27369192744044, -25.455527899093227],
#        [-49.27172954828001, -25.455496991193172],
#        [-49.27169637768566, -25.45732595682739],
#        [-49.27365877033594, -25.45735686562682]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54818N84974', 'POP10': 135},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27169637768566, -25.45732595682739],
#        [-49.27172954828001, -25.455496991193172],
#        [-49.26976717001884, -25.455466069803208],
#        [-49.269733985934636, -25.457295035437483],
#        [-49.27169637768566, -25.45732595682739]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84976', 'POP10': 96},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27957906672049, -25.45562054814974],
#        [-49.2796121815569, -25.453791594206677],
#        [-49.277649814986944, -25.45376072497743],
#        [-49.277616685761416, -25.45558967802117],
#        [-49.27957906672049, -25.45562054814974]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84976', 'POP10': 127},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.277616685761416, -25.45558967802117],
#        [-49.277649814986944, -25.45376072497743],
#        [-49.27568744841699, -25.453729842258383],
#        [-49.27565430660093, -25.455558795302125],
#        [-49.277616685761416, -25.45558967802117]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84976', 'POP10': 238},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27565430660093, -25.455558795302125],
#        [-49.27568744841699, -25.453729842258383],
#        [-49.27372508274635, -25.453698946948805],
#        [-49.27369192744044, -25.455527899093227],
#        [-49.27565430660093, -25.455558795302125]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54816N84976', 'POP10': 176},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27369192744044, -25.455527899093227],
#        [-49.27372508274635, -25.453698946948805],
#        [-49.27176271797504, -25.453668039048694],
#        [-49.27172954828001, -25.455496991193172],
#        [-49.27369192744044, -25.455527899093227]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54818N84976', 'POP10': 201},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27172954828001, -25.455496991193172],
#        [-49.27176271797504, -25.453668039048694],
#        [-49.26980035320372, -25.453637118558106],
#        [-49.26976717001884, -25.455466069803208],
#        [-49.27172954828001, -25.455496991193172]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84978', 'POP10': 146},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.2796121815569, -25.453791594206677],
#        [-49.279645295493935, -25.451962654652732],
#        [-49.27768294241383, -25.45193178542354],
#        [-49.277649814986944, -25.45376072497743],
#        [-49.2796121815569, -25.453791594206677]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84978', 'POP10': 158},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.277649814986944, -25.45376072497743],
#        [-49.27768294241383, -25.45193178542354],
#        [-49.27572059023299, -25.451900903603757],
#        [-49.27568744841699, -25.453729842258383],
#        [-49.277649814986944, -25.45376072497743]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84978', 'POP10': 267},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27568744841699, -25.453729842258383],
#        [-49.27572059023299, -25.451900903603757],
#        [-49.27375823895153, -25.4518700091935],
#        [-49.27372508274635, -25.453698946948805],
#        [-49.27568744841699, -25.453729842258383]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54816N84978', 'POP10': 132},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27372508274635, -25.453698946948805],
#        [-49.27375823895153, -25.4518700091935],
#        [-49.271795887670066, -25.451839101293444],
#        [-49.27176271797504, -25.453668039048694],
#        [-49.27372508274635, -25.453698946948805]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54818N84978', 'POP10': 180},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27176271797504, -25.453668039048694],
#        [-49.271795887670066, -25.451839101293444],
#        [-49.269833536388546, -25.451808180802857],
#        [-49.26980035320372, -25.453637118558106],
#        [-49.27176271797504, -25.453668039048694]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84980', 'POP10': 297},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.279645295493935, -25.451962654652732],
#        [-49.27967840943103, -25.45013372948796],
#        [-49.27771607074004, -25.450102861158086],
#        [-49.27768294241383, -25.45193178542354],
#        [-49.279645295493935, -25.451962654652732]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84980', 'POP10': 190},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27768294241383, -25.45193178542354],
#        [-49.27771607074004, -25.450102861158086],
#        [-49.275753732049054, -25.450071979338304],
#        [-49.27572059023299, -25.451900903603757],
#        [-49.27768294241383, -25.45193178542354]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84980', 'POP10': 113},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27572059023299, -25.451900903603757],
#        [-49.275753732049054, -25.450071979338304],
#        [-49.27379139425739, -25.450041085827422],
#        [-49.27375823895153, -25.4518700091935],
#        [-49.27572059023299, -25.451900903603757]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54816N84980', 'POP10': 294},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27375823895153, -25.4518700091935],
#        [-49.27379139425739, -25.450041085827422],
#        [-49.27182905646572, -25.45001017792731],
#        [-49.271795887670066, -25.451839101293444],
#        [-49.27375823895153, -25.4518700091935]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54818N84980', 'POP10': 167},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.271795887670066, -25.451839101293444],
#        [-49.27182905646572, -25.45001017792731],
#        [-49.26986671957343, -25.449979258336043],
#        [-49.269833536388546, -25.451808180802857],
#        [-49.271795887670066, -25.451839101293444]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84982', 'POP10': 337},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27967840943103, -25.45013372948796],
#        [-49.279711522468745, -25.44830481871236],
#        [-49.27774919726761, -25.448273951281806],
#        [-49.27771607074004, -25.450102861158086],
#        [-49.27967840943103, -25.45013372948796]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84982', 'POP10': 237},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27771607074004, -25.450102861158086],
#        [-49.27774919726761, -25.448273951281806],
#        [-49.275786872965796, -25.448243070361343],
#        [-49.275753732049054, -25.450071979338304],
#        [-49.27771607074004, -25.450102861158086]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84982', 'POP10': 250},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.275753732049054, -25.450071979338304],
#        [-49.275786872965796, -25.448243070361343],
#        [-49.273824548663924, -25.44821217595114],
#        [-49.27379139425739, -25.450041085827422],
#        [-49.275753732049054, -25.450071979338304]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54816N84982', 'POP10': 100},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27379139425739, -25.450041085827422],
#        [-49.273824548663924, -25.44821217595114],
#        [-49.27186222436211, -25.44818126984967],
#        [-49.27182905646572, -25.45001017792731],
#        [-49.27379139425739, -25.450041085827422]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84984', 'POP10': 302},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.279711522468745, -25.44830481871236],
#        [-49.27974463550646, -25.44647592232593],
#        [-49.27778232379518, -25.44644505489532],
#        [-49.27774919726761, -25.448273951281806],
#        [-49.279711522468745, -25.44830481871236]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84984', 'POP10': 255},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27774919726761, -25.448273951281806],
#        [-49.27778232379518, -25.44644505489532],
#        [-49.27582001298316, -25.446414174874235],
#        [-49.275786872965796, -25.448243070361343],
#        [-49.27774919726761, -25.448273951281806]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84984', 'POP10': 73},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.275786872965796, -25.448243070361343],
#        [-49.27582001298316, -25.446414174874235],
#        [-49.27385770307052, -25.446383281363296],
#        [-49.273824548663924, -25.44821217595114],
#        [-49.275786872965796, -25.448243070361343]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54816N84984', 'POP10': 297},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.273824548663924, -25.44821217595114],
#        [-49.27385770307052, -25.446383281363296],
#        [-49.2718953922585, -25.44635237526188],
#        [-49.27186222436211, -25.44818126984967],
#        [-49.273824548663924, -25.44821217595114]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84986', 'POP10': 340},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27974463550646, -25.44647592232593],
#        [-49.279777747644914, -25.44464704032862],
#        [-49.27781545032275, -25.44461617379733],
#        [-49.27778232379518, -25.44644505489532],
#        [-49.27974463550646, -25.44647592232593]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84986', 'POP10': 257},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27778232379518, -25.44644505489532],
#        [-49.27781545032275, -25.44461617379733],
#        [-49.27585315300058, -25.444585293776242],
#        [-49.27582001298316, -25.446414174874235],
#        [-49.27778232379518, -25.44644505489532]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84986', 'POP10': 52},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27582001298316, -25.446414174874235],
#        [-49.27585315300058, -25.444585293776242],
#        [-49.27389085657774, -25.444554400265304],
#        [-49.27385770307052, -25.446383281363296],
#        [-49.27582001298316, -25.446414174874235]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84988', 'POP10': 1054},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.279777747644914, -25.44464704032862],
#        [-49.27981085978331, -25.442818172720422],
#        [-49.277848575951, -25.44278730618919],
#        [-49.27781545032275, -25.44461617379733],
#        [-49.279777747644914, -25.44464704032862]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84988', 'POP10': 469},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27781545032275, -25.44461617379733],
#        [-49.277848575951, -25.44278730618919],
#        [-49.27588629301795, -25.442756427067422],
#        [-49.27585315300058, -25.444585293776242],
#        [-49.27781545032275, -25.44461617379733]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84988', 'POP10': 322},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27585315300058, -25.444585293776242],
#        [-49.27588629301795, -25.442756427067422],
#        [-49.273924010084954, -25.442725534455803],
#        [-49.27389085657774, -25.444554400265304],
#        [-49.27585315300058, -25.444585293776242]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54810N84990', 'POP10': 683},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27981085978331, -25.442818172720422],
#        [-49.27984397192171, -25.440989319501455],
#        [-49.27788170157925, -25.440958453869484],
#        [-49.277848575951, -25.44278730618919],
#        [-49.27981085978331, -25.442818172720422]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54812N84990', 'POP10': 973},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.277848575951, -25.44278730618919],
#        [-49.27788170157925, -25.440958453869484],
#        [-49.27591943213605, -25.440927574747718],
#        [-49.27588629301795, -25.442756427067422],
#        [-49.277848575951, -25.44278730618919]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54814N84990', 'POP10': 1389},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.27588629301795, -25.442756427067422],
#        [-49.27591943213605, -25.440927574747718],
#        [-49.27395716269285, -25.4408966821361],
#        [-49.273924010084954, -25.442725534455803],
#        [-49.27588629301795, -25.442756427067422]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54820N84972', 'POP10': 269},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.26970080095117, -25.459124015460873],
#        [-49.269733985934636, -25.457295035437483],
#        [-49.26777159418367, -25.457264100557722],
#        [-49.26773839571035, -25.45909308058117],
#        [-49.26970080095117, -25.459124015460873]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME54820N84974', 'POP10': 441},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-49.269733985934636, -25.457295035437483],
#        [-49.26976717001884, -25.455466069803208],
#        [-49.26780479175767, -25.455435135822825],
#        [-49.26777159418367, -25.457264100557722],
#        [-49.269733985934636, -25.457295035437483]]]]}}]}

# %%
# Count the total number of grid cells in GeoJSON
total_cells = len(grid['features'])
print(f"Total grid cells in GeoJSON: {total_cells}")
# Out:
# Total grid cells in GeoJSON: 154

# %%
# Partition the original GeoJSON grid into subsets of up to 4 cells each

# Number of cells per batch
subset_size = 4

# Split the original grid cells into subsets
subsets = [grid['features'][i:i + subset_size] for i in range(0, len(grid['features']), subset_size)]

# Create a new FeatureCollection structure for each subset and add a batch ID ("lote_id")
grid_subsets = []
for index, subset in enumerate(subsets):
    grid_subset = {
        'type': 'FeatureCollection',
        'features': subset,
        'lote_id': f"lote{index + 1}",
        'crs': grid['crs']
    }
    grid_subsets.append(grid_subset)

# %%
# Calcular e imprimir o total de subsets criados
total_subsets = len(grid_subsets)
print(f"Total de subsets criados: {total_subsets}")
# Out:
# Total de subsets criados: 39

# %%
# Check the subsets
grid_subsets
# Out:
# [{'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54798N84962', 'POP10': 834},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.291122118790724, -25.468608595809997],
#         [-49.29115515448677, -25.466779538444882],
#         [-49.28919268899136, -25.46674874296008],
#         [-49.28915963980552, -25.468577799425873],
#         [-49.291122118790724, -25.468608595809997]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54796N84964', 'POP10': 475},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.293117620881446, -25.46681032133921],
#         [-49.29315064218832, -25.46498127836327],
#         [-49.291188189283446, -25.46495049546894],
#         [-49.29115515448677, -25.466779538444882],
#         [-49.293117620881446, -25.46681032133921]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54798N84964', 'POP10': 368},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29115515448677, -25.466779538444882],
#         [-49.291188189283446, -25.46495049546894],
#         [-49.28922573817721, -25.464919700883456],
#         [-49.28919268899136, -25.46674874296008],
#         [-49.29115515448677, -25.466779538444882]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54796N84966', 'POP10': 218},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29315064218832, -25.46498127836327],
#         [-49.293183662595936, -25.463152249776442],
#         [-49.291221224080175, -25.46312146778149],
#         [-49.291188189283446, -25.46495049546894],
#         [-49.29315064218832, -25.46498127836327]]]]}}],
#   'lote_id': 'lote1',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54798N84966', 'POP10': 1086},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.291188189283446, -25.46495049546894],
#         [-49.291221224080175, -25.46312146778149],
#         [-49.28925878646379, -25.46309067319595],
#         [-49.28922573817721, -25.464919700883456],
#         [-49.291188189283446, -25.46495049546894]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54798N84968', 'POP10': 581},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.291221224080175, -25.46312146778149],
#         [-49.291254257977585, -25.461292453583837],
#         [-49.289291833850996, -25.461261658998296],
#         [-49.28925878646379, -25.46309067319595],
#         [-49.291221224080175, -25.46312146778149]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54798N84970', 'POP10': 1243},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.291254257977585, -25.461292453583837],
#         [-49.291287291874994, -25.4594634537753],
#         [-49.28932488123826, -25.459432660089135],
#         [-49.289291833850996, -25.461261658998296],
#         [-49.291254257977585, -25.461292453583837]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54796N84976', 'POP10': 449},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.293315740628884, -25.455836278421486],
#         [-49.2933487592378, -25.45400732178041],
#         [-49.29138638996989, -25.453976541584098],
#         [-49.29135335787112, -25.455805498225118],
#         [-49.293315740628884, -25.455836278421486]]]]}}],
#   'lote_id': 'lote2',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54798N84976', 'POP10': 383},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29135335787112, -25.455805498225118],
#         [-49.29138638996989, -25.453976541584098],
#         [-49.28942402070197, -25.453945748797253],
#         [-49.28939097421403, -25.455774705438273],
#         [-49.29135335787112, -25.455805498225118]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54794N84978', 'POP10': 238},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.295311129405036, -25.454038088486925],
#         [-49.29534413362484, -25.452209145335758],
#         [-49.29338177784672, -25.45217837862924],
#         [-49.2933487592378, -25.45400732178041],
#         [-49.295311129405036, -25.454038088486925]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54796N84978', 'POP10': 308},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2933487592378, -25.45400732178041],
#         [-49.29338177784672, -25.45217837862924],
#         [-49.29141942116934, -25.452147599332193],
#         [-49.29138638996989, -25.453976541584098],
#         [-49.2933487592378, -25.45400732178041]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54798N84978', 'POP10': 632},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29138638996989, -25.453976541584098],
#         [-49.29141942116934, -25.452147599332193],
#         [-49.28945706629054, -25.452116807444668],
#         [-49.28942402070197, -25.453945748797253],
#         [-49.29138638996989, -25.453976541584098]]]]}}],
#   'lote_id': 'lote3',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54794N84980', 'POP10': 242},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29534413362484, -25.452209145335758],
#         [-49.29537713784458, -25.450380216573706],
#         [-49.293414794657, -25.45034945076651],
#         [-49.29338177784672, -25.45217837862924],
#         [-49.29534413362484, -25.452209145335758]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54796N84980', 'POP10': 318},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29338177784672, -25.45217837862924],
#         [-49.293414794657, -25.45034945076651],
#         [-49.29145245236873, -25.45031867146946],
#         [-49.29141942116934, -25.452147599332193],
#         [-49.29338177784672, -25.45217837862924]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54798N84980', 'POP10': 602},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29141942116934, -25.452147599332193],
#         [-49.29145245236873, -25.45031867146946],
#         [-49.289490110979784, -25.450287880481255],
#         [-49.28945706629054, -25.452116807444668],
#         [-49.29141942116934, -25.452147599332193]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54792N84982', 'POP10': 362},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29733948103217, -25.45041096979037],
#         [-49.29737246996348, -25.44858205541749],
#         [-49.295410141165064, -25.44855130220077],
#         [-49.29537713784458, -25.450380216573706],
#         [-49.29733948103217, -25.45041096979037]]]]}}],
#   'lote_id': 'lote4',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54794N84982', 'POP10': 193},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29537713784458, -25.450380216573706],
#         [-49.295410141165064, -25.44855130220077],
#         [-49.293447812366594, -25.448520537292893],
#         [-49.293414794657, -25.45034945076651],
#         [-49.29537713784458, -25.450380216573706]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54796N84982', 'POP10': 148},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.293414794657, -25.45034945076651],
#         [-49.293447812366594, -25.448520537292893],
#         [-49.29148548356818, -25.44848975889522],
#         [-49.29145245236873, -25.45031867146946],
#         [-49.293414794657, -25.45034945076651]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54798N84982', 'POP10': 1180},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29145245236873, -25.45031867146946],
#         [-49.29148548356818, -25.44848975889522],
#         [-49.28952315566903, -25.448458967007696],
#         [-49.289490110979784, -25.450287880481255],
#         [-49.29145245236873, -25.45031867146946]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54794N84984', 'POP10': 279},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.295410141165064, -25.44855130220077],
#         [-49.29544314358617, -25.446722402217063],
#         [-49.29348082827755, -25.446691637309186],
#         [-49.293447812366594, -25.448520537292893],
#         [-49.295410141165064, -25.44855130220077]]]]}}],
#   'lote_id': 'lote5',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54796N84984', 'POP10': 493},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.293447812366594, -25.448520537292893],
#         [-49.29348082827755, -25.446691637309186],
#         [-49.291518513868255, -25.446660859810777],
#         [-49.29148548356818, -25.44848975889522],
#         [-49.293447812366594, -25.448520537292893]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54798N84984', 'POP10': 794},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.29148548356818, -25.44848975889522],
#         [-49.291518513868255, -25.446660859810777],
#         [-49.289556199459014, -25.44663006882257],
#         [-49.28952315566903, -25.448458967007696],
#         [-49.29148548356818, -25.44848975889522]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54798N84986', 'POP10': 862},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.291518513868255, -25.446660859810777],
#         [-49.291551544168385, -25.444831975115505],
#         [-49.28958924324894, -25.4448011841273],
#         [-49.289556199459014, -25.44663006882257],
#         [-49.291518513868255, -25.446660859810777]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84956', 'POP10': 589},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.287097969195884, -25.474034244384825],
#         [-49.28713103367022, -25.47220514565089],
#         [-49.285168527705366, -25.472174322287117],
#         [-49.285135449741176, -25.474003421020996],
#         [-49.287097969195884, -25.474034244384825]]]]}}],
#   'lote_id': 'lote6',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54802N84958', 'POP10': 477},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28713103367022, -25.47220514565089],
#         [-49.28716409724524, -25.470376060406807],
#         [-49.2852016056695, -25.470345237942354],
#         [-49.285168527705366, -25.472174322287117],
#         [-49.28713103367022, -25.47220514565089]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84958', 'POP10': 188},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.285168527705366, -25.472174322287117],
#         [-49.2852016056695, -25.470345237942354],
#         [-49.2832391131945, -25.47031440288731],
#         [-49.283206021740455, -25.47214348723213],
#         [-49.285168527705366, -25.472174322287117]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84960', 'POP10': 374},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2891265897203, -25.470406870280783],
#         [-49.28915963980552, -25.468577799425873],
#         [-49.287197160820256, -25.468546990451216],
#         [-49.28716409724524, -25.470376060406807],
#         [-49.2891265897203, -25.470406870280783]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84960', 'POP10': 229},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28716409724524, -25.470376060406807],
#         [-49.287197160820256, -25.468546990451216],
#         [-49.28523468273437, -25.468516167986706],
#         [-49.2852016056695, -25.470345237942354],
#         [-49.28716409724524, -25.470376060406807]]]]}}],
#   'lote_id': 'lote7',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54804N84960', 'POP10': 57},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2852016056695, -25.470345237942354],
#         [-49.28523468273437, -25.468516167986706],
#         [-49.28327220464848, -25.46848533383104],
#         [-49.2832391131945, -25.47031440288731],
#         [-49.2852016056695, -25.470345237942354]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84960', 'POP10': 154},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2832391131945, -25.47031440288731],
#         [-49.28327220464848, -25.46848533383104],
#         [-49.28130972746192, -25.46845448618552],
#         [-49.28127662251808, -25.47028355524185],
#         [-49.2832391131945, -25.47031440288731]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84962', 'POP10': 417},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28915963980552, -25.468577799425873],
#         [-49.28919268899136, -25.46674874296008],
#         [-49.28723022349595, -25.46671793398542],
#         [-49.287197160820256, -25.468546990451216],
#         [-49.28915963980552, -25.468577799425873]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84962', 'POP10': 301},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.287197160820256, -25.468546990451216],
#         [-49.28723022349595, -25.46671793398542],
#         [-49.28526775889992, -25.46668711242023],
#         [-49.28523468273437, -25.468516167986706],
#         [-49.287197160820256, -25.468546990451216]]]]}}],
#   'lote_id': 'lote8',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54804N84962', 'POP10': 198},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28523468273437, -25.468516167986706],
#         [-49.28526775889992, -25.46668711242023],
#         [-49.28330529520315, -25.466656278264566],
#         [-49.28327220464848, -25.46848533383104],
#         [-49.28523468273437, -25.468516167986706]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84962', 'POP10': 111},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28327220464848, -25.46848533383104],
#         [-49.28330529520315, -25.466656278264566],
#         [-49.281342831506436, -25.466625431518423],
#         [-49.28130972746192, -25.46845448618552],
#         [-49.28327220464848, -25.46848533383104]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84962', 'POP10': 79},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28130972746192, -25.46845448618552],
#         [-49.281342831506436, -25.466625431518423],
#         [-49.279380367809665, -25.46659457128237],
#         [-49.27934725027535, -25.468423625949526],
#         [-49.28130972746192, -25.46845448618552]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84964', 'POP10': 465},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28919268899136, -25.46674874296008],
#         [-49.28922573817721, -25.464919700883456],
#         [-49.28726328617165, -25.46488889280812],
#         [-49.28723022349595, -25.46671793398542],
#         [-49.28919268899136, -25.46674874296008]]]]}}],
#   'lote_id': 'lote9',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54802N84964', 'POP10': 643},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28723022349595, -25.46671793398542],
#         [-49.28726328617165, -25.46488889280812],
#         [-49.28530083506547, -25.46485807124293],
#         [-49.28526775889992, -25.46668711242023],
#         [-49.28723022349595, -25.46671793398542]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84964', 'POP10': 618},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28526775889992, -25.46668711242023],
#         [-49.28530083506547, -25.46485807124293],
#         [-49.28333838485855, -25.464827237986583],
#         [-49.28330529520315, -25.466656278264566],
#         [-49.28526775889992, -25.46668711242023]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84964', 'POP10': 761},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28330529520315, -25.466656278264566],
#         [-49.28333838485855, -25.464827237986583],
#         [-49.281375934651635, -25.46479639124044],
#         [-49.281342831506436, -25.466625431518423],
#         [-49.28330529520315, -25.466656278264566]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84964', 'POP10': 111},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.281342831506436, -25.466625431518423],
#         [-49.281375934651635, -25.46479639124044],
#         [-49.27941348534404, -25.46476553190371],
#         [-49.279380367809665, -25.46659457128237],
#         [-49.281342831506436, -25.466625431518423]]]]}}],
#   'lote_id': 'lote10',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54800N84966', 'POP10': 361},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28922573817721, -25.464919700883456],
#         [-49.28925878646379, -25.46309067319595],
#         [-49.287296348847406, -25.463059865120613],
#         [-49.28726328617165, -25.46488889280812],
#         [-49.28922573817721, -25.464919700883456]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84966', 'POP10': 983},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28726328617165, -25.46488889280812],
#         [-49.287296348847406, -25.463059865120613],
#         [-49.285333911230964, -25.4630290444548],
#         [-49.28530083506547, -25.46485807124293],
#         [-49.28726328617165, -25.46488889280812]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84966', 'POP10': 408},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28530083506547, -25.46485807124293],
#         [-49.285333911230964, -25.4630290444548],
#         [-49.2833714745139, -25.462998211198453],
#         [-49.28333838485855, -25.464827237986583],
#         [-49.28530083506547, -25.46485807124293]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84966', 'POP10': 469},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28333838485855, -25.464827237986583],
#         [-49.2833714745139, -25.462998211198453],
#         [-49.281409038696154, -25.462967365351574],
#         [-49.281375934651635, -25.46479639124044],
#         [-49.28333838485855, -25.464827237986583]]]]}}],
#   'lote_id': 'lote11',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54808N84966', 'POP10': 325},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.281375934651635, -25.46479639124044],
#         [-49.281409038696154, -25.462967365351574],
#         [-49.27944660287835, -25.4629365060149],
#         [-49.27941348534404, -25.46476553190371],
#         [-49.281375934651635, -25.46479639124044]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84968', 'POP10': 815},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28925878646379, -25.46309067319595],
#         [-49.289291833850996, -25.461261658998296],
#         [-49.287329409724464, -25.461230851822336],
#         [-49.287296348847406, -25.463059865120613],
#         [-49.28925878646379, -25.46309067319595]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84968', 'POP10': 785},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.287296348847406, -25.463059865120613],
#         [-49.287329409724464, -25.461230851822336],
#         [-49.285366986497195, -25.461200032055785],
#         [-49.285333911230964, -25.4630290444548],
#         [-49.287296348847406, -25.463059865120613]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84968', 'POP10': 415},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.285333911230964, -25.4630290444548],
#         [-49.285366986497195, -25.461200032055785],
#         [-49.283404564169246, -25.46116919879944],
#         [-49.2833714745139, -25.462998211198453],
#         [-49.285333911230964, -25.4630290444548]]]]}}],
#   'lote_id': 'lote12',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54806N84968', 'POP10': 474},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2833714745139, -25.462998211198453],
#         [-49.283404564169246, -25.46116919879944],
#         [-49.28144214094203, -25.46113835385188],
#         [-49.281409038696154, -25.462967365351574],
#         [-49.2833714745139, -25.462998211198453]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84968', 'POP10': 326},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.281409038696154, -25.462967365351574],
#         [-49.28144214094203, -25.46113835385188],
#         [-49.279479719513404, -25.461107495414524],
#         [-49.27944660287835, -25.4629365060149],
#         [-49.281409038696154, -25.462967365351574]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84970', 'POP10': 924},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.289291833850996, -25.461261658998296],
#         [-49.28932488123826, -25.459432660089135],
#         [-49.28736247150084, -25.459401853812437],
#         [-49.287329409724464, -25.461230851822336],
#         [-49.289291833850996, -25.461261658998296]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84970', 'POP10': 511},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.287329409724464, -25.461230851822336],
#         [-49.28736247150084, -25.459401853812437],
#         [-49.285400061763426, -25.459371034045944],
#         [-49.285366986497195, -25.461200032055785],
#         [-49.287329409724464, -25.461230851822336]]]]}}],
#   'lote_id': 'lote13',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54804N84970', 'POP10': 567},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.285366986497195, -25.461200032055785],
#         [-49.285400061763426, -25.459371034045944],
#         [-49.28343765202595, -25.459340201688917],
#         [-49.283404564169246, -25.46116919879944],
#         [-49.285366986497195, -25.461200032055785]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84970', 'POP10': 502},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.283404564169246, -25.46116919879944],
#         [-49.28343765202595, -25.459340201688917],
#         [-49.281475244087176, -25.459309355842038],
#         [-49.28144214094203, -25.46113835385188],
#         [-49.283404564169246, -25.46116919879944]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84970', 'POP10': 320},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28144214094203, -25.46113835385188],
#         [-49.281475244087176, -25.459309355842038],
#         [-49.27951283524908, -25.459278498304002],
#         [-49.279479719513404, -25.461107495414524],
#         [-49.28144214094203, -25.46113835385188]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84972', 'POP10': 115},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28932488123826, -25.459432660089135],
#         [-49.289357927726144, -25.457603675569146],
#         [-49.28739553147858, -25.45757286929245],
#         [-49.28736247150084, -25.459401853812437],
#         [-49.28932488123826, -25.459432660089135]]]]}}],
#   'lote_id': 'lote14',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54802N84972', 'POP10': 889},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28736247150084, -25.459401853812437],
#         [-49.28739553147858, -25.45757286929245],
#         [-49.28543313613028, -25.457542050425218],
#         [-49.285400061763426, -25.459371034045944],
#         [-49.28736247150084, -25.459401853812437]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84972', 'POP10': 645},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.285400061763426, -25.459371034045944],
#         [-49.28543313613028, -25.457542050425218],
#         [-49.283470740782036, -25.45751121806819],
#         [-49.28343765202595, -25.459340201688917],
#         [-49.285400061763426, -25.459371034045944]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84972', 'POP10': 380},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28343765202595, -25.459340201688917],
#         [-49.283470740782036, -25.45751121806819],
#         [-49.281508345433735, -25.45748037312069],
#         [-49.281475244087176, -25.459309355842038],
#         [-49.28343765202595, -25.459340201688917]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84972', 'POP10': 239},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.281475244087176, -25.459309355842038],
#         [-49.281508345433735, -25.45748037312069],
#         [-49.27954595098481, -25.457449515582653],
#         [-49.27951283524908, -25.459278498304002],
#         [-49.281475244087176, -25.459309355842038]]]]}}],
#   'lote_id': 'lote15',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54800N84974', 'POP10': 545},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.289357927726144, -25.457603675569146],
#         [-49.28939097421403, -25.455774705438273],
#         [-49.28742859235564, -25.455743899161575],
#         [-49.28739553147858, -25.45757286929245],
#         [-49.289357927726144, -25.457603675569146]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84974', 'POP10': 652},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28739553147858, -25.45757286929245],
#         [-49.28742859235564, -25.455743899161575],
#         [-49.28546620959787, -25.4557130802944],
#         [-49.28543313613028, -25.457542050425218],
#         [-49.28739553147858, -25.45757286929245]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84974', 'POP10': 303},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28543313613028, -25.457542050425218],
#         [-49.28546620959787, -25.4557130802944],
#         [-49.28350382863874, -25.455682248836695],
#         [-49.283470740782036, -25.45751121806819],
#         [-49.28543313613028, -25.457542050425218]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84974', 'POP10': 134},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.283470740782036, -25.45751121806819],
#         [-49.28350382863874, -25.455682248836695],
#         [-49.281541446780295, -25.455651404788455],
#         [-49.281508345433735, -25.45748037312069],
#         [-49.283470740782036, -25.45751121806819]]]]}}],
#   'lote_id': 'lote16',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54808N84974', 'POP10': 260},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.281508345433735, -25.45748037312069],
#         [-49.281541446780295, -25.455651404788455],
#         [-49.27957906672049, -25.45562054814974],
#         [-49.27954595098481, -25.457449515582653],
#         [-49.281508345433735, -25.45748037312069]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84976', 'POP10': 625},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28939097421403, -25.455774705438273],
#         [-49.28942402070197, -25.453945748797253],
#         [-49.287461651434, -25.453914943419875],
#         [-49.28742859235564, -25.455743899161575],
#         [-49.28939097421403, -25.455774705438273]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84976', 'POP10': 1716},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28742859235564, -25.455743899161575],
#         [-49.287461651434, -25.453914943419875],
#         [-49.285499283065406, -25.453884125451964],
#         [-49.28546620959787, -25.4557130802944],
#         [-49.28742859235564, -25.455743899161575]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84976', 'POP10': 206},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28546620959787, -25.4557130802944],
#         [-49.285499283065406, -25.453884125451964],
#         [-49.28353691559613, -25.453853294893577],
#         [-49.28350382863874, -25.455682248836695],
#         [-49.28546620959787, -25.4557130802944]]]]}}],
#   'lote_id': 'lote17',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54806N84976', 'POP10': 1},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28350382863874, -25.455682248836695],
#         [-49.28353691559613, -25.453853294893577],
#         [-49.281574548126855, -25.453822450845394],
#         [-49.281541446780295, -25.455651404788455],
#         [-49.28350382863874, -25.455682248836695]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84976', 'POP10': 286},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.281541446780295, -25.455651404788455],
#         [-49.281574548126855, -25.453822450845394],
#         [-49.2796121815569, -25.453791594206677],
#         [-49.27957906672049, -25.45562054814974],
#         [-49.281541446780295, -25.455651404788455]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84978', 'POP10': 1020},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28942402070197, -25.453945748797253],
#         [-49.28945706629054, -25.452116807444668],
#         [-49.28749471051242, -25.45208600296661],
#         [-49.287461651434, -25.453914943419875],
#         [-49.28942402070197, -25.453945748797253]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84978', 'POP10': 1135},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.287461651434, -25.453914943419875],
#         [-49.28749471051242, -25.45208600296661],
#         [-49.285532356533, -25.452055184998756],
#         [-49.285499283065406, -25.453884125451964],
#         [-49.287461651434, -25.453914943419875]]]]}}],
#   'lote_id': 'lote18',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54804N84978', 'POP10': 723},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.285499283065406, -25.453884125451964],
#         [-49.285532356533, -25.452055184998756],
#         [-49.28357000255352, -25.45202435444037],
#         [-49.28353691559613, -25.453853294893577],
#         [-49.285499283065406, -25.453884125451964]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84978', 'POP10': 251},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28353691559613, -25.453853294893577],
#         [-49.28357000255352, -25.45202435444037],
#         [-49.281607648574095, -25.451993511291448],
#         [-49.281574548126855, -25.453822450845394],
#         [-49.28353691559613, -25.453853294893577]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84978', 'POP10': 48},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.281574548126855, -25.453822450845394],
#         [-49.281607648574095, -25.451993511291448],
#         [-49.279645295493935, -25.451962654652732],
#         [-49.2796121815569, -25.453791594206677],
#         [-49.281574548126855, -25.453822450845394]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84980', 'POP10': 619},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28945706629054, -25.452116807444668],
#         [-49.289490110979784, -25.450287880481255],
#         [-49.28752776959084, -25.450257076003197],
#         [-49.28749471051242, -25.45208600296661],
#         [-49.28945706629054, -25.452116807444668]]]]}}],
#   'lote_id': 'lote19',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54802N84980', 'POP10': 314},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28749471051242, -25.45208600296661],
#         [-49.28752776959084, -25.450257076003197],
#         [-49.28556542910121, -25.450226258934663],
#         [-49.285532356533, -25.452055184998756],
#         [-49.28749471051242, -25.45208600296661]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84980', 'POP10': 488},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.285532356533, -25.452055184998756],
#         [-49.28556542910121, -25.450226258934663],
#         [-49.283603088611585, -25.450195428376276],
#         [-49.28357000255352, -25.45202435444037],
#         [-49.285532356533, -25.452055184998756]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84980', 'POP10': 375},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28357000255352, -25.45202435444037],
#         [-49.283603088611585, -25.450195428376276],
#         [-49.281640749021335, -25.450164585227355],
#         [-49.281607648574095, -25.451993511291448],
#         [-49.28357000255352, -25.45202435444037]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84980', 'POP10': 239},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.281607648574095, -25.451993511291448],
#         [-49.281640749021335, -25.450164585227355],
#         [-49.27967840943103, -25.45013372948796],
#         [-49.279645295493935, -25.451962654652732],
#         [-49.281607648574095, -25.451993511291448]]]]}}],
#   'lote_id': 'lote20',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54800N84982', 'POP10': 968},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.289490110979784, -25.450287880481255],
#         [-49.28952315566903, -25.448458967007696],
#         [-49.28756082776994, -25.448428163428957],
#         [-49.28752776959084, -25.450257076003197],
#         [-49.289490110979784, -25.450287880481255]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84982', 'POP10': 890},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28752776959084, -25.450257076003197],
#         [-49.28756082776994, -25.448428163428957],
#         [-49.28559850077016, -25.448397346360423],
#         [-49.28556542910121, -25.450226258934663],
#         [-49.28752776959084, -25.450257076003197]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84982', 'POP10': 401},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28556542910121, -25.450226258934663],
#         [-49.28559850077016, -25.448397346360423],
#         [-49.28363617466971, -25.448366516701356],
#         [-49.283603088611585, -25.450195428376276],
#         [-49.28556542910121, -25.450226258934663]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84982', 'POP10': 433},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.283603088611585, -25.450195428376276],
#         [-49.28363617466971, -25.448366516701356],
#         [-49.2816738485692, -25.448335674451755],
#         [-49.281640749021335, -25.450164585227355],
#         [-49.283603088611585, -25.450195428376276]]]]}}],
#   'lote_id': 'lote21',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54808N84982', 'POP10': 392},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.281640749021335, -25.450164585227355],
#         [-49.2816738485692, -25.448335674451755],
#         [-49.279711522468745, -25.44830481871236],
#         [-49.27967840943103, -25.45013372948796],
#         [-49.281640749021335, -25.450164585227355]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84984', 'POP10': 1007},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28952315566903, -25.448458967007696],
#         [-49.289556199459014, -25.44663006882257],
#         [-49.287593885949036, -25.446599265243833],
#         [-49.28756082776994, -25.448428163428957],
#         [-49.28952315566903, -25.448458967007696]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84984', 'POP10': 560},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28756082776994, -25.448428163428957],
#         [-49.287593885949036, -25.446599265243833],
#         [-49.28563157243906, -25.44656844907462],
#         [-49.28559850077016, -25.448397346360423],
#         [-49.28756082776994, -25.448428163428957]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84984', 'POP10': 474},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28559850077016, -25.448397346360423],
#         [-49.28563157243906, -25.44656844907462],
#         [-49.28366925982846, -25.44653761941555],
#         [-49.28363617466971, -25.448366516701356],
#         [-49.28559850077016, -25.448397346360423]]]]}}],
#   'lote_id': 'lote22',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54806N84984', 'POP10': 474},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28363617466971, -25.448366516701356],
#         [-49.28366925982846, -25.44653761941555],
#         [-49.2817069472178, -25.446506777166007],
#         [-49.2816738485692, -25.448335674451755],
#         [-49.28363617466971, -25.448366516701356]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84984', 'POP10': 320},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2816738485692, -25.448335674451755],
#         [-49.2817069472178, -25.446506777166007],
#         [-49.27974463550646, -25.44647592232593],
#         [-49.279711522468745, -25.44830481871236],
#         [-49.2816738485692, -25.448335674451755]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54800N84986', 'POP10': 838},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.289556199459014, -25.44663006882257],
#         [-49.28958924324894, -25.4448011841273],
#         [-49.287626943228815, -25.44477038144788],
#         [-49.287593885949036, -25.446599265243833],
#         [-49.289556199459014, -25.44663006882257]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54802N84986', 'POP10': 792},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.287593885949036, -25.446599265243833],
#         [-49.287626943228815, -25.44477038144788],
#         [-49.28566464410801, -25.444739565278667],
#         [-49.28563157243906, -25.44656844907462],
#         [-49.287593885949036, -25.446599265243833]]]]}}],
#   'lote_id': 'lote23',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54804N84986', 'POP10': 986},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28563157243906, -25.44656844907462],
#         [-49.28566464410801, -25.444739565278667],
#         [-49.283702344987205, -25.44470873651892],
#         [-49.28366925982846, -25.44653761941555],
#         [-49.28563157243906, -25.44656844907462]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54806N84986', 'POP10': 753},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28366925982846, -25.44653761941555],
#         [-49.283702344987205, -25.44470873651892],
#         [-49.2817400458664, -25.444677895168695],
#         [-49.2817069472178, -25.446506777166007],
#         [-49.28366925982846, -25.44653761941555]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84986', 'POP10': 346},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2817069472178, -25.446506777166007],
#         [-49.2817400458664, -25.444677895168695],
#         [-49.279777747644914, -25.44464704032862],
#         [-49.27974463550646, -25.44647592232593],
#         [-49.2817069472178, -25.446506777166007]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54804N84988', 'POP10': 628},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28566464410801, -25.444739565278667],
#         [-49.285697714877585, -25.442910696771207],
#         [-49.28373542924663, -25.44287986801146],
#         [-49.283702344987205, -25.44470873651892],
#         [-49.28566464410801, -25.444739565278667]]]]}}],
#   'lote_id': 'lote24',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54806N84988', 'POP10': 893},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.283702344987205, -25.44470873651892],
#         [-49.28373542924663, -25.44287986801146],
#         [-49.28177314451494, -25.44284902666118],
#         [-49.2817400458664, -25.444677895168695],
#         [-49.283702344987205, -25.44470873651892]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84988', 'POP10': 910},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2817400458664, -25.444677895168695],
#         [-49.28177314451494, -25.44284902666118],
#         [-49.27981085978331, -25.442818172720422],
#         [-49.279777747644914, -25.44464704032862],
#         [-49.2817400458664, -25.444677895168695]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54808N84990', 'POP10': 967},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.28177314451494, -25.44284902666118],
#         [-49.281806242264224, -25.44102017344221],
#         [-49.27984397192171, -25.440989319501455],
#         [-49.27981085978331, -25.442818172720422],
#         [-49.28177314451494, -25.44284902666118]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84964', 'POP10': 61},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.279380367809665, -25.46659457128237],
#         [-49.27941348534404, -25.46476553190371],
#         [-49.27745103693576, -25.464734659077237],
#         [-49.27741790501227, -25.4665636984559],
#         [-49.279380367809665, -25.46659457128237]]]]}}],
#   'lote_id': 'lote25',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54810N84966', 'POP10': 149},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27941348534404, -25.46476553190371],
#         [-49.27944660287835, -25.4629365060149],
#         [-49.27748416706061, -25.46290563408769],
#         [-49.27745103693576, -25.464734659077237],
#         [-49.27941348534404, -25.46476553190371]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54812N84966', 'POP10': 169},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27745103693576, -25.464734659077237],
#         [-49.27748416706061, -25.46290563408769],
#         [-49.27552173214218, -25.462874749570005],
#         [-49.27548858762816, -25.464703774559496],
#         [-49.27745103693576, -25.464734659077237]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84968', 'POP10': 210},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27944660287835, -25.4629365060149],
#         [-49.279479719513404, -25.461107495414524],
#         [-49.277517298084774, -25.461076623487315],
#         [-49.27748416706061, -25.46290563408769],
#         [-49.27944660287835, -25.4629365060149]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54812N84968', 'POP10': 248},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27748416706061, -25.46290563408769],
#         [-49.277517298084774, -25.461076623487315],
#         [-49.2755548766562, -25.46104573986895],
#         [-49.27552173214218, -25.462874749570005],
#         [-49.27748416706061, -25.46290563408769]]]]}}],
#   'lote_id': 'lote26',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54814N84968', 'POP10': 304},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27552173214218, -25.462874749570005],
#         [-49.2755548766562, -25.46104573986895],
#         [-49.27359245612689, -25.461014842760733],
#         [-49.273559298123075, -25.462843852461788],
#         [-49.27552173214218, -25.462874749570005]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84970', 'POP10': 368},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.279479719513404, -25.461107495414524],
#         [-49.27951283524908, -25.459278498304002],
#         [-49.2775504273103, -25.459247627276113],
#         [-49.277517298084774, -25.461076623487315],
#         [-49.279479719513404, -25.461107495414524]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54812N84970', 'POP10': 217},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.277517298084774, -25.461076623487315],
#         [-49.2775504273103, -25.459247627276113],
#         [-49.2755880202709, -25.45921674365775],
#         [-49.2755548766562, -25.46104573986895],
#         [-49.277517298084774, -25.461076623487315]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54814N84970', 'POP10': 361},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2755548766562, -25.46104573986895],
#         [-49.2755880202709, -25.45921674365775],
#         [-49.273625613231445, -25.45918584744885],
#         [-49.27359245612689, -25.461014842760733],
#         [-49.2755548766562, -25.46104573986895]]]]}}],
#   'lote_id': 'lote27',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54816N84970', 'POP10': 408},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27359245612689, -25.461014842760733],
#         [-49.273625613231445, -25.45918584744885],
#         [-49.27166320709131, -25.459154937750156],
#         [-49.27163003559764, -25.46098393306204],
#         [-49.27359245612689, -25.461014842760733]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54818N84970', 'POP10': 245},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27163003559764, -25.46098393306204],
#         [-49.27166320709131, -25.459154937750156],
#         [-49.26970080095117, -25.459124015460873],
#         [-49.26966761596765, -25.460953009873435],
#         [-49.27163003559764, -25.46098393306204]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84972', 'POP10': 144},
# ...
#         [-49.27369192744044, -25.455527899093227],
#         [-49.27365877033594, -25.45735686562682],
#         [-49.275621163885546, -25.45738776183572]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54816N84974', 'POP10': 129},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27365877033594, -25.45735686562682],
#         [-49.27369192744044, -25.455527899093227],
#         [-49.27172954828001, -25.455496991193172],
#         [-49.27169637768566, -25.45732595682739],
#         [-49.27365877033594, -25.45735686562682]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54818N84974', 'POP10': 135},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27169637768566, -25.45732595682739],
#         [-49.27172954828001, -25.455496991193172],
#         [-49.26976717001884, -25.455466069803208],
#         [-49.269733985934636, -25.457295035437483],
#         [-49.27169637768566, -25.45732595682739]]]]}}],
#   'lote_id': 'lote30',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54810N84976', 'POP10': 96},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27957906672049, -25.45562054814974],
#         [-49.2796121815569, -25.453791594206677],
#         [-49.277649814986944, -25.45376072497743],
#         [-49.277616685761416, -25.45558967802117],
#         [-49.27957906672049, -25.45562054814974]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54812N84976', 'POP10': 127},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.277616685761416, -25.45558967802117],
#         [-49.277649814986944, -25.45376072497743],
#         [-49.27568744841699, -25.453729842258383],
#         [-49.27565430660093, -25.455558795302125],
#         [-49.277616685761416, -25.45558967802117]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54814N84976', 'POP10': 238},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27565430660093, -25.455558795302125],
#         [-49.27568744841699, -25.453729842258383],
#         [-49.27372508274635, -25.453698946948805],
#         [-49.27369192744044, -25.455527899093227],
#         [-49.27565430660093, -25.455558795302125]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54816N84976', 'POP10': 176},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27369192744044, -25.455527899093227],
#         [-49.27372508274635, -25.453698946948805],
#         [-49.27176271797504, -25.453668039048694],
#         [-49.27172954828001, -25.455496991193172],
#         [-49.27369192744044, -25.455527899093227]]]]}}],
#   'lote_id': 'lote31',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54818N84976', 'POP10': 201},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27172954828001, -25.455496991193172],
#         [-49.27176271797504, -25.453668039048694],
#         [-49.26980035320372, -25.453637118558106],
#         [-49.26976717001884, -25.455466069803208],
#         [-49.27172954828001, -25.455496991193172]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84978', 'POP10': 146},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.2796121815569, -25.453791594206677],
#         [-49.279645295493935, -25.451962654652732],
#         [-49.27768294241383, -25.45193178542354],
#         [-49.277649814986944, -25.45376072497743],
#         [-49.2796121815569, -25.453791594206677]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54812N84978', 'POP10': 158},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.277649814986944, -25.45376072497743],
#         [-49.27768294241383, -25.45193178542354],
#         [-49.27572059023299, -25.451900903603757],
#         [-49.27568744841699, -25.453729842258383],
#         [-49.277649814986944, -25.45376072497743]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54814N84978', 'POP10': 267},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27568744841699, -25.453729842258383],
#         [-49.27572059023299, -25.451900903603757],
#         [-49.27375823895153, -25.4518700091935],
#         [-49.27372508274635, -25.453698946948805],
#         [-49.27568744841699, -25.453729842258383]]]]}}],
#   'lote_id': 'lote32',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54816N84978', 'POP10': 132},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27372508274635, -25.453698946948805],
#         [-49.27375823895153, -25.4518700091935],
#         [-49.271795887670066, -25.451839101293444],
#         [-49.27176271797504, -25.453668039048694],
#         [-49.27372508274635, -25.453698946948805]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54818N84978', 'POP10': 180},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27176271797504, -25.453668039048694],
#         [-49.271795887670066, -25.451839101293444],
#         [-49.269833536388546, -25.451808180802857],
#         [-49.26980035320372, -25.453637118558106],
#         [-49.27176271797504, -25.453668039048694]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84980', 'POP10': 297},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.279645295493935, -25.451962654652732],
#         [-49.27967840943103, -25.45013372948796],
#         [-49.27771607074004, -25.450102861158086],
#         [-49.27768294241383, -25.45193178542354],
#         [-49.279645295493935, -25.451962654652732]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54812N84980', 'POP10': 190},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27768294241383, -25.45193178542354],
#         [-49.27771607074004, -25.450102861158086],
#         [-49.275753732049054, -25.450071979338304],
#         [-49.27572059023299, -25.451900903603757],
#         [-49.27768294241383, -25.45193178542354]]]]}}],
#   'lote_id': 'lote33',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54814N84980', 'POP10': 113},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27572059023299, -25.451900903603757],
#         [-49.275753732049054, -25.450071979338304],
#         [-49.27379139425739, -25.450041085827422],
#         [-49.27375823895153, -25.4518700091935],
#         [-49.27572059023299, -25.451900903603757]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54816N84980', 'POP10': 294},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27375823895153, -25.4518700091935],
#         [-49.27379139425739, -25.450041085827422],
#         [-49.27182905646572, -25.45001017792731],
#         [-49.271795887670066, -25.451839101293444],
#         [-49.27375823895153, -25.4518700091935]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54818N84980', 'POP10': 167},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.271795887670066, -25.451839101293444],
#         [-49.27182905646572, -25.45001017792731],
#         [-49.26986671957343, -25.449979258336043],
#         [-49.269833536388546, -25.451808180802857],
#         [-49.271795887670066, -25.451839101293444]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84982', 'POP10': 337},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27967840943103, -25.45013372948796],
#         [-49.279711522468745, -25.44830481871236],
#         [-49.27774919726761, -25.448273951281806],
#         [-49.27771607074004, -25.450102861158086],
#         [-49.27967840943103, -25.45013372948796]]]]}}],
#   'lote_id': 'lote34',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54812N84982', 'POP10': 237},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27771607074004, -25.450102861158086],
#         [-49.27774919726761, -25.448273951281806],
#         [-49.275786872965796, -25.448243070361343],
#         [-49.275753732049054, -25.450071979338304],
#         [-49.27771607074004, -25.450102861158086]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54814N84982', 'POP10': 250},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.275753732049054, -25.450071979338304],
#         [-49.275786872965796, -25.448243070361343],
#         [-49.273824548663924, -25.44821217595114],
#         [-49.27379139425739, -25.450041085827422],
#         [-49.275753732049054, -25.450071979338304]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54816N84982', 'POP10': 100},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27379139425739, -25.450041085827422],
#         [-49.273824548663924, -25.44821217595114],
#         [-49.27186222436211, -25.44818126984967],
#         [-49.27182905646572, -25.45001017792731],
#         [-49.27379139425739, -25.450041085827422]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84984', 'POP10': 302},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.279711522468745, -25.44830481871236],
#         [-49.27974463550646, -25.44647592232593],
#         [-49.27778232379518, -25.44644505489532],
#         [-49.27774919726761, -25.448273951281806],
#         [-49.279711522468745, -25.44830481871236]]]]}}],
#   'lote_id': 'lote35',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54812N84984', 'POP10': 255},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27774919726761, -25.448273951281806],
#         [-49.27778232379518, -25.44644505489532],
#         [-49.27582001298316, -25.446414174874235],
#         [-49.275786872965796, -25.448243070361343],
#         [-49.27774919726761, -25.448273951281806]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54814N84984', 'POP10': 73},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.275786872965796, -25.448243070361343],
#         [-49.27582001298316, -25.446414174874235],
#         [-49.27385770307052, -25.446383281363296],
#         [-49.273824548663924, -25.44821217595114],
#         [-49.275786872965796, -25.448243070361343]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54816N84984', 'POP10': 297},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.273824548663924, -25.44821217595114],
#         [-49.27385770307052, -25.446383281363296],
#         [-49.2718953922585, -25.44635237526188],
#         [-49.27186222436211, -25.44818126984967],
#         [-49.273824548663924, -25.44821217595114]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84986', 'POP10': 340},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27974463550646, -25.44647592232593],
#         [-49.279777747644914, -25.44464704032862],
#         [-49.27781545032275, -25.44461617379733],
#         [-49.27778232379518, -25.44644505489532],
#         [-49.27974463550646, -25.44647592232593]]]]}}],
#   'lote_id': 'lote36',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54812N84986', 'POP10': 257},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27778232379518, -25.44644505489532],
#         [-49.27781545032275, -25.44461617379733],
#         [-49.27585315300058, -25.444585293776242],
#         [-49.27582001298316, -25.446414174874235],
#         [-49.27778232379518, -25.44644505489532]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54814N84986', 'POP10': 52},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27582001298316, -25.446414174874235],
#         [-49.27585315300058, -25.444585293776242],
#         [-49.27389085657774, -25.444554400265304],
#         [-49.27385770307052, -25.446383281363296],
#         [-49.27582001298316, -25.446414174874235]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84988', 'POP10': 1054},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.279777747644914, -25.44464704032862],
#         [-49.27981085978331, -25.442818172720422],
#         [-49.277848575951, -25.44278730618919],
#         [-49.27781545032275, -25.44461617379733],
#         [-49.279777747644914, -25.44464704032862]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54812N84988', 'POP10': 469},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27781545032275, -25.44461617379733],
#         [-49.277848575951, -25.44278730618919],
#         [-49.27588629301795, -25.442756427067422],
#         [-49.27585315300058, -25.444585293776242],
#         [-49.27781545032275, -25.44461617379733]]]]}}],
#   'lote_id': 'lote37',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54814N84988', 'POP10': 322},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27585315300058, -25.444585293776242],
#         [-49.27588629301795, -25.442756427067422],
#         [-49.273924010084954, -25.442725534455803],
#         [-49.27389085657774, -25.444554400265304],
#         [-49.27585315300058, -25.444585293776242]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54810N84990', 'POP10': 683},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27981085978331, -25.442818172720422],
#         [-49.27984397192171, -25.440989319501455],
#         [-49.27788170157925, -25.440958453869484],
#         [-49.277848575951, -25.44278730618919],
#         [-49.27981085978331, -25.442818172720422]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54812N84990', 'POP10': 973},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.277848575951, -25.44278730618919],
#         [-49.27788170157925, -25.440958453869484],
#         [-49.27591943213605, -25.440927574747718],
#         [-49.27588629301795, -25.442756427067422],
#         [-49.277848575951, -25.44278730618919]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54814N84990', 'POP10': 1389},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.27588629301795, -25.442756427067422],
#         [-49.27591943213605, -25.440927574747718],
#         [-49.27395716269285, -25.4408966821361],
#         [-49.273924010084954, -25.442725534455803],
#         [-49.27588629301795, -25.442756427067422]]]]}}],
#   'lote_id': 'lote38',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME54820N84972', 'POP10': 269},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.26970080095117, -25.459124015460873],
#         [-49.269733985934636, -25.457295035437483],
#         [-49.26777159418367, -25.457264100557722],
#         [-49.26773839571035, -25.45909308058117],
#         [-49.26970080095117, -25.459124015460873]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME54820N84974', 'POP10': 441},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-49.269733985934636, -25.457295035437483],
#         [-49.26976717001884, -25.455466069803208],
#         [-49.26780479175767, -25.455435135822825],
#         [-49.26777159418367, -25.457264100557722],
#         [-49.269733985934636, -25.457295035437483]]]]}}],
#   'lote_id': 'lote39',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}}]

# %% [markdown]
# #### Visualize the spatial distribution of the homogeneous grid cell

# %%
import folium
import ipywidgets as widgets
from IPython.display import display

# Function to calculate the centroid of a polygon (original grid)
def calculate_centroid(coordinates):
    x = [p[0] for p in coordinates]
    y = [p[1] for p in coordinates]
    centroid_x = sum(x) / len(coordinates)
    centroid_y = sum(y) / len(coordinates)
    return [centroid_y, centroid_x]

# Calculate the coordinates of the centroid of the original grid
first_polygon = grid['features'][0]['geometry']['coordinates'][0][0]
centroid_coords = calculate_centroid(first_polygon)

# Function to plot a subset
def plot_subset(subset_index):
    subset_to_plot = grid_subsets[subset_index]

    # GeoJson style
    style = {'fillColor': '#8C8989', 'color': '#e31a1c', 'weight': 2}

    # Initialize the Folium map at the centroid of the original grid
    m = folium.Map(location=centroid_coords, tiles='OpenStreetMap', zoom_start=14)

    # Add GeoJson to the map
    folium.GeoJson(
        subset_to_plot,
        name=f'Grade Estatística 200m - Lote {subset_index+1}',
        tooltip=folium.GeoJsonTooltip(fields=['id', 'POP10']),
        style_function=lambda x: style
    ).add_to(m)

    # Display the map
    display(m)

# Create the drop-down list with the subset indexes
dropdown = widgets.Dropdown(
    options=[(f'Lote {i+1}', i) for i in range(len(grid_subsets))],
    description='Select a Batch:',
    disabled=False,
)

# Update the map based on the selection
widgets.interactive(plot_subset, subset_index=dropdown)
# Out:
# interactive(children=(Dropdown(description='Select a Batch:', options=(('Lote 1', 0), ('Lote 2', 1), ('Lote 3'…

# %% [markdown]
# ### **OHSOME API**
#
#  - Access to features, attributes and OSM history edits using the OHSOME API (*OpenStreetMap History Data Analytics Platform*)
#
# > - https://docs.ohsome.org/ohsome-api/v1/

# %%
# URL of OHSOME API Metadata endpoint
URL = 'https://api.ohsome.org/v1/metadata'

# Request to the OHSOME API
response = requests.get(URL)

response_json = response.json()
response_json

# %% [markdown]
# ### Retrieving data from OpenStreetMap using OHSOME API and homogeneous grid cells

# %% [markdown]
# #### Step 1 (*API Endpoint: Elements Aggregation*): count the number of OSM features (elements) and calculate the proportion of features with the attribute "name" fill in by contributors, for each grid cells:
#
#
#  - Determine the total number of OSM features for interest tags, grouped by grid cell;
#
#  - Quantify the total number of features with attribute "name" filled in; and
#
#  - Calculate the proportion of features with attribute "name" filled in for each grid cell.
#
#  - Period of data retrieved: 2007-10-08 to 2024-03-10;

# %%
# Approach for processing batches of 04 cells from the original grid

# Step 1 (API Endpoint: Elements Aggregation): count the number of OSM features
# (elements) and calculate the proportion of features with "name" attribute filled by contributors, for each grid cells:
# Aggregation method: count
# POST /elements/(aggregation)/groupBy/boundary/groupBy/tag

# Start the time counter
start_time = time.time()

# Load a copy of previously created grid_subsets
grid_subset2 = grid_subsets.copy()

# OHSOME API endpoint url
url_tag = "https://api.ohsome.org/v1/elements/count/groupBy/boundary/groupBy/tag"

# OSM tags of interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_base = {
    'time': '2007-10-08/2024-03-10'
}

# List to store the final results
final_results = {}

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
    for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        for tag, value in tags_de_interesse.items():
            # 1st: Aggregate the object of each interest tag by grid cell
            params = params_base.copy()
            params.update({
                'bpolys': cell_geojson,
                'filter': f'{tag}={value}',
                'groupByKey': tag,
                'groupByValues': value
            })

            response = requests.post(url_tag, data=params)
            if response.status_code == 200:
                data = response.json()

                total_count = sum(res.get('value', 0) for res in data.get('groupByResult', [])[0].get('result', []))
                feature['properties'][f'{tag}_total_count'] = total_count

            # 2nd: Count the features with the attribute 'name' filled in
            params['filter'] = f'{tag}={value} and name=*'
            response = requests.post(url_tag, data=params)
            if response.status_code == 200:
                data = response.json()

                name_count = sum(res.get('value', 0) for res in data.get('groupByResult', [])[0].get('result', []))
                feature['properties'][f'{tag}_name_count'] = name_count
                name_ratio_perc = (name_count / total_count) * 100 if total_count > 0 else 0
                feature['properties'][f'{tag}_name_ratio'] = name_ratio_perc

        # Add cell results to final_results
        final_results[cell_id] = feature['properties']

    print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutes and {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 1
grid_subset2

# %% [markdown]
# #### Step 2 (*API Endpoint: Contributions Aggregation*): count the total number of contributions for features with and without the attribute "name" filled in:
#
# - Count the **total number of contributions** to the *interest tags* for the total features in the grid cells, with and without the attribute "name" filled in.
#
# - Period of data retrieved: 2007-10-08 to 2024-03-10.

# %%
# Approach for processing batches of 04 cells from the original grid

# Step 2 (API Endpoint: Endpoint Contributions Aggregation): count the total number of
# contributions for features with and without a name attribute filled in.
# Aggregation method: count
# POST /contributions/count/groupBy/boundary

# Start the time counter
start_time = time.time()

# OHSOME API endpoint url
url_contributions = "https://api.ohsome.org/v1/contributions/count/groupBy/boundary"

# OSM tags of Interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_contributions_base = {
    'time': '2007-10-08/2024-03-10'
}

# Function to process the response
def process_response(response, cell_id):
    if response.status_code == 200:
        data = response.json()
        return sum(result.get('value', 0) for result in data.get('groupByResult', [])[0].get('result', []))
    else:
        print(f"Cell query error {cell_id}: {response.text}")
        return 0

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
  for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        for tag in tags_de_interesse:

            # Settings for all features
            params_contributions_all = params_contributions_base.copy()
            params_contributions_all.update({'bpolys': cell_geojson, 'filter': f'{tag}=*'})
            response_all = requests.post(url_contributions, data=params_contributions_all)
            contributions_all = process_response(response_all, cell_id)


            # Settings for all features with 'name' filled in
            params_contributions_name = params_contributions_base.copy()
            params_contributions_name.update({'bpolys': cell_geojson, 'filter': f'{tag}=* and name=*'})
            response_name = requests.post(url_contributions, data=params_contributions_name)
            contributions_name = process_response(response_name, cell_id)

            # Update the feature's properties
            feature['properties'][f'{tag}_total_contributions'] = contributions_all
            feature['properties'][f'{tag}_name_contributions'] = contributions_name

  print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutos and {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 2
grid_subset2

# %% [markdown]
# #### Step 3 (*API Endpoint: Contributions Aggregation*): Count the number of contributions in the past five years for features with the attribute "name" filled in:
#
#  - Count the number of contributions in the past five years for tags of interest, aggregated by grid cells, with the attribute "name" filled in;
#
#  - Period of data retrieved: 2019-03-09 to 2024-03-10

# %%
# Approach for processing batches of 04 cells from the original grid

# Step 3 (API Endpoint: Contributions Aggregation): Count the number of contributions
# in the past five years for features with a filled-in name
# Aggregation method: count
# POST /contributions/latest/count

# Start the time counter
start_time = time.time()

# OHSOME API endpoint url
url_latest_contributions = "https://api.ohsome.org/v1/contributions/latest/count"

# OSM tags of Interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_contributions_base = {
    'time': '2019-03-09/2024-03-10'
}

# Function to process the response
def process_response(response, cell_id):
    if response.status_code == 200:
        data = response.json()
        latest_result = data.get('result', [])
        return latest_result[-1].get('value', 0) if latest_result else 0
    else:
        print(f"Cell query error {cell_id}: {response.text}")
        return 0

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
    for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        # Settings for all features with 'name' filled in
        for tag in tags_de_interesse:
            params_latest_contributions = params_contributions_base.copy()
            params_latest_contributions.update({'bpolys': cell_geojson, 'filter': f'{tag}=* and name=*'})
            response = requests.post(url_latest_contributions, data=params_latest_contributions)
            latest_contributions_count = process_response(response, cell_id)

            # Update the feature's properties
            feature['properties'][f'{tag}_latest5_name_contributions'] = latest_contributions_count

    print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutes e {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 3
grid_subset2

# %% [markdown]
# #### Step 4 (*API Endpoint: Contributions Aggregation*): Count the total number of contributions to features with a filled-in name where a tagChange occurred:
#
# - Count the total number of contributions to the tags of interest, aggregated by grid cell, with the attribute name filled in, considering the type of contribution (contributionType) tag change ('tagChange').
#
#   - *contributionType available: ‘creation’, ‘deletion’, ‘tagChange’, ‘geometryChange’ ou uma combinação destes*
#
# - Period of data retrieved: 2007-10-08 to 2024-03-10.

# %%
# Approach for processing batches of 04 cells from the original grid

# Step 4 (API Endpoint: Contributions Aggregation): Count the total number of
# contributions to features with a filled-in name where a tagChange occurred
# Aggregation method: count
# POST /contributions/count/groupBy/boundary

# Start the time counter
start_time = time.time()

# OHSOME API endpoint url
url_contributions = "https://api.ohsome.org/v1/contributions/count/groupBy/boundary"

# OSM tags of Interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_contributions_base = {
    'time': '2007-10-08/2024-03-10',
    'contributionType': 'tagChange'
}

# Function to process the response
def process_response(response, cell_id):
    if response.status_code == 200:
        data = response.json()
        return sum(result.get('value', 0) for result in data.get('groupByResult', [])[0].get('result', []))
    else:
        print(f"Erro na consulta da célula {cell_id}: {response.text}")
        return 0

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
    for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        # Settings for all features with 'name' filled in AND tagChange
        for tag in tags_de_interesse:
            params_contributions = params_contributions_base.copy()
            params_contributions.update({'bpolys': cell_geojson, 'filter': f'{tag}=* and name=*'})

            response = requests.post(url_contributions, data=params_contributions)
            contributions_count = process_response(response, cell_id)

            # Update the feature's properties
            feature['properties'][f'{tag}_name_tagChange_contributions'] = contributions_count

    print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutes and {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 4
grid_subset2

# %% [markdown]
# #### Step 5 (API Endpoint: Users Aggregation): Count the number of users (contributors) who edited features with attribute name filled in:
#
# - Count the number of users who edited features of the OSM tags of Interest with attribute "name" attribute filled in, aggregated by grid cells.
#
# - Period of data retrieved: 2007-10-08 to 2024-03-10.

# %%
# # Approach for processing batches of 04 cells from the original grid

# Step 5 (API Endpoint: Users Aggregation): Count the number of users (contributors)
# who edited features with attribute name filled in:
# Aggregation method: count
# POST /users/count/groupBy/boundary

# Start the time counter
start_time = time.time()

# OHSOME API endpoint url
url_users_count = "https://api.ohsome.org/v1/users/count/groupBy/boundary"

# OSM tags of Interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_users_count_base = {
    'time': '2007-10-08/2024-03-10'
}

# Function to process the response
def process_user_response(response, cell_id):
    if response.status_code == 200:
        data = response.json()
        for result in data.get('groupByResult', []):
            if result['groupByObject'] == cell_id:
                return result['result'][0]['value']
    return 0

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
    for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        # Settings for all features with 'name' filled
        for tag in tags_de_interesse:
            params_users_count = params_users_count_base.copy()
            params_users_count.update({'bpolys': cell_geojson, 'filter': f'{tag}=* and name=*'})

            response = requests.post(url_users_count, data=params_users_count)
            users_name_count = process_user_response(response, cell_id)

            # Update the feature's properties
            feature['properties'][f'{tag}_users_count_name'] = users_name_count

    print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutes and {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 5
grid_subset2

# %% [markdown]
# #### Save the updated grid cells with the information Extracted using the OHSOME API endpoints

# %%
output_filename = "/content/drive/MyDrive/UFPR_PPGCG_DSc/DSc_Dev/02-saidas/02_testes_feicoes_agregadasGrade/passare/grade_id77_passare_results.geojson"

# Create a new FeatureCollection to combine all the subsets
grid_subset2_results = {
    'type': 'FeatureCollection',
    'crs': grid_subset2[0]['crs'],
    'features': []
}

# Iterate over each subset and add its features to the combined FeatureCollection
for subset in grid_subset2:
    grid_subset2_results['features'].extend(subset['features'])

# Save the combined grid cells in a GeoJSON file
with open(output_filename, 'w') as file:
    json.dump(grid_subset2_results, file)

# %% [markdown]
# ---
