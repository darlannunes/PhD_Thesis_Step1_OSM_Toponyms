# %% [markdown]
# ## Jupyter notebook 01: Retrieving data from OpenStreetMap using OHSOME API and homogeneous grid cells

# %% [markdown]
# ***Paper: Collaborative Toponyms in OpenStreetMap: an open-source framework to investigate the relationship with intrinsic quality parameters***

# %% [markdown]
# **Aims**
#
# - To conduct a quantitative assessment of elements within OpenStreetMap (OSM) that have the 'name' attribute filled for potential categories of the Brazilian Authoritative Topographic Map; and
#
# - To investigate the most significant intrinsic quality parameters that contribute to the reliability of toponyms in OSM.

# %% [markdown]
# **Brief Overview of the Proposed Methodology**
#
# - Preliminary survey of potential OpenStreetMap (OSM) tags to provide relevant toponym information to categories of interest related to Brazilian Topographic Mapping;
#
# - Execution of a quantitative analysis on collaboratively entered toponyms, utilizing homogeneous grid-based approaches; and
#
# - Assessment of intrinsic quality parameters as indicators of the reliability of toponyms in a scientific context.
#
# ---

# %% [markdown]
# ### Install the necessary libraries to the project

# %%
# In case of using colab, install these necessary libraries
# %pip install requests geopandas folium shapely -q

# %% [markdown]
# ### Import the libraries

# %%
# Import library and some pre-installed modules
import os
import requests
import json
import pandas as pd
import geopandas as gpd
import time
from ipywidgets import widgets

# %% [markdown]
# ### Connect to Google Drive

# %%
# In case of using colab, conect to Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Homogeneous Grid Cells
#  - Statistical Grid (cell size of 200 x 200m) produced by Instituto Brasileiro de Geografia e Estatística (Brazilian Institute of Geography and Statistics)
#
#   - https://geoftp.ibge.gov.br/recortes_para_fins_estatisticos/

# %% [markdown]
# #### Import Homogeneous Grid Cells from Google Drive

# %%
# Import the statistics grid in GeoJSON format

# @title Import the grid with the aggregated data extracted from OSM via the OHSOME API
grid = None

# Function for selecting and loading the GeoJSON file
def select_file(change):
    global grid
    selected_file = change['new']
    
    if selected_file != "Select the GeoJSON file with grid cells:":
        file_path = os.path.join('../data/input_code1/', selected_file)
        try:
            with open(file_path, 'r') as file:
                grid = json.load(file)
            print("File selected with success:", selected_file)
            print("File path:", file_path)
        except FileNotFoundError:
            print("File not found:", selected_file)

# Listing available GeoJSON files
file_list = [f for f in os.listdir('../data/input_code1/') if f.endswith('.geojson')]
options = ["Select the GeoJSON file with grid cells:"] + file_list

# Dropdown to select the GeoJSON file
dropdown = widgets.Dropdown(options=options)
dropdown.observe(select_file, names='value')

# Display the dropdown
display(dropdown)
# Out:
# Dropdown(options=('Select the GeoJSON file with grid cells:', 'grade_id25_aguaverde.geojson', 'grade_id77_pass…

# %%
# Preview grid cells
grid
# Out:
# {'type': 'FeatureCollection',
#  'name': 'grade_id77_passare',
#  'crs': {'type': 'name', 'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}},
#  'features': [{'type': 'Feature',
#    'properties': {'id': '200ME67074N108676', 'POP10': 3},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.544511985439726, -3.826623840517755],
#        [-38.544611901917676, -3.824826793621583],
#        [-38.54280518371223, -3.824727406844318],
#        [-38.54270525554307, -3.82652445374049],
#        [-38.544511985439726, -3.826623840517755]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108676', 'POP10': 166},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54270525554307, -3.82652445374049],
#        [-38.54280518371223, -3.824727406844318],
#        [-38.54099846640605, -3.824628008375839],
#        [-38.54089852744505, -3.826425055272011],
#        [-38.54270525554307, -3.82652445374049]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108676', 'POP10': 562},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54089852744505, -3.826425055272011],
#        [-38.54099846640605, -3.824628008375839],
#        [-38.53919175089857, -3.824528599115524],
#        [-38.539091799347034, -3.826325645112377],
#        [-38.54089852744505, -3.826425055272011]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67074N108678', 'POP10': 223},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.544611901917676, -3.824826793621583],
#        [-38.54471181659699, -3.823029738631476],
#        [-38.5429051100827, -3.822930351854211],
#        [-38.54280518371223, -3.824727406844318],
#        [-38.544611901917676, -3.824826793621583]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108678', 'POP10': 62},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54280518371223, -3.824727406844318],
#        [-38.5429051100827, -3.822930351854211],
#        [-38.54109840446773, -3.822830954285052],
#        [-38.54099846640605, -3.824628008375839],
#        [-38.54280518371223, -3.824727406844318]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108678', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54099846640605, -3.824628008375839],
#        [-38.54109840446773, -3.822830954285052],
#        [-38.539291700651404, -3.822731544125418],
#        [-38.53919175089857, -3.824528599115524],
#        [-38.54099846640605, -3.824628008375839]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108680', 'POP10': 9},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5429051100827, -3.822930351854211],
#        [-38.543005034654584, -3.821133288770227],
#        [-38.54119834073077, -3.821033891201068],
#        [-38.54109840446773, -3.822830954285052],
#        [-38.5429051100827, -3.822930351854211]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108680', 'POP10': 15},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54109840446773, -3.822830954285052],
#        [-38.54119834073077, -3.821033891201068],
#        [-38.53939164860566, -3.820934481940753],
#        [-38.539291700651404, -3.822731544125418],
#        [-38.54109840446773, -3.822830954285052]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108686', 'POP10': 181},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54139821055895, -3.81743974255005],
#        [-38.541498143224715, -3.815642656083639],
#        [-38.539691486173126, -3.815543246823324],
#        [-38.53959154181615, -3.817340333289678],
#        [-38.54139821055895, -3.81743974255005]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108688', 'POP10': 291},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.543304802074886, -3.815742052753478],
#        [-38.54340472215017, -3.813944958193247],
#        [-38.5415980749911, -3.813845561523408],
#        [-38.541498143224715, -3.815642656083639],
#        [-38.543304802074886, -3.815742052753478]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108688', 'POP10': 533},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.541498143224715, -3.815642656083639],
#        [-38.5415980749911, -3.813845561523408],
#        [-38.539791428731405, -3.813746152263093],
#        [-38.539691486173126, -3.815543246823324],
#        [-38.541498143224715, -3.815642656083639]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67074N108690', 'POP10': 1434},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.545211370208506, -3.814044343171872],
#        [-38.54531127769326, -3.812247240517706],
#        [-38.54350464042676, -3.812147855539081],
#        [-38.54340472215017, -3.813944958193247],
#        [-38.545211370208506, -3.814044343171872]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108690', 'POP10': 787},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54340472215017, -3.813944958193247],
#        [-38.54350464042676, -3.812147855539081],
#        [-38.5416980049589, -3.812048458869242],
#        [-38.5415980749911, -3.813845561523408],
#        [-38.54340472215017, -3.813944958193247]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108690', 'POP10': 828},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5415980749911, -3.813845561523408],
#        [-38.5416980049589, -3.812048458869242],
#        [-38.539891371289684, -3.811949050508247],
#        [-38.539791428731405, -3.813746152263093],
#        [-38.5415980749911, -3.813845561523408]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67074N108692', 'POP10': 1047},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54531127769326, -3.812247240517706],
#        [-38.54541118337937, -3.810450129769606],
#        [-38.54360455780403, -3.810350744790981],
#        [-38.54350464042676, -3.812147855539081],
#        [-38.54531127769326, -3.812247240517706]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108692', 'POP10': 554},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54350464042676, -3.812147855539081],
#        [-38.54360455780403, -3.810350744790981],
#        [-38.541797934027386, -3.810251348121199],
#        [-38.5416980049589, -3.812048458869242],
#        [-38.54350464042676, -3.812147855539081]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108692', 'POP10': 167},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5416980049589, -3.812048458869242],
#        [-38.541797934027386, -3.810251348121199],
#        [-38.53999131115006, -3.810151939760146],
#        [-38.539891371289684, -3.811949050508247],
#        [-38.5416980049589, -3.812048458869242]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67074N108694', 'POP10': 1064},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54541118337937, -3.810450129769606],
#        [-38.545511088166165, -3.808653010927685],
#        [-38.54370447428204, -3.808553625949003],
#        [-38.54360455780403, -3.810350744790981],
#        [-38.54541118337937, -3.810450129769606]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108694', 'POP10': 755},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54360455780403, -3.810350744790981],
#        [-38.54370447428204, -3.808553625949003],
#        [-38.54189786219655, -3.808454229279221],
#        [-38.541797934027386, -3.810251348121199],
#        [-38.54360455780403, -3.810350744790981]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108694', 'POP10': 804},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.541797934027386, -3.810251348121199],
#        [-38.54189786219655, -3.808454229279221],
#        [-38.54009125101038, -3.808354821817545],
#        [-38.53999131115006, -3.810151939760146],
#        [-38.541797934027386, -3.810251348121199]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67072N108696', 'POP10': 992},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54731770294961, -3.808752383315777],
#        [-38.547417594246554, -3.806955256379922],
#        [-38.54561099115426, -3.80685588399183],
#        [-38.545511088166165, -3.808653010927685],
#        [-38.54731770294961, -3.808752383315777]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67074N108696', 'POP10': 1318},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.545511088166165, -3.808653010927685],
#        [-38.54561099115426, -3.80685588399183],
#        [-38.54380438896135, -3.806756499013147],
#        [-38.54370447428204, -3.808553625949003],
#        [-38.545511088166165, -3.808653010927685]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108696', 'POP10': 673},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54370447428204, -3.808553625949003],
#        [-38.54380438896135, -3.806756499013147],
#        [-38.54199778856707, -3.806657103242685],
#        [-38.54189786219655, -3.808454229279221],
#        [-38.54370447428204, -3.808553625949003]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108696', 'POP10': 478},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54189786219655, -3.808454229279221],
#        [-38.54199778856707, -3.806657103242685],
#        [-38.54019118907206, -3.80655769488169],
#        [-38.54009125101038, -3.808354821817545],
#        [-38.54189786219655, -3.808454229279221]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67074N108698', 'POP10': 532},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54561099115426, -3.80685588399183],
#        [-38.54571089234378, -3.80505874896204],
#        [-38.54390430184202, -3.804959364882734],
#        [-38.54380438896135, -3.806756499013147],
#        [-38.54561099115426, -3.80685588399183]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108698', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54380438896135, -3.806756499013147],
#        [-38.54390430184202, -3.804959364882734],
#        [-38.5420977131389, -3.804859968212895],
#        [-38.54199778856707, -3.806657103242685],
#        [-38.54380438896135, -3.806756499013147]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108698', 'POP10': 29},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54199778856707, -3.806657103242685],
#        [-38.5420977131389, -3.804859968212895],
#        [-38.5402911253351, -3.80476056075122],
#        [-38.54019118907206, -3.80655769488169],
#        [-38.54199778856707, -3.806657103242685]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67074N108700', 'POP10': 882},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54571089234378, -3.80505874896204],
#        [-38.545810793533235, -3.803261605838372],
#        [-38.54400421472269, -3.803162221759067],
#        [-38.54390430184202, -3.804959364882734],
#        [-38.54571089234378, -3.80505874896204]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108700', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54390430184202, -3.804959364882734],
#        [-38.54400421472269, -3.803162221759067],
#        [-38.542197636811466, -3.803062825988604],
#        [-38.5420977131389, -3.804859968212895],
#        [-38.54390430184202, -3.804959364882734]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108700', 'POP10': 361},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5420977131389, -3.804859968212895],
#        [-38.542197636811466, -3.803062825988604],
#        [-38.54039106069882, -3.802963418526872],
#        [-38.5402911253351, -3.80476056075122],
#        [-38.5420977131389, -3.804859968212895]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67074N108702', 'POP10': 632},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.545810793533235, -3.803261605838372],
#        [-38.54591069202479, -3.801464455520147],
#        [-38.5441041249054, -3.801365071440841],
#        [-38.54400421472269, -3.803162221759067],
#        [-38.545810793533235, -3.803261605838372]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108702', 'POP10': 6},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54400421472269, -3.803162221759067],
#        [-38.5441041249054, -3.801365071440841],
#        [-38.542297559584654, -3.801265675670322],
#        [-38.542197636811466, -3.803062825988604],
#        [-38.54400421472269, -3.803162221759067]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108702', 'POP10': 60},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.542197636811466, -3.803062825988604],
#        [-38.542297559584654, -3.801265675670322],
#        [-38.540490995163225, -3.801166268208647],
#        [-38.54039106069882, -3.802963418526872],
#        [-38.542197636811466, -3.803062825988604]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67076N108704', 'POP10': 301},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5441041249054, -3.801365071440841],
#        [-38.544204035088114, -3.799567912129419],
#        [-38.54239748055926, -3.799468517258219],
#        [-38.542297559584654, -3.801265675670322],
#        [-38.5441041249054, -3.801365071440841]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108704', 'POP10': 78},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.542297559584654, -3.801265675670322],
#        [-38.54239748055926, -3.799468517258219],
#        [-38.54059092782899, -3.799369110695864],
#        [-38.540490995163225, -3.801166268208647],
#        [-38.542297559584654, -3.801265675670322]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67078N108706', 'POP10': 241},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54239748055926, -3.799468517258219],
#        [-38.54249740063449, -3.797671350752182],
#        [-38.54069085959543, -3.797571944189826],
#        [-38.54059092782899, -3.799369110695864],
#        [-38.54239748055926, -3.799468517258219]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108672', 'POP10': 8},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53527839688047, -3.829720858330916],
#        [-38.535378373613014, -3.827923828521818],
#        [-38.53357163832038, -3.827824383288601],
#        [-38.53347164989668, -3.829621413097698],
#        [-38.53527839688047, -3.829720858330916]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108672', 'POP10': 140},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53347164989668, -3.829621413097698],
#        [-38.53357163832038, -3.827824383288601],
#        [-38.531764904826446, -3.827724926364226],
#        [-38.53166490471153, -3.829521956173267],
#        [-38.53347164989668, -3.829621413097698]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108672', 'POP10': 196},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53166490471153, -3.829521956173267],
#        [-38.531764904826446, -3.827724926364226],
#        [-38.52995817223183, -3.827625458647958],
#        [-38.529858160425704, -3.829422487557736],
#        [-38.53166490471153, -3.829521956173267]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108674', 'POP10': 7},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5389918477955, -3.828122683914671],
#        [-38.539091799347034, -3.826325645112377],
#        [-38.537285073946975, -3.826226224160848],
#        [-38.53718510980491, -3.828023262063823],
#        [-38.5389918477955, -3.828122683914671]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108674', 'POP10': 23},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53718510980491, -3.828023262063823],
#        [-38.537285073946975, -3.826226224160848],
#        [-38.53547834854692, -3.826126790618844],
#        [-38.535378373613014, -3.827923828521818],
#        [-38.53718510980491, -3.828023262063823]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108674', 'POP10': 13},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.535378373613014, -3.827923828521818],
#        [-38.53547834854692, -3.826126790618844],
#        [-38.53367162584482, -3.826027345385626],
#        [-38.53357163832038, -3.827824383288601],
#        [-38.535378373613014, -3.827923828521818]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108674', 'POP10': 86},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53357163832038, -3.827824383288601],
#        [-38.53367162584482, -3.826027345385626],
#        [-38.53186490314272, -3.825927889360571],
#        [-38.531764904826446, -3.827724926364226],
#        [-38.53357163832038, -3.827824383288601]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108674', 'POP10': 172},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.531764904826446, -3.827724926364226],
#        [-38.53186490314272, -3.825927889360571],
#        [-38.53005818223926, -3.825828420744983],
#        [-38.52995817223183, -3.827625458647958],
#        [-38.531764904826446, -3.827724926364226]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108676', 'POP10': 22},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.539091799347034, -3.826325645112377],
#        [-38.53919175089857, -3.824528599115524],
#        [-38.537385036290345, -3.824429177264676],
#        [-38.537285073946975, -3.826226224160848],
#        [-38.539091799347034, -3.826325645112377]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108676', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.537285073946975, -3.826226224160848],
#        [-38.537385036290345, -3.824429177264676],
#        [-38.53557832348082, -3.824329744621991],
#        [-38.53547834854692, -3.826126790618844],
#        [-38.537285073946975, -3.826226224160848]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108676', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53547834854692, -3.826126790618844],
#        [-38.53557832348082, -3.824329744621991],
#        [-38.53377161157056, -3.824230299388773],
#        [-38.53367162584482, -3.826027345385626],
#        [-38.53547834854692, -3.826126790618844]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108676', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53367162584482, -3.826027345385626],
#        [-38.53377161157056, -3.824230299388773],
#        [-38.53196490055967, -3.824130843363662],
#        [-38.53186490314272, -3.825927889360571],
#        [-38.53367162584482, -3.826027345385626]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108676', 'POP10': 65},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53186490314272, -3.825927889360571],
#        [-38.53196490055967, -3.824130843363662],
#        [-38.530158191347425, -3.824031375647394],
#        [-38.53005818223926, -3.825828420744983],
#        [-38.53186490314272, -3.825927889360571]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108678', 'POP10': 33},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53919175089857, -3.824528599115524],
#        [-38.539291700651404, -3.822731544125418],
#        [-38.537484997734396, -3.822632123173889],
#        [-38.537385036290345, -3.824429177264676],
#        [-38.53919175089857, -3.824528599115524]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108678', 'POP10': 30},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.537385036290345, -3.824429177264676],
#        [-38.537484997734396, -3.822632123173889],
#        [-38.53567829571671, -3.822532690531204],
#        [-38.53557832348082, -3.824329744621991],
#        [-38.537385036290345, -3.824429177264676]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108678', 'POP10': 60},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53557832348082, -3.824329744621991],
#        [-38.53567829571671, -3.822532690531204],
#        [-38.533871595497715, -3.822433246197306],
#        [-38.53377161157056, -3.824230299388773],
#        [-38.53557832348082, -3.824329744621991]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108678', 'POP10': 342},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53377161157056, -3.824230299388773],
#        [-38.533871595497715, -3.822433246197306],
#        [-38.532064897077305, -3.822333790172252],
#        [-38.53196490055967, -3.824130843363662],
#        [-38.53377161157056, -3.824230299388773]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108678', 'POP10': 283},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53196490055967, -3.824130843363662],
#        [-38.532064897077305, -3.822333790172252],
#        [-38.530258199556215, -3.822234322455984],
#        [-38.530158191347425, -3.824031375647394],
#        [-38.53196490055967, -3.824130843363662]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108680', 'POP10': 158},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.539291700651404, -3.822731544125418],
#        [-38.53939164860566, -3.820934481940753],
#        [-38.53758495737986, -3.820835060989225],
#        [-38.537484997734396, -3.822632123173889],
#        [-38.539291700651404, -3.822731544125418]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108680', 'POP10': 36},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.537484997734396, -3.822632123173889],
#        [-38.53758495737986, -3.820835060989225],
#        [-38.53577826795265, -3.82073562834654],
#        [-38.53567829571671, -3.822532690531204],
#        [-38.537484997734396, -3.822632123173889]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108680', 'POP10': 23},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53567829571671, -3.822532690531204],
#        [-38.53577826795265, -3.82073562834654],
#        [-38.533971578525495, -3.820636184012642],
#        [-38.533871595497715, -3.822433246197306],
#        [-38.53567829571671, -3.822532690531204]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108680', 'POP10': 242},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.533871595497715, -3.822433246197306],
#        [-38.533971578525495, -3.820636184012642],
#        [-38.5321648917963, -3.820536727987587],
#        [-38.532064897077305, -3.822333790172252],
#        [-38.533871595497715, -3.822433246197306]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108680', 'POP10': 375},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.532064897077305, -3.822333790172252],
#        [-38.5321648917963, -3.820536727987587],
#        [-38.530358205966365, -3.820437260271319],
#        [-38.530258199556215, -3.822234322455984],
#        [-38.532064897077305, -3.822333790172252]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108682', 'POP10': 160},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53939164860566, -3.820934481940753],
#        [-38.53949159566059, -3.819137411662155],
#        [-38.537684916125954, -3.819037990710683],
#        [-38.53758495737986, -3.820835060989225],
#        [-38.53939164860566, -3.820934481940753]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108682', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53758495737986, -3.820835060989225],
#        [-38.537684916125954, -3.819037990710683],
#        [-38.535878237490635, -3.818938558067941],
#        [-38.53577826795265, -3.82073562834654],
#        [-38.53758495737986, -3.820835060989225]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108682', 'POP10': 3},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53577826795265, -3.82073562834654],
#        [-38.535878237490635, -3.818938558067941],
#        [-38.534071560653956, -3.818839114633363],
#        [-38.533971578525495, -3.820636184012642],
#        [-38.53577826795265, -3.82073562834654]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108682', 'POP10': 79},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.533971578525495, -3.820636184012642],
#        [-38.534071560653956, -3.818839114633363],
#        [-38.532264885615916, -3.818739658608308],
#        [-38.5321648917963, -3.820536727987587],
#        [-38.533971578525495, -3.820636184012642]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108682', 'POP10': 188},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5321648917963, -3.820536727987587],
#        [-38.532264885615916, -3.818739658608308],
#        [-38.53045821057793, -3.81864019089204],
#        [-38.530358205966365, -3.820437260271319],
#        [-38.5321648917963, -3.820536727987587]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108684', 'POP10': 340},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53949159566059, -3.819137411662155],
#        [-38.53959154181615, -3.817340333289678],
#        [-38.537784873073406, -3.817240912338207],
#        [-38.537684916125954, -3.819037990710683],
#        [-38.53949159566059, -3.819137411662155]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108684', 'POP10': 74},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.537684916125954, -3.819037990710683],
#        [-38.537784873073406, -3.817240912338207],
#        [-38.53597820702856, -3.817141480594785],
#        [-38.535878237490635, -3.818938558067941],
#        [-38.537684916125954, -3.819037990710683]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108684', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.535878237490635, -3.818938558067941],
#        [-38.53597820702856, -3.817141480594785],
#        [-38.5341715418831, -3.817042036260943],
#        [-38.534071560653956, -3.818839114633363],
#        [-38.535878237490635, -3.818938558067941]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108684', 'POP10': 9},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.534071560653956, -3.818839114633363],
#        [-38.5341715418831, -3.817042036260943],
#        [-38.53236487763695, -3.816942581135152],
#        [-38.532264885615916, -3.818739658608308],
#        [-38.534071560653956, -3.818839114633363]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108684', 'POP10': 388},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.532264885615916, -3.818739658608308],
#        [-38.53236487763695, -3.816942581135152],
#        [-38.530558215189444, -3.816843114318203],
#        [-38.53045821057793, -3.81864019089204],
#        [-38.532264885615916, -3.818739658608308]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108686', 'POP10': 672},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53959154181615, -3.817340333289678],
#        [-38.539691486173126, -3.815543246823324],
#        [-38.53788482912154, -3.815443826771116],
#        [-38.537784873073406, -3.817240912338207],
#        [-38.53959154181615, -3.817340333289678]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108686', 'POP10': 511},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.537784873073406, -3.817240912338207],
#        [-38.53788482912154, -3.815443826771116],
#        [-38.53607817476791, -3.815344394128431],
#        [-38.53597820702856, -3.817141480594785],
#        [-38.537784873073406, -3.817240912338207]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108686', 'POP10': 39},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53597820702856, -3.817141480594785],
#        [-38.53607817476791, -3.815344394128431],
#        [-38.5342715213136, -3.815244950693852],
#        [-38.5341715418831, -3.817042036260943],
#        [-38.53597820702856, -3.817141480594785]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108686', 'POP10': 47},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5341715418831, -3.817042036260943],
#        [-38.5342715213136, -3.815244950693852],
#        [-38.532464868758666, -3.815145495568117],
#        [-38.53236487763695, -3.816942581135152],
#        [-38.5341715418831, -3.817042036260943]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108686', 'POP10': 156},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53236487763695, -3.816942581135152],
#        [-38.532464868758666, -3.815145495568117],
#        [-38.530658217102996, -3.815046028751169],
#        [-38.530558215189444, -3.816843114318203],
#        [-38.53236487763695, -3.816942581135152]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108688', 'POP10': 1047},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.539691486173126, -3.815543246823324],
#        [-38.539791428731405, -3.813746152263093],
#        [-38.53798478427035, -3.813646732210884],
#        [-38.53788482912154, -3.815443826771116],
#        [-38.539691486173126, -3.815543246823324]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108688', 'POP10': 508},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53788482912154, -3.815443826771116],
#        [-38.53798478427035, -3.813646732210884],
#        [-38.53617814070856, -3.813547300467519],
#        [-38.53607817476791, -3.815344394128431],
#        [-38.53788482912154, -3.815443826771116]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108688', 'POP10': 397},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53607817476791, -3.815344394128431],
#        [-38.53617814070856, -3.813547300467519],
#        [-38.53437149894546, -3.813447857032941],
#        [-38.5342715213136, -3.815244950693852],
#        [-38.53607817476791, -3.815344394128431]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108688', 'POP10': 73},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5342715213136, -3.815244950693852],
#        [-38.53437149894546, -3.813447857032941],
#        [-38.532564858081685, -3.813348401907149],
#        [-38.532464868758666, -3.815145495568117],
#        [-38.5342715213136, -3.815244950693852]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108688', 'POP10': 109},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.532464868758666, -3.815145495568117],
#        [-38.532564858081685, -3.813348401907149],
#        [-38.53075821901655, -3.813248935090257],
#        [-38.530658217102996, -3.815046028751169],
#        [-38.532464868758666, -3.815145495568117]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108690', 'POP10': 348},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.539791428731405, -3.813746152263093],
#        [-38.539891371289684, -3.811949050508247],
#        [-38.53808473762052, -3.811849630456038],
#        [-38.53798478427035, -3.813646732210884],
#        [-38.539791428731405, -3.813746152263093]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108690', 'POP10': 162},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53798478427035, -3.813646732210884],
#        [-38.53808473762052, -3.811849630456038],
#        [-38.53627810574994, -3.811750198712673],
#        [-38.53617814070856, -3.813547300467519],
#        [-38.53798478427035, -3.813646732210884]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108690', 'POP10': 377},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53617814070856, -3.813547300467519],
#        [-38.53627810574994, -3.811750198712673],
#        [-38.534471475678004, -3.811650755278094],
#        [-38.53437149894546, -3.813447857032941],
#        [-38.53617814070856, -3.813547300467519]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108690', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53437149894546, -3.813447857032941],
#        [-38.534471475678004, -3.811650755278094],
#        [-38.53266484650544, -3.81155130015236],
#        [-38.532564858081685, -3.813348401907149],
#        [-38.53437149894546, -3.813447857032941]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108690', 'POP10': 320},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.532564858081685, -3.813348401907149],
#        [-38.53266484650544, -3.81155130015236],
#        [-38.53085821913146, -3.811451834234731],
#        [-38.53075821901655, -3.813248935090257],
#        [-38.532564858081685, -3.813348401907149]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108692', 'POP10': 118},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.539891371289684, -3.811949050508247],
#        [-38.53999131115006, -3.810151939760146],
#        [-38.53818469007132, -3.810052519707995],
#        [-38.53808473762052, -3.811849630456038],
#        [-38.539891371289684, -3.811949050508247]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108692', 'POP10': 542},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53808473762052, -3.811849630456038],
#        [-38.53818469007132, -3.810052519707995],
#        [-38.53637806989195, -3.809953088863892],
#        [-38.53627810574994, -3.811750198712673],
#        [-38.53808473762052, -3.811849630456038]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108692', 'POP10': 417},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53627810574994, -3.811750198712673],
#        [-38.53637806989195, -3.809953088863892],
#        [-38.534571451511226, -3.809853645429371],
#        [-38.534471475678004, -3.811650755278094],
#        [-38.53627810574994, -3.811750198712673]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108692', 'POP10': 22},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.534471475678004, -3.811650755278094],
#        [-38.534571451511226, -3.809853645429371],
#        [-38.53276483402982, -3.809754191202899],
#        [-38.53266484650544, -3.81155130015236],
#        [-38.534471475678004, -3.811650755278094]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108692', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53266484650544, -3.81155130015236],
#        [-38.53276483402982, -3.809754191202899],
#        [-38.53095821744773, -3.80965472438595],
#        [-38.53085821913146, -3.811451834234731],
#        [-38.53266484650544, -3.81155130015236]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108694', 'POP10': 786},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53999131115006, -3.810151939760146],
#        [-38.54009125101038, -3.808354821817545],
#        [-38.53828464072353, -3.808255401765337],
#        [-38.53818469007132, -3.810052519707995],
#        [-38.53999131115006, -3.810151939760146]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108694', 'POP10': 774},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53818469007132, -3.810052519707995],
#        [-38.53828464072353, -3.808255401765337],
#        [-38.53647803223538, -3.808155970921291],
#        [-38.53637806989195, -3.809953088863892],
#        [-38.53818469007132, -3.810052519707995]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108694', 'POP10': 307},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53637806989195, -3.809953088863892],
#        [-38.53647803223538, -3.808155970921291],
#        [-38.53467142554581, -3.808056528386032],
#        [-38.534571451511226, -3.809853645429371],
#        [-38.53637806989195, -3.809953088863892]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108694', 'POP10': 166},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.534571451511226, -3.809853645429371],
#        [-38.53467142554581, -3.808056528386032],
#        [-38.53286481975556, -3.807957073260297],
#        [-38.53276483402982, -3.809754191202899],
#        [-38.534571451511226, -3.809853645429371]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108694', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53276483402982, -3.809754191202899],
#        [-38.53286481975556, -3.807957073260297],
#        [-38.531058214864686, -3.807857607342669],
#        [-38.53095821744773, -3.80965472438595],
#        [-38.53276483402982, -3.809754191202899]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108696', 'POP10': 314},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54009125101038, -3.808354821817545],
#        [-38.54019118907206, -3.80655769488169],
#        [-38.538384590476426, -3.806458275728801],
#        [-38.53828464072353, -3.808255401765337],
#        [-38.54009125101038, -3.808354821817545]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108696', 'POP10': 107},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53828464072353, -3.808255401765337],
#        [-38.538384590476426, -3.806458275728801],
#        [-38.53657799367943, -3.806358844884755],
#        [-38.53647803223538, -3.808155970921291],
#        [-38.53828464072353, -3.808255401765337]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108696', 'POP10': 248},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53647803223538, -3.808155970921291],
#        [-38.53657799367943, -3.806358844884755],
#        [-38.53477139868107, -3.806259402349497],
#        [-38.53467142554581, -3.808056528386032],
#        [-38.53647803223538, -3.808155970921291]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108696', 'POP10': 127},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53467142554581, -3.808056528386032],
#        [-38.53477139868107, -3.806259402349497],
#        [-38.53296480368272, -3.806159948123081],
#        [-38.53286481975556, -3.807957073260297],
#        [-38.53467142554581, -3.808056528386032]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108696', 'POP10': 17},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53286481975556, -3.807957073260297],
#        [-38.53296480368272, -3.806159948123081],
#        [-38.53115821138232, -3.806060482205453],
#        [-38.531058214864686, -3.807857607342669],
#        [-38.53286481975556, -3.807957073260297]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108698', 'POP10': 228},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54019118907206, -3.80655769488169],
#        [-38.5402911253351, -3.80476056075122],
#        [-38.53848453933, -3.804661141598331],
#        [-38.538384590476426, -3.806458275728801],
#        [-38.54019118907206, -3.80655769488169]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108698', 'POP10': 269},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.538384590476426, -3.806458275728801],
#        [-38.53848453933, -3.804661141598331],
#        [-38.53667795332484, -3.804561710754285],
#        [-38.53657799367943, -3.806358844884755],
#        [-38.538384590476426, -3.806458275728801]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108698', 'POP10': 172},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53657799367943, -3.806358844884755],
#        [-38.53667795332484, -3.804561710754285],
#        [-38.5348713700177, -3.804462268219083],
#        [-38.53477139868107, -3.806259402349497],
#        [-38.53657799367943, -3.806358844884755]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108698', 'POP10': 76},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53477139868107, -3.806259402349497],
#        [-38.5348713700177, -3.804462268219083],
#        [-38.53306478760982, -3.804362814891931],
#        [-38.53296480368272, -3.806159948123081],
#        [-38.53477139868107, -3.806259402349497]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108698', 'POP10': 19},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53296480368272, -3.806159948123081],
#        [-38.53306478760982, -3.804362814891931],
#        [-38.53125820610131, -3.804263348974303],
#        [-38.53115821138232, -3.806060482205453],
#        [-38.53296480368272, -3.806159948123081]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108700', 'POP10': 76},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5402911253351, -3.80476056075122],
#        [-38.54039106069882, -3.802963418526872],
#        [-38.53858448638488, -3.80286399937404],
#        [-38.53848453933, -3.804661141598331],
#        [-38.5402911253351, -3.80476056075122]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108700', 'POP10': 240},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53848453933, -3.804661141598331],
#        [-38.53858448638488, -3.80286399937404],
#        [-38.53677791207093, -3.802764569429314],
#        [-38.53667795332484, -3.804561710754285],
#        [-38.53848453933, -3.804661141598331]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108700', 'POP10': 563},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53667795332484, -3.804561710754285],
#        [-38.53677791207093, -3.802764569429314],
#        [-38.534971340454945, -3.802665126894055],
#        [-38.5348713700177, -3.804462268219083],
#        [-38.53667795332484, -3.804561710754285]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108700', 'POP10': 54},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5348713700177, -3.804462268219083],
#        [-38.534971340454945, -3.802665126894055],
#        [-38.53316476883896, -3.80256567266764],
#        [-38.53306478760982, -3.804362814891931],
#        [-38.5348713700177, -3.804462268219083]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108700', 'POP10': 164},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53306478760982, -3.804362814891931],
#        [-38.53316476883896, -3.80256567266764],
#        [-38.53135819992093, -3.802466207649331],
#        [-38.53125820610131, -3.804263348974303],
#        [-38.53306478760982, -3.804362814891931]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108702', 'POP10': 132},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54039106069882, -3.802963418526872],
#        [-38.540490995163225, -3.801166268208647],
#        [-38.53868443164117, -3.801066849955134],
#        [-38.53858448638488, -3.80286399937404],
#        [-38.54039106069882, -3.802963418526872]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108702', 'POP10': 307},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53858448638488, -3.80286399937404],
#        [-38.53868443164117, -3.801066849955134],
#        [-38.5368778699177, -3.800967419111032],
#        [-38.53677791207093, -3.802764569429314],
#        [-38.53858448638488, -3.80286399937404]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108702', 'POP10': 405},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53677791207093, -3.802764569429314],
#        [-38.5368778699177, -3.800967419111032],
#        [-38.53507130909361, -3.80086797747515],
#        [-38.534971340454945, -3.802665126894055],
#        [-38.53677791207093, -3.802764569429314]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108702', 'POP10': 448},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.534971340454945, -3.802665126894055],
#        [-38.53507130909361, -3.80086797747515],
#        [-38.5332647500681, -3.800768523248678],
#        [-38.53316476883896, -3.80256567266764],
#        [-38.534971340454945, -3.802665126894055]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108702', 'POP10': 290},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53316476883896, -3.80256567266764],
#        [-38.5332647500681, -3.800768523248678],
#        [-38.531458191941965, -3.800669058230426],
#        [-38.53135819992093, -3.802466207649331],
#        [-38.53316476883896, -3.80256567266764]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108704', 'POP10': 286},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.540490995163225, -3.801166268208647],
#        [-38.54059092782899, -3.799369110695864],
#        [-38.53878437599809, -3.799269691542975],
#        [-38.53868443164117, -3.801066849955134],
#        [-38.540490995163225, -3.801166268208647]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108704', 'POP10': 291},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53868443164117, -3.801066849955134],
#        [-38.53878437599809, -3.799269691542975],
#        [-38.536977825965835, -3.799170261598249],
#        [-38.5368778699177, -3.800967419111032],
#        [-38.53868443164117, -3.801066849955134]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108704', 'POP10': 300},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5368778699177, -3.800967419111032],
#        [-38.536977825965835, -3.799170261598249],
#        [-38.5351712768329, -3.79907081996231],
#        [-38.53507130909361, -3.80086797747515],
#        [-38.5368778699177, -3.800967419111032]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108704', 'POP10': 192},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53507130909361, -3.80086797747515],
#        [-38.5351712768329, -3.79907081996231],
#        [-38.5333647294986, -3.798971365735895],
#        [-38.5332647500681, -3.800768523248678],
#        [-38.53507130909361, -3.80086797747515]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108704', 'POP10': 143},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5332647500681, -3.800768523248678],
#        [-38.5333647294986, -3.798971365735895],
#        [-38.53155818306368, -3.798871900717586],
#        [-38.531458191941965, -3.800669058230426],
#        [-38.5332647500681, -3.800768523248678]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67080N108706', 'POP10': 66},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.54059092782899, -3.799369110695864],
#        [-38.54069085959543, -3.797571944189826],
#        [-38.53888431945575, -3.797472525936257],
#        [-38.53878437599809, -3.799269691542975],
#        [-38.54059092782899, -3.799369110695864]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67082N108706', 'POP10': 171},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53878437599809, -3.799269691542975],
#        [-38.53888431945575, -3.797472525936257],
#        [-38.53707778111465, -3.797373095991531],
#        [-38.536977825965835, -3.799170261598249],
#        [-38.53878437599809, -3.799269691542975]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67084N108706', 'POP10': 49},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.536977825965835, -3.799170261598249],
#        [-38.53707778111465, -3.797373095991531],
#        [-38.53527124367292, -3.797273654355592],
#        [-38.5351712768329, -3.79907081996231],
#        [-38.536977825965835, -3.799170261598249]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67086N108706', 'POP10': 5},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5351712768329, -3.79907081996231],
#        [-38.53527124367292, -3.797273654355592],
#        [-38.53346470713046, -3.797174201028497],
#        [-38.5333647294986, -3.798971365735895],
#        [-38.5351712768329, -3.79907081996231]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67088N108706', 'POP10': 10},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5333647294986, -3.798971365735895],
#        [-38.53346470713046, -3.797174201028497],
# ...
#        [-38.52363172042749, -3.811053851853728]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67090N108694', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53095821744773, -3.80965472438595],
#        [-38.531058214864686, -3.807857607342669],
#        [-38.529251611772395, -3.807758129733827],
#        [-38.529151602664285, -3.809555246777165],
#        [-38.53095821744773, -3.80965472438595]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67092N108694', 'POP10': 9},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.529151602664285, -3.809555246777165],
#        [-38.529251611772395, -3.807758129733827],
#        [-38.52744500957948, -3.807658640433885],
#        [-38.52734498878016, -3.809455757477167],
#        [-38.529151602664285, -3.809555246777165]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67094N108694', 'POP10': 280},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52734498878016, -3.809455757477167],
#        [-38.52744500957948, -3.807658640433885],
#        [-38.525638409185206, -3.807559139442674],
#        [-38.52553837669467, -3.809356255586692],
#        [-38.52734498878016, -3.809455757477167]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67096N108694', 'POP10': 121},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52553837669467, -3.809356255586692],
#        [-38.525638409185206, -3.807559139442674],
#        [-38.52383180969025, -3.807459626760306],
#        [-38.5237317655085, -3.809256742904324],
#        [-38.52553837669467, -3.809356255586692]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67098N108694', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5237317655085, -3.809256742904324],
#        [-38.52383180969025, -3.807459626760306],
#        [-38.52202521109456, -3.807360102386781],
#        [-38.52192515612103, -3.809157218530743],
#        [-38.5237317655085, -3.809256742904324]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67090N108696', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.531058214864686, -3.807857607342669],
#        [-38.53115821138232, -3.806060482205453],
#        [-38.52935161908192, -3.805961004596611],
#        [-38.529251611772395, -3.807758129733827],
#        [-38.531058214864686, -3.807857607342669]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67092N108696', 'POP10': 30},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.529251611772395, -3.807758129733827],
#        [-38.52935161908192, -3.805961004596611],
#        [-38.527545029479484, -3.805861515296669],
#        [-38.52744500957948, -3.807658640433885],
#        [-38.529251611772395, -3.807758129733827]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67094N108696', 'POP10': 224},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52744500957948, -3.807658640433885],
#        [-38.527545029479484, -3.805861515296669],
#        [-38.525738439877045, -3.805762014305458],
#        [-38.525638409185206, -3.807559139442674],
#        [-38.52744500957948, -3.807658640433885]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67096N108696', 'POP10': 59},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.525638409185206, -3.807559139442674],
#        [-38.525738439877045, -3.805762014305458],
#        [-38.52393185207325, -3.805662502522409],
#        [-38.52383180969025, -3.807459626760306],
#        [-38.525638409185206, -3.807559139442674]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67090N108698', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53115821138232, -3.806060482205453],
#        [-38.53125820610131, -3.804263348974303],
#        [-38.52945162549207, -3.804163871365517],
#        [-38.52935161908192, -3.805961004596611],
#        [-38.53115821138232, -3.806060482205453]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67092N108698', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52935161908192, -3.805961004596611],
#        [-38.52945162549207, -3.804163871365517],
#        [-38.52764504758085, -3.804064382065519],
#        [-38.527545029479484, -3.805861515296669],
#        [-38.52935161908192, -3.805961004596611]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67094N108698', 'POP10': 20},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.527545029479484, -3.805861515296669],
#        [-38.52764504758085, -3.804064382065519],
#        [-38.52583846966962, -3.803964881973684],
#        [-38.525738439877045, -3.805762014305458],
#        [-38.527545029479484, -3.805861515296669]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67090N108700', 'POP10': 139},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53125820610131, -3.804263348974303],
#        [-38.53135819992093, -3.802466207649331],
#        [-38.5295516310029, -3.80236673004049],
#        [-38.52945162549207, -3.804163871365517],
#        [-38.53125820610131, -3.804263348974303]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67092N108700', 'POP10': 83},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52945162549207, -3.804163871365517],
#        [-38.5295516310029, -3.80236673004049],
#        [-38.52774506388357, -3.802267241639868],
#        [-38.52764504758085, -3.804064382065519],
#        [-38.52945162549207, -3.804163871365517]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67094N108700', 'POP10': 0},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52764504758085, -3.804064382065519],
#        [-38.52774506388357, -3.802267241639868],
#        [-38.52593849856282, -3.802167741547976],
#        [-38.52583846966962, -3.803964881973684],
#        [-38.52764504758085, -3.804064382065519]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67090N108702', 'POP10': 74},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53135819992093, -3.802466207649331],
#        [-38.531458191941965, -3.800669058230426],
#        [-38.52965163471515, -3.800569581520904],
#        [-38.5295516310029, -3.80236673004049],
#        [-38.53135819992093, -3.802466207649331]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67092N108702', 'POP10': 162},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.5295516310029, -3.80236673004049],
#        [-38.52965163471515, -3.800569581520904],
#        [-38.52784507928692, -3.800470093120282],
#        [-38.52774506388357, -3.802267241639868],
#        [-38.5295516310029, -3.80236673004049]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67090N108704', 'POP10': 452},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.531458191941965, -3.800669058230426],
#        [-38.53155818306368, -3.798871900717586],
#        [-38.52975163752802, -3.798772424008121],
#        [-38.52965163471515, -3.800569581520904],
#        [-38.531458191941965, -3.800669058230426]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67090N108706', 'POP10': 23},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.53155818306368, -3.798871900717586],
#        [-38.5316581723867, -3.797074736010188],
#        [-38.529851638542254, -3.796975259300723],
#        [-38.52975163752802, -3.798772424008121],
#        [-38.53155818306368, -3.798871900717586]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67100N108676', 'POP10': 935},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52102459750711, -3.825330905896521],
#        [-38.52112466417185, -3.823533861698309],
#        [-38.51931796305348, -3.823434323834931],
#        [-38.51921788379826, -3.825231368033144],
#        [-38.52102459750711, -3.825330905896521]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67100N108678', 'POP10': 693},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52112466417185, -3.823533861698309],
#        [-38.52122473083659, -3.821736808506841],
#        [-38.51941804051012, -3.821637271542784],
#        [-38.51931796305348, -3.823434323834931],
#        [-38.52112466417185, -3.823533861698309]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67100N108680', 'POP10': 84},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52122473083659, -3.821736808506841],
#        [-38.52132479480338, -3.819939748120817],
#        [-38.51951811706738, -3.819840211156759],
#        [-38.51941804051012, -3.821637271542784],
#        [-38.52122473083659, -3.821736808506841]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67102N108680', 'POP10': 143},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.51941804051012, -3.821637271542784],
#        [-38.51951811706738, -3.819840211156759],
#        [-38.517711440230755, -3.819740662501545],
#        [-38.51761135198228, -3.82153772198825],
#        [-38.51941804051012, -3.821637271542784]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67100N108682', 'POP10': 163},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52132479480338, -3.819939748120817],
#        [-38.52142485877016, -3.818142680540234],
#        [-38.519618191826055, -3.818043142676856],
#        [-38.51951811706738, -3.819840211156759],
#        [-38.52132479480338, -3.819939748120817]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67102N108682', 'POP10': 337},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.51951811706738, -3.819840211156759],
#        [-38.519618191826055, -3.818043142676856],
#        [-38.51781152668059, -3.817943594021585],
#        [-38.517711440230755, -3.819740662501545],
#        [-38.51951811706738, -3.819840211156759]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67100N108684', 'POP10': 293},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52142485877016, -3.818142680540234],
#        [-38.521524920038985, -3.816345603966397],
#        [-38.519718265685356, -3.816246067002339],
#        [-38.519618191826055, -3.818043142676856],
#        [-38.52142485877016, -3.818142680540234]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67102N108684', 'POP10': 243},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.519618191826055, -3.818043142676856],
#        [-38.519718265685356, -3.816246067002339],
#        [-38.517911611331726, -3.816146518347125],
#        [-38.51781152668059, -3.817943594021585],
#        [-38.519618191826055, -3.818043142676856]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67100N108686', 'POP10': 480},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.521524920038985, -3.816345603966397],
#        [-38.52162498130781, -3.814548519298683],
#        [-38.519818337746074, -3.814448983233945],
#        [-38.519718265685356, -3.816246067002339],
#        [-38.521524920038985, -3.816345603966397]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67102N108686', 'POP10': 111},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.519718265685356, -3.816246067002339],
#        [-38.519818337746074, -3.814448983233945],
#        [-38.51801169598292, -3.814349434578673],
#        [-38.517911611331726, -3.816146518347125],
#        [-38.519718265685356, -3.816246067002339]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67104N108686', 'POP10': 141},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.517911611331726, -3.816146518347125],
#        [-38.51801169598292, -3.814349434578673],
#        [-38.516205055119144, -3.814249874232246],
#        [-38.51610495967611, -3.816046958000641],
#        [-38.517911611331726, -3.816146518347125]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67100N108688', 'POP10': 325},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52162498130781, -3.814548519298683],
#        [-38.521725040777994, -3.812751427436353],
#        [-38.519918408907415, -3.812651890472296],
#        [-38.519818337746074, -3.814448983233945],
#        [-38.52162498130781, -3.814548519298683]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67102N108688', 'POP10': 274},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.519818337746074, -3.814448983233945],
#        [-38.519918408907415, -3.812651890472296],
#        [-38.518111778835475, -3.812552342716401],
#        [-38.51801169598292, -3.814349434578673],
#        [-38.519818337746074, -3.814448983233945]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67104N108688', 'POP10': 296},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.51801169598292, -3.814349434578673],
#        [-38.518111778835475, -3.812552342716401],
#        [-38.516305149662855, -3.812452782369974],
#        [-38.516205055119144, -3.814249874232246],
#        [-38.51801169598292, -3.814349434578673]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67106N108688', 'POP10': 64},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.516205055119144, -3.814249874232246],
#        [-38.516305149662855, -3.812452782369974],
#        [-38.51449852138961, -3.812353211231652],
#        [-38.51439841515469, -3.814150303093982],
#        [-38.516205055119144, -3.814249874232246]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67100N108690', 'POP10': 308},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.521725040777994, -3.812751427436353],
#        [-38.52182509844948, -3.810954326580884],
#        [-38.52001847916944, -3.810854790516146],
#        [-38.519918408907415, -3.812651890472296],
#        [-38.521725040777994, -3.812751427436353]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67102N108690', 'POP10': 387},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.519918408907415, -3.812651890472296],
#        [-38.52001847916944, -3.810854790516146],
#        [-38.51821185988939, -3.810755242760195],
#        [-38.518111778835475, -3.812552342716401],
#        [-38.519918408907415, -3.812651890472296]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67104N108690', 'POP10': 373},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.518111778835475, -3.812552342716401],
#        [-38.51821185988939, -3.810755242760195],
#        [-38.516405242407984, -3.810655683313087],
#        [-38.516305149662855, -3.812452782369974],
#        [-38.518111778835475, -3.812552342716401]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67106N108690', 'POP10': 369},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.516305149662855, -3.812452782369974],
#        [-38.516405242407984, -3.810655683313087],
#        [-38.5145986258259, -3.810556112174766],
#        [-38.51449852138961, -3.812353211231652],
#        [-38.516305149662855, -3.812452782369974]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67100N108692', 'POP10': 219},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52182509844948, -3.810954326580884],
#        [-38.52192515612103, -3.809157218530743],
#        [-38.52011854763282, -3.809057682466005],
#        [-38.52001847916944, -3.810854790516146],
#        [-38.52182509844948, -3.810954326580884]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67102N108692', 'POP10': 289},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.52001847916944, -3.810854790516146],
#        [-38.52011854763282, -3.809057682466005],
#        [-38.51831194004393, -3.80895813471011],
#        [-38.51821185988939, -3.810755242760195],
#        [-38.52001847916944, -3.810854790516146]]]]}},
#   {'type': 'Feature',
#    'properties': {'id': '200ME67104N108692', 'POP10': 200},
#    'geometry': {'type': 'MultiPolygon',
#     'coordinates': [[[[-38.51821185988939, -3.810755242760195],
#        [-38.51831194004393, -3.80895813471011],
#        [-38.516505334253736, -3.808858575263002],
#        [-38.516405242407984, -3.810655683313087],
#        [-38.51821185988939, -3.810755242760195]]]]}}]}

# %%
# Count the total number of grid cells in GeoJSON
total_cells = len(grid['features'])
print(f"Total grid cells in GeoJSON: {total_cells}")
# Out:
# Total grid cells in GeoJSON: 220

# %%
# Partition the original GeoJSON grid into subsets of up to 4 cells each

# Number of cells per batch
subset_size = 4

# Split the original grid cells into subsets
subsets = [grid['features'][i:i + subset_size] for i in range(0, len(grid['features']), subset_size)]

# Create a new FeatureCollection structure for each subset and add a batch ID ("lote_id")
grid_subsets = []
for index, subset in enumerate(subsets):
    grid_subset = {
        'type': 'FeatureCollection',
        'features': subset,
        'lote_id': f"lote{index + 1}",
        'crs': grid['crs']
    }
    grid_subsets.append(grid_subset)

# %%
# Calcular e imprimir o total de subsets criados
total_subsets = len(grid_subsets)
print(f"Total de subsets criados: {total_subsets}")
# Out:
# Total de subsets criados: 55

# %%
# Check the subsets
grid_subsets
# Out:
# [{'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67074N108676', 'POP10': 3},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.544511985439726, -3.826623840517755],
#         [-38.544611901917676, -3.824826793621583],
#         [-38.54280518371223, -3.824727406844318],
#         [-38.54270525554307, -3.82652445374049],
#         [-38.544511985439726, -3.826623840517755]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67076N108676', 'POP10': 166},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54270525554307, -3.82652445374049],
#         [-38.54280518371223, -3.824727406844318],
#         [-38.54099846640605, -3.824628008375839],
#         [-38.54089852744505, -3.826425055272011],
#         [-38.54270525554307, -3.82652445374049]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108676', 'POP10': 562},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54089852744505, -3.826425055272011],
#         [-38.54099846640605, -3.824628008375839],
#         [-38.53919175089857, -3.824528599115524],
#         [-38.539091799347034, -3.826325645112377],
#         [-38.54089852744505, -3.826425055272011]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67074N108678', 'POP10': 223},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.544611901917676, -3.824826793621583],
#         [-38.54471181659699, -3.823029738631476],
#         [-38.5429051100827, -3.822930351854211],
#         [-38.54280518371223, -3.824727406844318],
#         [-38.544611901917676, -3.824826793621583]]]]}}],
#   'lote_id': 'lote1',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67076N108678', 'POP10': 62},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54280518371223, -3.824727406844318],
#         [-38.5429051100827, -3.822930351854211],
#         [-38.54109840446773, -3.822830954285052],
#         [-38.54099846640605, -3.824628008375839],
#         [-38.54280518371223, -3.824727406844318]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108678', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54099846640605, -3.824628008375839],
#         [-38.54109840446773, -3.822830954285052],
#         [-38.539291700651404, -3.822731544125418],
#         [-38.53919175089857, -3.824528599115524],
#         [-38.54099846640605, -3.824628008375839]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67076N108680', 'POP10': 9},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5429051100827, -3.822930351854211],
#         [-38.543005034654584, -3.821133288770227],
#         [-38.54119834073077, -3.821033891201068],
#         [-38.54109840446773, -3.822830954285052],
#         [-38.5429051100827, -3.822930351854211]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108680', 'POP10': 15},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54109840446773, -3.822830954285052],
#         [-38.54119834073077, -3.821033891201068],
#         [-38.53939164860566, -3.820934481940753],
#         [-38.539291700651404, -3.822731544125418],
#         [-38.54109840446773, -3.822830954285052]]]]}}],
#   'lote_id': 'lote2',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67078N108686', 'POP10': 181},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54139821055895, -3.81743974255005],
#         [-38.541498143224715, -3.815642656083639],
#         [-38.539691486173126, -3.815543246823324],
#         [-38.53959154181615, -3.817340333289678],
#         [-38.54139821055895, -3.81743974255005]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67076N108688', 'POP10': 291},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.543304802074886, -3.815742052753478],
#         [-38.54340472215017, -3.813944958193247],
#         [-38.5415980749911, -3.813845561523408],
#         [-38.541498143224715, -3.815642656083639],
#         [-38.543304802074886, -3.815742052753478]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108688', 'POP10': 533},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.541498143224715, -3.815642656083639],
#         [-38.5415980749911, -3.813845561523408],
#         [-38.539791428731405, -3.813746152263093],
#         [-38.539691486173126, -3.815543246823324],
#         [-38.541498143224715, -3.815642656083639]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67074N108690', 'POP10': 1434},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.545211370208506, -3.814044343171872],
#         [-38.54531127769326, -3.812247240517706],
#         [-38.54350464042676, -3.812147855539081],
#         [-38.54340472215017, -3.813944958193247],
#         [-38.545211370208506, -3.814044343171872]]]]}}],
#   'lote_id': 'lote3',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67076N108690', 'POP10': 787},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54340472215017, -3.813944958193247],
#         [-38.54350464042676, -3.812147855539081],
#         [-38.5416980049589, -3.812048458869242],
#         [-38.5415980749911, -3.813845561523408],
#         [-38.54340472215017, -3.813944958193247]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108690', 'POP10': 828},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5415980749911, -3.813845561523408],
#         [-38.5416980049589, -3.812048458869242],
#         [-38.539891371289684, -3.811949050508247],
#         [-38.539791428731405, -3.813746152263093],
#         [-38.5415980749911, -3.813845561523408]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67074N108692', 'POP10': 1047},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54531127769326, -3.812247240517706],
#         [-38.54541118337937, -3.810450129769606],
#         [-38.54360455780403, -3.810350744790981],
#         [-38.54350464042676, -3.812147855539081],
#         [-38.54531127769326, -3.812247240517706]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67076N108692', 'POP10': 554},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54350464042676, -3.812147855539081],
#         [-38.54360455780403, -3.810350744790981],
#         [-38.541797934027386, -3.810251348121199],
#         [-38.5416980049589, -3.812048458869242],
#         [-38.54350464042676, -3.812147855539081]]]]}}],
#   'lote_id': 'lote4',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67078N108692', 'POP10': 167},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5416980049589, -3.812048458869242],
#         [-38.541797934027386, -3.810251348121199],
#         [-38.53999131115006, -3.810151939760146],
#         [-38.539891371289684, -3.811949050508247],
#         [-38.5416980049589, -3.812048458869242]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67074N108694', 'POP10': 1064},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54541118337937, -3.810450129769606],
#         [-38.545511088166165, -3.808653010927685],
#         [-38.54370447428204, -3.808553625949003],
#         [-38.54360455780403, -3.810350744790981],
#         [-38.54541118337937, -3.810450129769606]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67076N108694', 'POP10': 755},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54360455780403, -3.810350744790981],
#         [-38.54370447428204, -3.808553625949003],
#         [-38.54189786219655, -3.808454229279221],
#         [-38.541797934027386, -3.810251348121199],
#         [-38.54360455780403, -3.810350744790981]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108694', 'POP10': 804},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.541797934027386, -3.810251348121199],
#         [-38.54189786219655, -3.808454229279221],
#         [-38.54009125101038, -3.808354821817545],
#         [-38.53999131115006, -3.810151939760146],
#         [-38.541797934027386, -3.810251348121199]]]]}}],
#   'lote_id': 'lote5',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67072N108696', 'POP10': 992},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54731770294961, -3.808752383315777],
#         [-38.547417594246554, -3.806955256379922],
#         [-38.54561099115426, -3.80685588399183],
#         [-38.545511088166165, -3.808653010927685],
#         [-38.54731770294961, -3.808752383315777]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67074N108696', 'POP10': 1318},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.545511088166165, -3.808653010927685],
#         [-38.54561099115426, -3.80685588399183],
#         [-38.54380438896135, -3.806756499013147],
#         [-38.54370447428204, -3.808553625949003],
#         [-38.545511088166165, -3.808653010927685]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67076N108696', 'POP10': 673},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54370447428204, -3.808553625949003],
#         [-38.54380438896135, -3.806756499013147],
#         [-38.54199778856707, -3.806657103242685],
#         [-38.54189786219655, -3.808454229279221],
#         [-38.54370447428204, -3.808553625949003]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108696', 'POP10': 478},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54189786219655, -3.808454229279221],
#         [-38.54199778856707, -3.806657103242685],
#         [-38.54019118907206, -3.80655769488169],
#         [-38.54009125101038, -3.808354821817545],
#         [-38.54189786219655, -3.808454229279221]]]]}}],
#   'lote_id': 'lote6',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67074N108698', 'POP10': 532},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54561099115426, -3.80685588399183],
#         [-38.54571089234378, -3.80505874896204],
#         [-38.54390430184202, -3.804959364882734],
#         [-38.54380438896135, -3.806756499013147],
#         [-38.54561099115426, -3.80685588399183]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67076N108698', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54380438896135, -3.806756499013147],
#         [-38.54390430184202, -3.804959364882734],
#         [-38.5420977131389, -3.804859968212895],
#         [-38.54199778856707, -3.806657103242685],
#         [-38.54380438896135, -3.806756499013147]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108698', 'POP10': 29},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54199778856707, -3.806657103242685],
#         [-38.5420977131389, -3.804859968212895],
#         [-38.5402911253351, -3.80476056075122],
#         [-38.54019118907206, -3.80655769488169],
#         [-38.54199778856707, -3.806657103242685]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67074N108700', 'POP10': 882},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54571089234378, -3.80505874896204],
#         [-38.545810793533235, -3.803261605838372],
#         [-38.54400421472269, -3.803162221759067],
#         [-38.54390430184202, -3.804959364882734],
#         [-38.54571089234378, -3.80505874896204]]]]}}],
#   'lote_id': 'lote7',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67076N108700', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54390430184202, -3.804959364882734],
#         [-38.54400421472269, -3.803162221759067],
#         [-38.542197636811466, -3.803062825988604],
#         [-38.5420977131389, -3.804859968212895],
#         [-38.54390430184202, -3.804959364882734]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108700', 'POP10': 361},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5420977131389, -3.804859968212895],
#         [-38.542197636811466, -3.803062825988604],
#         [-38.54039106069882, -3.802963418526872],
#         [-38.5402911253351, -3.80476056075122],
#         [-38.5420977131389, -3.804859968212895]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67074N108702', 'POP10': 632},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.545810793533235, -3.803261605838372],
#         [-38.54591069202479, -3.801464455520147],
#         [-38.5441041249054, -3.801365071440841],
#         [-38.54400421472269, -3.803162221759067],
#         [-38.545810793533235, -3.803261605838372]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67076N108702', 'POP10': 6},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54400421472269, -3.803162221759067],
#         [-38.5441041249054, -3.801365071440841],
#         [-38.542297559584654, -3.801265675670322],
#         [-38.542197636811466, -3.803062825988604],
#         [-38.54400421472269, -3.803162221759067]]]]}}],
#   'lote_id': 'lote8',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67078N108702', 'POP10': 60},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.542197636811466, -3.803062825988604],
#         [-38.542297559584654, -3.801265675670322],
#         [-38.540490995163225, -3.801166268208647],
#         [-38.54039106069882, -3.802963418526872],
#         [-38.542197636811466, -3.803062825988604]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67076N108704', 'POP10': 301},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5441041249054, -3.801365071440841],
#         [-38.544204035088114, -3.799567912129419],
#         [-38.54239748055926, -3.799468517258219],
#         [-38.542297559584654, -3.801265675670322],
#         [-38.5441041249054, -3.801365071440841]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108704', 'POP10': 78},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.542297559584654, -3.801265675670322],
#         [-38.54239748055926, -3.799468517258219],
#         [-38.54059092782899, -3.799369110695864],
#         [-38.540490995163225, -3.801166268208647],
#         [-38.542297559584654, -3.801265675670322]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67078N108706', 'POP10': 241},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54239748055926, -3.799468517258219],
#         [-38.54249740063449, -3.797671350752182],
#         [-38.54069085959543, -3.797571944189826],
#         [-38.54059092782899, -3.799369110695864],
#         [-38.54239748055926, -3.799468517258219]]]]}}],
#   'lote_id': 'lote9',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67084N108672', 'POP10': 8},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53527839688047, -3.829720858330916],
#         [-38.535378373613014, -3.827923828521818],
#         [-38.53357163832038, -3.827824383288601],
#         [-38.53347164989668, -3.829621413097698],
#         [-38.53527839688047, -3.829720858330916]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108672', 'POP10': 140},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53347164989668, -3.829621413097698],
#         [-38.53357163832038, -3.827824383288601],
#         [-38.531764904826446, -3.827724926364226],
#         [-38.53166490471153, -3.829521956173267],
#         [-38.53347164989668, -3.829621413097698]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108672', 'POP10': 196},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53166490471153, -3.829521956173267],
#         [-38.531764904826446, -3.827724926364226],
#         [-38.52995817223183, -3.827625458647958],
#         [-38.529858160425704, -3.829422487557736],
#         [-38.53166490471153, -3.829521956173267]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108674', 'POP10': 7},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5389918477955, -3.828122683914671],
#         [-38.539091799347034, -3.826325645112377],
#         [-38.537285073946975, -3.826226224160848],
#         [-38.53718510980491, -3.828023262063823],
#         [-38.5389918477955, -3.828122683914671]]]]}}],
#   'lote_id': 'lote10',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67082N108674', 'POP10': 23},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53718510980491, -3.828023262063823],
#         [-38.537285073946975, -3.826226224160848],
#         [-38.53547834854692, -3.826126790618844],
#         [-38.535378373613014, -3.827923828521818],
#         [-38.53718510980491, -3.828023262063823]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108674', 'POP10': 13},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.535378373613014, -3.827923828521818],
#         [-38.53547834854692, -3.826126790618844],
#         [-38.53367162584482, -3.826027345385626],
#         [-38.53357163832038, -3.827824383288601],
#         [-38.535378373613014, -3.827923828521818]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108674', 'POP10': 86},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53357163832038, -3.827824383288601],
#         [-38.53367162584482, -3.826027345385626],
#         [-38.53186490314272, -3.825927889360571],
#         [-38.531764904826446, -3.827724926364226],
#         [-38.53357163832038, -3.827824383288601]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108674', 'POP10': 172},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.531764904826446, -3.827724926364226],
#         [-38.53186490314272, -3.825927889360571],
#         [-38.53005818223926, -3.825828420744983],
#         [-38.52995817223183, -3.827625458647958],
#         [-38.531764904826446, -3.827724926364226]]]]}}],
#   'lote_id': 'lote11',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67080N108676', 'POP10': 22},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.539091799347034, -3.826325645112377],
#         [-38.53919175089857, -3.824528599115524],
#         [-38.537385036290345, -3.824429177264676],
#         [-38.537285073946975, -3.826226224160848],
#         [-38.539091799347034, -3.826325645112377]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108676', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.537285073946975, -3.826226224160848],
#         [-38.537385036290345, -3.824429177264676],
#         [-38.53557832348082, -3.824329744621991],
#         [-38.53547834854692, -3.826126790618844],
#         [-38.537285073946975, -3.826226224160848]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108676', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53547834854692, -3.826126790618844],
#         [-38.53557832348082, -3.824329744621991],
#         [-38.53377161157056, -3.824230299388773],
#         [-38.53367162584482, -3.826027345385626],
#         [-38.53547834854692, -3.826126790618844]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108676', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53367162584482, -3.826027345385626],
#         [-38.53377161157056, -3.824230299388773],
#         [-38.53196490055967, -3.824130843363662],
#         [-38.53186490314272, -3.825927889360571],
#         [-38.53367162584482, -3.826027345385626]]]]}}],
#   'lote_id': 'lote12',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67088N108676', 'POP10': 65},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53186490314272, -3.825927889360571],
#         [-38.53196490055967, -3.824130843363662],
#         [-38.530158191347425, -3.824031375647394],
#         [-38.53005818223926, -3.825828420744983],
#         [-38.53186490314272, -3.825927889360571]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108678', 'POP10': 33},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53919175089857, -3.824528599115524],
#         [-38.539291700651404, -3.822731544125418],
#         [-38.537484997734396, -3.822632123173889],
#         [-38.537385036290345, -3.824429177264676],
#         [-38.53919175089857, -3.824528599115524]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108678', 'POP10': 30},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.537385036290345, -3.824429177264676],
#         [-38.537484997734396, -3.822632123173889],
#         [-38.53567829571671, -3.822532690531204],
#         [-38.53557832348082, -3.824329744621991],
#         [-38.537385036290345, -3.824429177264676]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108678', 'POP10': 60},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53557832348082, -3.824329744621991],
#         [-38.53567829571671, -3.822532690531204],
#         [-38.533871595497715, -3.822433246197306],
#         [-38.53377161157056, -3.824230299388773],
#         [-38.53557832348082, -3.824329744621991]]]]}}],
#   'lote_id': 'lote13',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67086N108678', 'POP10': 342},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53377161157056, -3.824230299388773],
#         [-38.533871595497715, -3.822433246197306],
#         [-38.532064897077305, -3.822333790172252],
#         [-38.53196490055967, -3.824130843363662],
#         [-38.53377161157056, -3.824230299388773]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108678', 'POP10': 283},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53196490055967, -3.824130843363662],
#         [-38.532064897077305, -3.822333790172252],
#         [-38.530258199556215, -3.822234322455984],
#         [-38.530158191347425, -3.824031375647394],
#         [-38.53196490055967, -3.824130843363662]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108680', 'POP10': 158},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.539291700651404, -3.822731544125418],
#         [-38.53939164860566, -3.820934481940753],
#         [-38.53758495737986, -3.820835060989225],
#         [-38.537484997734396, -3.822632123173889],
#         [-38.539291700651404, -3.822731544125418]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108680', 'POP10': 36},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.537484997734396, -3.822632123173889],
#         [-38.53758495737986, -3.820835060989225],
#         [-38.53577826795265, -3.82073562834654],
#         [-38.53567829571671, -3.822532690531204],
#         [-38.537484997734396, -3.822632123173889]]]]}}],
#   'lote_id': 'lote14',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67084N108680', 'POP10': 23},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53567829571671, -3.822532690531204],
#         [-38.53577826795265, -3.82073562834654],
#         [-38.533971578525495, -3.820636184012642],
#         [-38.533871595497715, -3.822433246197306],
#         [-38.53567829571671, -3.822532690531204]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108680', 'POP10': 242},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.533871595497715, -3.822433246197306],
#         [-38.533971578525495, -3.820636184012642],
#         [-38.5321648917963, -3.820536727987587],
#         [-38.532064897077305, -3.822333790172252],
#         [-38.533871595497715, -3.822433246197306]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108680', 'POP10': 375},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.532064897077305, -3.822333790172252],
#         [-38.5321648917963, -3.820536727987587],
#         [-38.530358205966365, -3.820437260271319],
#         [-38.530258199556215, -3.822234322455984],
#         [-38.532064897077305, -3.822333790172252]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108682', 'POP10': 160},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53939164860566, -3.820934481940753],
#         [-38.53949159566059, -3.819137411662155],
#         [-38.537684916125954, -3.819037990710683],
#         [-38.53758495737986, -3.820835060989225],
#         [-38.53939164860566, -3.820934481940753]]]]}}],
#   'lote_id': 'lote15',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67082N108682', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53758495737986, -3.820835060989225],
#         [-38.537684916125954, -3.819037990710683],
#         [-38.535878237490635, -3.818938558067941],
#         [-38.53577826795265, -3.82073562834654],
#         [-38.53758495737986, -3.820835060989225]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108682', 'POP10': 3},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53577826795265, -3.82073562834654],
#         [-38.535878237490635, -3.818938558067941],
#         [-38.534071560653956, -3.818839114633363],
#         [-38.533971578525495, -3.820636184012642],
#         [-38.53577826795265, -3.82073562834654]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108682', 'POP10': 79},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.533971578525495, -3.820636184012642],
#         [-38.534071560653956, -3.818839114633363],
#         [-38.532264885615916, -3.818739658608308],
#         [-38.5321648917963, -3.820536727987587],
#         [-38.533971578525495, -3.820636184012642]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108682', 'POP10': 188},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5321648917963, -3.820536727987587],
#         [-38.532264885615916, -3.818739658608308],
#         [-38.53045821057793, -3.81864019089204],
#         [-38.530358205966365, -3.820437260271319],
#         [-38.5321648917963, -3.820536727987587]]]]}}],
#   'lote_id': 'lote16',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67080N108684', 'POP10': 340},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53949159566059, -3.819137411662155],
#         [-38.53959154181615, -3.817340333289678],
#         [-38.537784873073406, -3.817240912338207],
#         [-38.537684916125954, -3.819037990710683],
#         [-38.53949159566059, -3.819137411662155]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108684', 'POP10': 74},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.537684916125954, -3.819037990710683],
#         [-38.537784873073406, -3.817240912338207],
#         [-38.53597820702856, -3.817141480594785],
#         [-38.535878237490635, -3.818938558067941],
#         [-38.537684916125954, -3.819037990710683]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108684', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.535878237490635, -3.818938558067941],
#         [-38.53597820702856, -3.817141480594785],
#         [-38.5341715418831, -3.817042036260943],
#         [-38.534071560653956, -3.818839114633363],
#         [-38.535878237490635, -3.818938558067941]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108684', 'POP10': 9},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.534071560653956, -3.818839114633363],
#         [-38.5341715418831, -3.817042036260943],
#         [-38.53236487763695, -3.816942581135152],
#         [-38.532264885615916, -3.818739658608308],
#         [-38.534071560653956, -3.818839114633363]]]]}}],
#   'lote_id': 'lote17',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67088N108684', 'POP10': 388},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.532264885615916, -3.818739658608308],
#         [-38.53236487763695, -3.816942581135152],
#         [-38.530558215189444, -3.816843114318203],
#         [-38.53045821057793, -3.81864019089204],
#         [-38.532264885615916, -3.818739658608308]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108686', 'POP10': 672},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53959154181615, -3.817340333289678],
#         [-38.539691486173126, -3.815543246823324],
#         [-38.53788482912154, -3.815443826771116],
#         [-38.537784873073406, -3.817240912338207],
#         [-38.53959154181615, -3.817340333289678]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108686', 'POP10': 511},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.537784873073406, -3.817240912338207],
#         [-38.53788482912154, -3.815443826771116],
#         [-38.53607817476791, -3.815344394128431],
#         [-38.53597820702856, -3.817141480594785],
#         [-38.537784873073406, -3.817240912338207]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108686', 'POP10': 39},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53597820702856, -3.817141480594785],
#         [-38.53607817476791, -3.815344394128431],
#         [-38.5342715213136, -3.815244950693852],
#         [-38.5341715418831, -3.817042036260943],
#         [-38.53597820702856, -3.817141480594785]]]]}}],
#   'lote_id': 'lote18',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67086N108686', 'POP10': 47},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5341715418831, -3.817042036260943],
#         [-38.5342715213136, -3.815244950693852],
#         [-38.532464868758666, -3.815145495568117],
#         [-38.53236487763695, -3.816942581135152],
#         [-38.5341715418831, -3.817042036260943]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108686', 'POP10': 156},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53236487763695, -3.816942581135152],
#         [-38.532464868758666, -3.815145495568117],
#         [-38.530658217102996, -3.815046028751169],
#         [-38.530558215189444, -3.816843114318203],
#         [-38.53236487763695, -3.816942581135152]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108688', 'POP10': 1047},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.539691486173126, -3.815543246823324],
#         [-38.539791428731405, -3.813746152263093],
#         [-38.53798478427035, -3.813646732210884],
#         [-38.53788482912154, -3.815443826771116],
#         [-38.539691486173126, -3.815543246823324]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108688', 'POP10': 508},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53788482912154, -3.815443826771116],
#         [-38.53798478427035, -3.813646732210884],
#         [-38.53617814070856, -3.813547300467519],
#         [-38.53607817476791, -3.815344394128431],
#         [-38.53788482912154, -3.815443826771116]]]]}}],
#   'lote_id': 'lote19',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67084N108688', 'POP10': 397},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53607817476791, -3.815344394128431],
#         [-38.53617814070856, -3.813547300467519],
#         [-38.53437149894546, -3.813447857032941],
#         [-38.5342715213136, -3.815244950693852],
#         [-38.53607817476791, -3.815344394128431]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108688', 'POP10': 73},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5342715213136, -3.815244950693852],
#         [-38.53437149894546, -3.813447857032941],
#         [-38.532564858081685, -3.813348401907149],
#         [-38.532464868758666, -3.815145495568117],
#         [-38.5342715213136, -3.815244950693852]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108688', 'POP10': 109},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.532464868758666, -3.815145495568117],
#         [-38.532564858081685, -3.813348401907149],
#         [-38.53075821901655, -3.813248935090257],
#         [-38.530658217102996, -3.815046028751169],
#         [-38.532464868758666, -3.815145495568117]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108690', 'POP10': 348},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.539791428731405, -3.813746152263093],
#         [-38.539891371289684, -3.811949050508247],
#         [-38.53808473762052, -3.811849630456038],
#         [-38.53798478427035, -3.813646732210884],
#         [-38.539791428731405, -3.813746152263093]]]]}}],
#   'lote_id': 'lote20',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67082N108690', 'POP10': 162},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53798478427035, -3.813646732210884],
#         [-38.53808473762052, -3.811849630456038],
#         [-38.53627810574994, -3.811750198712673],
#         [-38.53617814070856, -3.813547300467519],
#         [-38.53798478427035, -3.813646732210884]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108690', 'POP10': 377},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53617814070856, -3.813547300467519],
#         [-38.53627810574994, -3.811750198712673],
#         [-38.534471475678004, -3.811650755278094],
#         [-38.53437149894546, -3.813447857032941],
#         [-38.53617814070856, -3.813547300467519]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108690', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53437149894546, -3.813447857032941],
#         [-38.534471475678004, -3.811650755278094],
#         [-38.53266484650544, -3.81155130015236],
#         [-38.532564858081685, -3.813348401907149],
#         [-38.53437149894546, -3.813447857032941]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108690', 'POP10': 320},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.532564858081685, -3.813348401907149],
#         [-38.53266484650544, -3.81155130015236],
#         [-38.53085821913146, -3.811451834234731],
#         [-38.53075821901655, -3.813248935090257],
#         [-38.532564858081685, -3.813348401907149]]]]}}],
#   'lote_id': 'lote21',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67080N108692', 'POP10': 118},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.539891371289684, -3.811949050508247],
#         [-38.53999131115006, -3.810151939760146],
#         [-38.53818469007132, -3.810052519707995],
#         [-38.53808473762052, -3.811849630456038],
#         [-38.539891371289684, -3.811949050508247]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108692', 'POP10': 542},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53808473762052, -3.811849630456038],
#         [-38.53818469007132, -3.810052519707995],
#         [-38.53637806989195, -3.809953088863892],
#         [-38.53627810574994, -3.811750198712673],
#         [-38.53808473762052, -3.811849630456038]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108692', 'POP10': 417},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53627810574994, -3.811750198712673],
#         [-38.53637806989195, -3.809953088863892],
#         [-38.534571451511226, -3.809853645429371],
#         [-38.534471475678004, -3.811650755278094],
#         [-38.53627810574994, -3.811750198712673]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108692', 'POP10': 22},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.534471475678004, -3.811650755278094],
#         [-38.534571451511226, -3.809853645429371],
#         [-38.53276483402982, -3.809754191202899],
#         [-38.53266484650544, -3.81155130015236],
#         [-38.534471475678004, -3.811650755278094]]]]}}],
#   'lote_id': 'lote22',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67088N108692', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53266484650544, -3.81155130015236],
#         [-38.53276483402982, -3.809754191202899],
#         [-38.53095821744773, -3.80965472438595],
#         [-38.53085821913146, -3.811451834234731],
#         [-38.53266484650544, -3.81155130015236]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108694', 'POP10': 786},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53999131115006, -3.810151939760146],
#         [-38.54009125101038, -3.808354821817545],
#         [-38.53828464072353, -3.808255401765337],
#         [-38.53818469007132, -3.810052519707995],
#         [-38.53999131115006, -3.810151939760146]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108694', 'POP10': 774},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53818469007132, -3.810052519707995],
#         [-38.53828464072353, -3.808255401765337],
#         [-38.53647803223538, -3.808155970921291],
#         [-38.53637806989195, -3.809953088863892],
#         [-38.53818469007132, -3.810052519707995]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108694', 'POP10': 307},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53637806989195, -3.809953088863892],
#         [-38.53647803223538, -3.808155970921291],
#         [-38.53467142554581, -3.808056528386032],
#         [-38.534571451511226, -3.809853645429371],
#         [-38.53637806989195, -3.809953088863892]]]]}}],
#   'lote_id': 'lote23',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67086N108694', 'POP10': 166},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.534571451511226, -3.809853645429371],
#         [-38.53467142554581, -3.808056528386032],
#         [-38.53286481975556, -3.807957073260297],
#         [-38.53276483402982, -3.809754191202899],
#         [-38.534571451511226, -3.809853645429371]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108694', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53276483402982, -3.809754191202899],
#         [-38.53286481975556, -3.807957073260297],
#         [-38.531058214864686, -3.807857607342669],
#         [-38.53095821744773, -3.80965472438595],
#         [-38.53276483402982, -3.809754191202899]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108696', 'POP10': 314},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54009125101038, -3.808354821817545],
#         [-38.54019118907206, -3.80655769488169],
#         [-38.538384590476426, -3.806458275728801],
#         [-38.53828464072353, -3.808255401765337],
#         [-38.54009125101038, -3.808354821817545]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108696', 'POP10': 107},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53828464072353, -3.808255401765337],
#         [-38.538384590476426, -3.806458275728801],
#         [-38.53657799367943, -3.806358844884755],
#         [-38.53647803223538, -3.808155970921291],
#         [-38.53828464072353, -3.808255401765337]]]]}}],
#   'lote_id': 'lote24',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67084N108696', 'POP10': 248},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53647803223538, -3.808155970921291],
#         [-38.53657799367943, -3.806358844884755],
#         [-38.53477139868107, -3.806259402349497],
#         [-38.53467142554581, -3.808056528386032],
#         [-38.53647803223538, -3.808155970921291]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108696', 'POP10': 127},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53467142554581, -3.808056528386032],
#         [-38.53477139868107, -3.806259402349497],
#         [-38.53296480368272, -3.806159948123081],
#         [-38.53286481975556, -3.807957073260297],
#         [-38.53467142554581, -3.808056528386032]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108696', 'POP10': 17},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53286481975556, -3.807957073260297],
#         [-38.53296480368272, -3.806159948123081],
#         [-38.53115821138232, -3.806060482205453],
#         [-38.531058214864686, -3.807857607342669],
#         [-38.53286481975556, -3.807957073260297]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108698', 'POP10': 228},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54019118907206, -3.80655769488169],
#         [-38.5402911253351, -3.80476056075122],
#         [-38.53848453933, -3.804661141598331],
#         [-38.538384590476426, -3.806458275728801],
#         [-38.54019118907206, -3.80655769488169]]]]}}],
#   'lote_id': 'lote25',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67082N108698', 'POP10': 269},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.538384590476426, -3.806458275728801],
#         [-38.53848453933, -3.804661141598331],
#         [-38.53667795332484, -3.804561710754285],
#         [-38.53657799367943, -3.806358844884755],
#         [-38.538384590476426, -3.806458275728801]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108698', 'POP10': 172},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53657799367943, -3.806358844884755],
#         [-38.53667795332484, -3.804561710754285],
#         [-38.5348713700177, -3.804462268219083],
#         [-38.53477139868107, -3.806259402349497],
#         [-38.53657799367943, -3.806358844884755]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108698', 'POP10': 76},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53477139868107, -3.806259402349497],
#         [-38.5348713700177, -3.804462268219083],
#         [-38.53306478760982, -3.804362814891931],
#         [-38.53296480368272, -3.806159948123081],
#         [-38.53477139868107, -3.806259402349497]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67088N108698', 'POP10': 19},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53296480368272, -3.806159948123081],
#         [-38.53306478760982, -3.804362814891931],
#         [-38.53125820610131, -3.804263348974303],
#         [-38.53115821138232, -3.806060482205453],
#         [-38.53296480368272, -3.806159948123081]]]]}}],
#   'lote_id': 'lote26',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67080N108700', 'POP10': 76},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5402911253351, -3.80476056075122],
#         [-38.54039106069882, -3.802963418526872],
#         [-38.53858448638488, -3.80286399937404],
#         [-38.53848453933, -3.804661141598331],
#         [-38.5402911253351, -3.80476056075122]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108700', 'POP10': 240},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53848453933, -3.804661141598331],
#         [-38.53858448638488, -3.80286399937404],
#         [-38.53677791207093, -3.802764569429314],
#         [-38.53667795332484, -3.804561710754285],
#         [-38.53848453933, -3.804661141598331]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67084N108700', 'POP10': 563},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53667795332484, -3.804561710754285],
#         [-38.53677791207093, -3.802764569429314],
#         [-38.534971340454945, -3.802665126894055],
#         [-38.5348713700177, -3.804462268219083],
#         [-38.53667795332484, -3.804561710754285]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67086N108700', 'POP10': 54},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5348713700177, -3.804462268219083],
#         [-38.534971340454945, -3.802665126894055],
#         [-38.53316476883896, -3.80256567266764],
#         [-38.53306478760982, -3.804362814891931],
#         [-38.5348713700177, -3.804462268219083]]]]}}],
#   'lote_id': 'lote27',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67088N108700', 'POP10': 164},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53306478760982, -3.804362814891931],
#         [-38.53316476883896, -3.80256567266764],
#         [-38.53135819992093, -3.802466207649331],
#         [-38.53125820610131, -3.804263348974303],
#         [-38.53306478760982, -3.804362814891931]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67080N108702', 'POP10': 132},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.54039106069882, -3.802963418526872],
#         [-38.540490995163225, -3.801166268208647],
#         [-38.53868443164117, -3.801066849955134],
#         [-38.53858448638488, -3.80286399937404],
#         [-38.54039106069882, -3.802963418526872]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67082N108702', 'POP10': 307},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53858448638488, -3.80286399937404],
#         [-38.53868443164117, -3.801066849955134],
#         [-38.5368778699177, -3.800967419111032],
#         [-38.53677791207093, -3.802764569429314],
#         [-38.53858448638488, -3.80286399937404]]]]}},
# ...
#         [-38.52383180969025, -3.807459626760306],
#         [-38.52202521109456, -3.807360102386781],
#         [-38.52192515612103, -3.809157218530743],
#         [-38.5237317655085, -3.809256742904324]]]]}}],
#   'lote_id': 'lote46',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67090N108696', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.531058214864686, -3.807857607342669],
#         [-38.53115821138232, -3.806060482205453],
#         [-38.52935161908192, -3.805961004596611],
#         [-38.529251611772395, -3.807758129733827],
#         [-38.531058214864686, -3.807857607342669]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67092N108696', 'POP10': 30},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.529251611772395, -3.807758129733827],
#         [-38.52935161908192, -3.805961004596611],
#         [-38.527545029479484, -3.805861515296669],
#         [-38.52744500957948, -3.807658640433885],
#         [-38.529251611772395, -3.807758129733827]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67094N108696', 'POP10': 224},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52744500957948, -3.807658640433885],
#         [-38.527545029479484, -3.805861515296669],
#         [-38.525738439877045, -3.805762014305458],
#         [-38.525638409185206, -3.807559139442674],
#         [-38.52744500957948, -3.807658640433885]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67096N108696', 'POP10': 59},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.525638409185206, -3.807559139442674],
#         [-38.525738439877045, -3.805762014305458],
#         [-38.52393185207325, -3.805662502522409],
#         [-38.52383180969025, -3.807459626760306],
#         [-38.525638409185206, -3.807559139442674]]]]}}],
#   'lote_id': 'lote47',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67090N108698', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53115821138232, -3.806060482205453],
#         [-38.53125820610131, -3.804263348974303],
#         [-38.52945162549207, -3.804163871365517],
#         [-38.52935161908192, -3.805961004596611],
#         [-38.53115821138232, -3.806060482205453]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67092N108698', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52935161908192, -3.805961004596611],
#         [-38.52945162549207, -3.804163871365517],
#         [-38.52764504758085, -3.804064382065519],
#         [-38.527545029479484, -3.805861515296669],
#         [-38.52935161908192, -3.805961004596611]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67094N108698', 'POP10': 20},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.527545029479484, -3.805861515296669],
#         [-38.52764504758085, -3.804064382065519],
#         [-38.52583846966962, -3.803964881973684],
#         [-38.525738439877045, -3.805762014305458],
#         [-38.527545029479484, -3.805861515296669]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67090N108700', 'POP10': 139},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53125820610131, -3.804263348974303],
#         [-38.53135819992093, -3.802466207649331],
#         [-38.5295516310029, -3.80236673004049],
#         [-38.52945162549207, -3.804163871365517],
#         [-38.53125820610131, -3.804263348974303]]]]}}],
#   'lote_id': 'lote48',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67092N108700', 'POP10': 83},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52945162549207, -3.804163871365517],
#         [-38.5295516310029, -3.80236673004049],
#         [-38.52774506388357, -3.802267241639868],
#         [-38.52764504758085, -3.804064382065519],
#         [-38.52945162549207, -3.804163871365517]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67094N108700', 'POP10': 0},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52764504758085, -3.804064382065519],
#         [-38.52774506388357, -3.802267241639868],
#         [-38.52593849856282, -3.802167741547976],
#         [-38.52583846966962, -3.803964881973684],
#         [-38.52764504758085, -3.804064382065519]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67090N108702', 'POP10': 74},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53135819992093, -3.802466207649331],
#         [-38.531458191941965, -3.800669058230426],
#         [-38.52965163471515, -3.800569581520904],
#         [-38.5295516310029, -3.80236673004049],
#         [-38.53135819992093, -3.802466207649331]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67092N108702', 'POP10': 162},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.5295516310029, -3.80236673004049],
#         [-38.52965163471515, -3.800569581520904],
#         [-38.52784507928692, -3.800470093120282],
#         [-38.52774506388357, -3.802267241639868],
#         [-38.5295516310029, -3.80236673004049]]]]}}],
#   'lote_id': 'lote49',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67090N108704', 'POP10': 452},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.531458191941965, -3.800669058230426],
#         [-38.53155818306368, -3.798871900717586],
#         [-38.52975163752802, -3.798772424008121],
#         [-38.52965163471515, -3.800569581520904],
#         [-38.531458191941965, -3.800669058230426]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67090N108706', 'POP10': 23},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.53155818306368, -3.798871900717586],
#         [-38.5316581723867, -3.797074736010188],
#         [-38.529851638542254, -3.796975259300723],
#         [-38.52975163752802, -3.798772424008121],
#         [-38.53155818306368, -3.798871900717586]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67100N108676', 'POP10': 935},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52102459750711, -3.825330905896521],
#         [-38.52112466417185, -3.823533861698309],
#         [-38.51931796305348, -3.823434323834931],
#         [-38.51921788379826, -3.825231368033144],
#         [-38.52102459750711, -3.825330905896521]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67100N108678', 'POP10': 693},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52112466417185, -3.823533861698309],
#         [-38.52122473083659, -3.821736808506841],
#         [-38.51941804051012, -3.821637271542784],
#         [-38.51931796305348, -3.823434323834931],
#         [-38.52112466417185, -3.823533861698309]]]]}}],
#   'lote_id': 'lote50',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67100N108680', 'POP10': 84},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52122473083659, -3.821736808506841],
#         [-38.52132479480338, -3.819939748120817],
#         [-38.51951811706738, -3.819840211156759],
#         [-38.51941804051012, -3.821637271542784],
#         [-38.52122473083659, -3.821736808506841]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67102N108680', 'POP10': 143},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.51941804051012, -3.821637271542784],
#         [-38.51951811706738, -3.819840211156759],
#         [-38.517711440230755, -3.819740662501545],
#         [-38.51761135198228, -3.82153772198825],
#         [-38.51941804051012, -3.821637271542784]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67100N108682', 'POP10': 163},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52132479480338, -3.819939748120817],
#         [-38.52142485877016, -3.818142680540234],
#         [-38.519618191826055, -3.818043142676856],
#         [-38.51951811706738, -3.819840211156759],
#         [-38.52132479480338, -3.819939748120817]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67102N108682', 'POP10': 337},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.51951811706738, -3.819840211156759],
#         [-38.519618191826055, -3.818043142676856],
#         [-38.51781152668059, -3.817943594021585],
#         [-38.517711440230755, -3.819740662501545],
#         [-38.51951811706738, -3.819840211156759]]]]}}],
#   'lote_id': 'lote51',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67100N108684', 'POP10': 293},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52142485877016, -3.818142680540234],
#         [-38.521524920038985, -3.816345603966397],
#         [-38.519718265685356, -3.816246067002339],
#         [-38.519618191826055, -3.818043142676856],
#         [-38.52142485877016, -3.818142680540234]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67102N108684', 'POP10': 243},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.519618191826055, -3.818043142676856],
#         [-38.519718265685356, -3.816246067002339],
#         [-38.517911611331726, -3.816146518347125],
#         [-38.51781152668059, -3.817943594021585],
#         [-38.519618191826055, -3.818043142676856]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67100N108686', 'POP10': 480},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.521524920038985, -3.816345603966397],
#         [-38.52162498130781, -3.814548519298683],
#         [-38.519818337746074, -3.814448983233945],
#         [-38.519718265685356, -3.816246067002339],
#         [-38.521524920038985, -3.816345603966397]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67102N108686', 'POP10': 111},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.519718265685356, -3.816246067002339],
#         [-38.519818337746074, -3.814448983233945],
#         [-38.51801169598292, -3.814349434578673],
#         [-38.517911611331726, -3.816146518347125],
#         [-38.519718265685356, -3.816246067002339]]]]}}],
#   'lote_id': 'lote52',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67104N108686', 'POP10': 141},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.517911611331726, -3.816146518347125],
#         [-38.51801169598292, -3.814349434578673],
#         [-38.516205055119144, -3.814249874232246],
#         [-38.51610495967611, -3.816046958000641],
#         [-38.517911611331726, -3.816146518347125]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67100N108688', 'POP10': 325},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52162498130781, -3.814548519298683],
#         [-38.521725040777994, -3.812751427436353],
#         [-38.519918408907415, -3.812651890472296],
#         [-38.519818337746074, -3.814448983233945],
#         [-38.52162498130781, -3.814548519298683]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67102N108688', 'POP10': 274},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.519818337746074, -3.814448983233945],
#         [-38.519918408907415, -3.812651890472296],
#         [-38.518111778835475, -3.812552342716401],
#         [-38.51801169598292, -3.814349434578673],
#         [-38.519818337746074, -3.814448983233945]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67104N108688', 'POP10': 296},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.51801169598292, -3.814349434578673],
#         [-38.518111778835475, -3.812552342716401],
#         [-38.516305149662855, -3.812452782369974],
#         [-38.516205055119144, -3.814249874232246],
#         [-38.51801169598292, -3.814349434578673]]]]}}],
#   'lote_id': 'lote53',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67106N108688', 'POP10': 64},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.516205055119144, -3.814249874232246],
#         [-38.516305149662855, -3.812452782369974],
#         [-38.51449852138961, -3.812353211231652],
#         [-38.51439841515469, -3.814150303093982],
#         [-38.516205055119144, -3.814249874232246]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67100N108690', 'POP10': 308},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.521725040777994, -3.812751427436353],
#         [-38.52182509844948, -3.810954326580884],
#         [-38.52001847916944, -3.810854790516146],
#         [-38.519918408907415, -3.812651890472296],
#         [-38.521725040777994, -3.812751427436353]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67102N108690', 'POP10': 387},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.519918408907415, -3.812651890472296],
#         [-38.52001847916944, -3.810854790516146],
#         [-38.51821185988939, -3.810755242760195],
#         [-38.518111778835475, -3.812552342716401],
#         [-38.519918408907415, -3.812651890472296]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67104N108690', 'POP10': 373},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.518111778835475, -3.812552342716401],
#         [-38.51821185988939, -3.810755242760195],
#         [-38.516405242407984, -3.810655683313087],
#         [-38.516305149662855, -3.812452782369974],
#         [-38.518111778835475, -3.812552342716401]]]]}}],
#   'lote_id': 'lote54',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}},
#  {'type': 'FeatureCollection',
#   'features': [{'type': 'Feature',
#     'properties': {'id': '200ME67106N108690', 'POP10': 369},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.516305149662855, -3.812452782369974],
#         [-38.516405242407984, -3.810655683313087],
#         [-38.5145986258259, -3.810556112174766],
#         [-38.51449852138961, -3.812353211231652],
#         [-38.516305149662855, -3.812452782369974]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67100N108692', 'POP10': 219},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52182509844948, -3.810954326580884],
#         [-38.52192515612103, -3.809157218530743],
#         [-38.52011854763282, -3.809057682466005],
#         [-38.52001847916944, -3.810854790516146],
#         [-38.52182509844948, -3.810954326580884]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67102N108692', 'POP10': 289},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.52001847916944, -3.810854790516146],
#         [-38.52011854763282, -3.809057682466005],
#         [-38.51831194004393, -3.80895813471011],
#         [-38.51821185988939, -3.810755242760195],
#         [-38.52001847916944, -3.810854790516146]]]]}},
#    {'type': 'Feature',
#     'properties': {'id': '200ME67104N108692', 'POP10': 200},
#     'geometry': {'type': 'MultiPolygon',
#      'coordinates': [[[[-38.51821185988939, -3.810755242760195],
#         [-38.51831194004393, -3.80895813471011],
#         [-38.516505334253736, -3.808858575263002],
#         [-38.516405242407984, -3.810655683313087],
#         [-38.51821185988939, -3.810755242760195]]]]}}],
#   'lote_id': 'lote55',
#   'crs': {'type': 'name',
#    'properties': {'name': 'urn:ogc:def:crs:EPSG::4674'}}}]

# %% [markdown]
# #### Visualize the spatial distribution of the homogeneous grid cell

# %%
import folium
import ipywidgets as widgets
from IPython.display import display

# Function to calculate the centroid of a polygon (original grid)
def calculate_centroid(coordinates):
    x = [p[0] for p in coordinates]
    y = [p[1] for p in coordinates]
    centroid_x = sum(x) / len(coordinates)
    centroid_y = sum(y) / len(coordinates)
    return [centroid_y, centroid_x]

# Calculate the coordinates of the centroid of the original grid
first_polygon = grid['features'][0]['geometry']['coordinates'][0][0]
centroid_coords = calculate_centroid(first_polygon)

# Function to plot a subset
def plot_subset(subset_index):
    subset_to_plot = grid_subsets[subset_index]

    # GeoJson style
    style = {'fillColor': '#8C8989', 'color': '#e31a1c', 'weight': 2}

    # Initialize the Folium map at the centroid of the original grid
    m = folium.Map(location=centroid_coords, tiles='OpenStreetMap', zoom_start=14)

    # Add GeoJson to the map
    folium.GeoJson(
        subset_to_plot,
        name=f'Grade Estatística 200m - Lote {subset_index+1}',
        tooltip=folium.GeoJsonTooltip(fields=['id', 'POP10']),
        style_function=lambda x: style
    ).add_to(m)

    # Display the map
    display(m)

# Create the drop-down list with the subset indexes
dropdown = widgets.Dropdown(
    options=[(f'Lote {i+1}', i) for i in range(len(grid_subsets))],
    description='Select a Batch:',
    disabled=False,
)

# Update the map based on the selection
widgets.interactive(plot_subset, subset_index=dropdown)
# Out:
# interactive(children=(Dropdown(description='Select a Batch:', options=(('Lote 1', 0), ('Lote 2', 1), ('Lote 3'…

# %% [markdown]
# ### **OHSOME API**
#
#  - Access to features, attributes and OSM history edits using the OHSOME API (*OpenStreetMap History Data Analytics Platform*)
#
# > - https://docs.ohsome.org/ohsome-api/v1/

# %%
# URL of OHSOME API Metadata endpoint
URL = 'https://api.ohsome.org/v1/metadata'

# Request to the OHSOME API
response = requests.get(URL)

response_json = response.json()
response_json

# %% [markdown]
# ### Retrieving data from OpenStreetMap using OHSOME API and homogeneous grid cells

# %% [markdown]
# #### Step 1 (*API Endpoint: Elements Aggregation*): count the number of OSM features (elements) and calculate the proportion of features with the attribute "name" fill in by contributors, for each grid cells:
#
#
#  - Determine the total number of OSM features for interest tags, grouped by grid cell;
#
#  - Quantify the total number of features with attribute "name" filled in; and
#
#  - Calculate the proportion of features with attribute "name" filled in for each grid cell.
#
#  - Period of data retrieved: 2007-10-08 to 2024-03-10;

# %%
# Approach for processing batches of 04 cells from the original grid

# Step 1 (API Endpoint: Elements Aggregation): count the number of OSM features
# (elements) and calculate the proportion of features with "name" attribute filled by contributors, for each grid cells:
# Aggregation method: count
# POST /elements/(aggregation)/groupBy/boundary/groupBy/tag

# Start the time counter
start_time = time.time()

# Load a copy of previously created grid_subsets
grid_subset2 = grid_subsets.copy()

# OHSOME API endpoint url
url_tag = "https://api.ohsome.org/v1/elements/count/groupBy/boundary/groupBy/tag"

# OSM tags of interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_base = {
    'time': '2007-10-08/2024-03-10'
}

# List to store the final results
final_results = {}

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
    for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        for tag, value in tags_de_interesse.items():
            # 1st: Aggregate the object of each interest tag by grid cell
            params = params_base.copy()
            params.update({
                'bpolys': cell_geojson,
                'filter': f'{tag}={value}',
                'groupByKey': tag,
                'groupByValues': value
            })

            response = requests.post(url_tag, data=params)
            if response.status_code == 200:
                data = response.json()

                total_count = sum(res.get('value', 0) for res in data.get('groupByResult', [])[0].get('result', []))
                feature['properties'][f'{tag}_total_count'] = total_count

            # 2nd: Count the features with the attribute 'name' filled in
            params['filter'] = f'{tag}={value} and name=*'
            response = requests.post(url_tag, data=params)
            if response.status_code == 200:
                data = response.json()

                name_count = sum(res.get('value', 0) for res in data.get('groupByResult', [])[0].get('result', []))
                feature['properties'][f'{tag}_name_count'] = name_count
                name_ratio_perc = (name_count / total_count) * 100 if total_count > 0 else 0
                feature['properties'][f'{tag}_name_ratio'] = name_ratio_perc

        # Add cell results to final_results
        final_results[cell_id] = feature['properties']

    print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutes and {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 1
grid_subset2

# %% [markdown]
# #### Step 2 (*API Endpoint: Contributions Aggregation*): count the total number of contributions for features with and without the attribute "name" filled in:
#
# - Count the **total number of contributions** to the *interest tags* for the total features in the grid cells, with and without the attribute "name" filled in.
#
# - Period of data retrieved: 2007-10-08 to 2024-03-10.

# %%
# Approach for processing batches of 04 cells from the original grid

# Step 2 (API Endpoint: Endpoint Contributions Aggregation): count the total number of
# contributions for features with and without a name attribute filled in.
# Aggregation method: count
# POST /contributions/count/groupBy/boundary

# Start the time counter
start_time = time.time()

# OHSOME API endpoint url
url_contributions = "https://api.ohsome.org/v1/contributions/count/groupBy/boundary"

# OSM tags of Interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_contributions_base = {
    'time': '2007-10-08/2024-03-10'
}

# Function to process the response
def process_response(response, cell_id):
    if response.status_code == 200:
        data = response.json()
        return sum(result.get('value', 0) for result in data.get('groupByResult', [])[0].get('result', []))
    else:
        print(f"Cell query error {cell_id}: {response.text}")
        return 0

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
  for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        for tag in tags_de_interesse:

            # Settings for all features
            params_contributions_all = params_contributions_base.copy()
            params_contributions_all.update({'bpolys': cell_geojson, 'filter': f'{tag}=*'})
            response_all = requests.post(url_contributions, data=params_contributions_all)
            contributions_all = process_response(response_all, cell_id)


            # Settings for all features with 'name' filled in
            params_contributions_name = params_contributions_base.copy()
            params_contributions_name.update({'bpolys': cell_geojson, 'filter': f'{tag}=* and name=*'})
            response_name = requests.post(url_contributions, data=params_contributions_name)
            contributions_name = process_response(response_name, cell_id)

            # Update the feature's properties
            feature['properties'][f'{tag}_total_contributions'] = contributions_all
            feature['properties'][f'{tag}_name_contributions'] = contributions_name

  print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutos and {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 2
grid_subset2

# %% [markdown]
# #### Step 3 (*API Endpoint: Contributions Aggregation*): Count the number of contributions in the past five years for features with the attribute "name" filled in:
#
#  - Count the number of contributions in the past five years for tags of interest, aggregated by grid cells, with the attribute "name" filled in;
#
#  - Period of data retrieved: 2019-03-09 to 2024-03-10

# %%
# Approach for processing batches of 04 cells from the original grid

# Step 3 (API Endpoint: Contributions Aggregation): Count the number of contributions
# in the past five years for features with a filled-in name
# Aggregation method: count
# POST /contributions/latest/count

# Start the time counter
start_time = time.time()

# OHSOME API endpoint url
url_latest_contributions = "https://api.ohsome.org/v1/contributions/latest/count"

# OSM tags of Interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_contributions_base = {
    'time': '2019-03-09/2024-03-10'
}

# Function to process the response
def process_response(response, cell_id):
    if response.status_code == 200:
        data = response.json()
        latest_result = data.get('result', [])
        return latest_result[-1].get('value', 0) if latest_result else 0
    else:
        print(f"Cell query error {cell_id}: {response.text}")
        return 0

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
    for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        # Settings for all features with 'name' filled in
        for tag in tags_de_interesse:
            params_latest_contributions = params_contributions_base.copy()
            params_latest_contributions.update({'bpolys': cell_geojson, 'filter': f'{tag}=* and name=*'})
            response = requests.post(url_latest_contributions, data=params_latest_contributions)
            latest_contributions_count = process_response(response, cell_id)

            # Update the feature's properties
            feature['properties'][f'{tag}_latest5_name_contributions'] = latest_contributions_count

    print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutes e {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 3
grid_subset2

# %% [markdown]
# #### Step 4 (*API Endpoint: Contributions Aggregation*): Count the total number of contributions to features with a filled-in name where a tagChange occurred:
#
# - Count the total number of contributions to the tags of interest, aggregated by grid cell, with the attribute name filled in, considering the type of contribution (contributionType) tag change ('tagChange').
#
#   - *contributionType available: ‘creation’, ‘deletion’, ‘tagChange’, ‘geometryChange’ ou uma combinação destes*
#
# - Period of data retrieved: 2007-10-08 to 2024-03-10.

# %%
# Approach for processing batches of 04 cells from the original grid

# Step 4 (API Endpoint: Contributions Aggregation): Count the total number of
# contributions to features with a filled-in name where a tagChange occurred
# Aggregation method: count
# POST /contributions/count/groupBy/boundary

# Start the time counter
start_time = time.time()

# OHSOME API endpoint url
url_contributions = "https://api.ohsome.org/v1/contributions/count/groupBy/boundary"

# OSM tags of Interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_contributions_base = {
    'time': '2007-10-08/2024-03-10',
    'contributionType': 'tagChange'
}

# Function to process the response
def process_response(response, cell_id):
    if response.status_code == 200:
        data = response.json()
        return sum(result.get('value', 0) for result in data.get('groupByResult', [])[0].get('result', []))
    else:
        print(f"Erro na consulta da célula {cell_id}: {response.text}")
        return 0

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
    for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        # Settings for all features with 'name' filled in AND tagChange
        for tag in tags_de_interesse:
            params_contributions = params_contributions_base.copy()
            params_contributions.update({'bpolys': cell_geojson, 'filter': f'{tag}=* and name=*'})

            response = requests.post(url_contributions, data=params_contributions)
            contributions_count = process_response(response, cell_id)

            # Update the feature's properties
            feature['properties'][f'{tag}_name_tagChange_contributions'] = contributions_count

    print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutes and {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 4
grid_subset2

# %% [markdown]
# #### Step 5 (API Endpoint: Users Aggregation): Count the number of users (contributors) who edited features with attribute name filled in:
#
# - Count the number of users who edited features of the OSM tags of Interest with attribute "name" attribute filled in, aggregated by grid cells.
#
# - Period of data retrieved: 2007-10-08 to 2024-03-10.

# %%
# # Approach for processing batches of 04 cells from the original grid

# Step 5 (API Endpoint: Users Aggregation): Count the number of users (contributors)
# who edited features with attribute name filled in:
# Aggregation method: count
# POST /users/count/groupBy/boundary

# Start the time counter
start_time = time.time()

# OHSOME API endpoint url
url_users_count = "https://api.ohsome.org/v1/users/count/groupBy/boundary"

# OSM tags of Interest
tags_de_interesse = {
    'leisure': '*',
    'building': '*',
    'amenity': '*'
}

# Configuring basic parameters
params_users_count_base = {
    'time': '2007-10-08/2024-03-10'
}

# Function to process the response
def process_user_response(response, cell_id):
    if response.status_code == 200:
        data = response.json()
        for result in data.get('groupByResult', []):
            if result['groupByObject'] == cell_id:
                return result['result'][0]['value']
    return 0

# Process each batch of grid_subsets
for lote_id, subset in enumerate(grid_subset2, start=1):
    for feature in subset['features']:
        cell_geojson = json.dumps({"type": "FeatureCollection", "features": [feature]})
        cell_id = feature['properties']['id']

        # Settings for all features with 'name' filled
        for tag in tags_de_interesse:
            params_users_count = params_users_count_base.copy()
            params_users_count.update({'bpolys': cell_geojson, 'filter': f'{tag}=* and name=*'})

            response = requests.post(url_users_count, data=params_users_count)
            users_name_count = process_user_response(response, cell_id)

            # Update the feature's properties
            feature['properties'][f'{tag}_users_count_name'] = users_name_count

    print(f"{subset['lote_id']} successfully processed!")

# Stop the time counter
end_time = time.time()

# Calculate and display the total execution time
total_time_seconds = end_time - start_time
print(f"Total execution time: {total_time_seconds // 60} minutes and {total_time_seconds % 60} seconds")

# %%
# Check the grid cells results of step 5
grid_subset2

# %% [markdown]
# #### Save the updated grid cells with the information Extracted using the OHSOME API endpoints

# %%
output_filename = "../data/output_code1/grade_id77_passare_results.geojson"

# Create a new FeatureCollection to combine all the subsets
grid_subset2_results = {
    'type': 'FeatureCollection',
    'crs': grid_subset2[0]['crs'],
    'features': []
}

# Iterate over each subset and add its features to the combined FeatureCollection
for subset in grid_subset2:
    grid_subset2_results['features'].extend(subset['features'])

# Save the combined grid cells in a GeoJSON file
with open(output_filename, 'w') as file:
    json.dump(grid_subset2_results, file)

# %% [markdown]
# ---
